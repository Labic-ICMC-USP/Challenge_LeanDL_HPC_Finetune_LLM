# %%
# !pip install codecarbon # reiniciar apos instalar este pacote se você estiver em um notebook
# Out:
# Requirement already satisfied: codecarbon in /home/magalylica/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (3.0.4)
# Requirement already satisfied: arrow in /home/magalylica/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from codecarbon) (1.3.0)
# Requirement already satisfied: click in /home/magalylica/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from codecarbon) (8.2.1)
# Requirement already satisfied: fief-client[cli] in /home/magalylica/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from codecarbon) (0.20.0)
# Requirement already satisfied: pandas in /home/magalylica/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from codecarbon) (2.2.3)
# Requirement already satisfied: prometheus_client in /home/magalylica/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from codecarbon) (0.22.1)
# Requirement already satisfied: psutil>=6.0.0 in /home/magalylica/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from codecarbon) (7.0.0)
# Requirement already satisfied: py-cpuinfo in /home/magalylica/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from codecarbon) (9.0.0)
# Requirement already satisfied: pydantic in /home/magalylica/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from codecarbon) (2.11.7)
# Requirement already satisfied: pynvml in /home/magalylica/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from codecarbon) (12.0.0)
# Requirement already satisfied: rapidfuzz in /home/magalylica/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from codecarbon) (3.14.0)
# Requirement already satisfied: requests in /home/magalylica/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from codecarbon) (2.32.5)
# Requirement already satisfied: questionary in /home/magalylica/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from codecarbon) (2.1.1)
# Requirement already satisfied: rich in /home/magalylica/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from codecarbon) (14.1.0)
# Requirement already satisfied: typer in /home/magalylica/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from codecarbon) (0.17.3)
# Requirement already satisfied: python-dateutil>=2.7.0 in /home/magalylica/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from arrow->codecarbon) (2.9.0.post0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /home/magalylica/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from arrow->codecarbon) (2.9.0.20250822)
# Requirement already satisfied: six>=1.5 in /home/magalylica/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from python-dateutil>=2.7.0->arrow->codecarbon) (1.17.0)
# Requirement already satisfied: httpx<0.28.0,>=0.21.3 in /home/magalylica/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from fief-client[cli]->codecarbon) (0.27.2)
# Requirement already satisfied: jwcrypto<2.0.0,>=1.4 in /home/magalylica/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from fief-client[cli]->codecarbon) (1.5.6)
# Requirement already satisfied: yaspin in /home/magalylica/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from fief-client[cli]->codecarbon) (3.1.0)
# Requirement already satisfied: anyio in /home/magalylica/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from httpx<0.28.0,>=0.21.3->fief-client[cli]->codecarbon) (4.10.0)
# Requirement already satisfied: certifi in /home/magalylica/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from httpx<0.28.0,>=0.21.3->fief-client[cli]->codecarbon) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /home/magalylica/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from httpx<0.28.0,>=0.21.3->fief-client[cli]->codecarbon) (1.0.9)
# Requirement already satisfied: idna in /home/magalylica/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from httpx<0.28.0,>=0.21.3->fief-client[cli]->codecarbon) (3.10)
# Requirement already satisfied: sniffio in /home/magalylica/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from httpx<0.28.0,>=0.21.3->fief-client[cli]->codecarbon) (1.3.1)
# Requirement already satisfied: h11>=0.16 in /home/magalylica/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from httpcore==1.*->httpx<0.28.0,>=0.21.3->fief-client[cli]->codecarbon) (0.16.0)
# Requirement already satisfied: cryptography>=3.4 in /home/magalylica/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from jwcrypto<2.0.0,>=1.4->fief-client[cli]->codecarbon) (45.0.6)
# Requirement already satisfied: typing-extensions>=4.5.0 in /home/magalylica/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from jwcrypto<2.0.0,>=1.4->fief-client[cli]->codecarbon) (4.12.2)
# Requirement already satisfied: cffi>=1.14 in /home/magalylica/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from cryptography>=3.4->jwcrypto<2.0.0,>=1.4->fief-client[cli]->codecarbon) (1.17.1)
# Requirement already satisfied: pycparser in /home/magalylica/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from cffi>=1.14->cryptography>=3.4->jwcrypto<2.0.0,>=1.4->fief-client[cli]->codecarbon) (2.22)
# Requirement already satisfied: numpy>=1.23.2 in /home/magalylica/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from pandas->codecarbon) (2.1.2)
# Requirement already satisfied: pytz>=2020.1 in /home/magalylica/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from pandas->codecarbon) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/magalylica/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from pandas->codecarbon) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/magalylica/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from pydantic->codecarbon) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /home/magalylica/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from pydantic->codecarbon) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/magalylica/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from pydantic->codecarbon) (0.4.1)
# Requirement already satisfied: nvidia-ml-py<13.0.0a0,>=12.0.0 in /home/magalylica/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from pynvml->codecarbon) (12.575.51)
# Requirement already satisfied: prompt_toolkit<4.0,>=2.0 in /home/magalylica/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from questionary->codecarbon) (3.0.52)
# Requirement already satisfied: wcwidth in /home/magalylica/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from prompt_toolkit<4.0,>=2.0->questionary->codecarbon) (0.2.13)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/magalylica/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from requests->codecarbon) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/magalylica/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from requests->codecarbon) (2.5.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/magalylica/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from rich->codecarbon) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/magalylica/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from rich->codecarbon) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /home/magalylica/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->codecarbon) (0.1.2)
# Requirement already satisfied: shellingham>=1.3.0 in /home/magalylica/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from typer->codecarbon) (1.5.4)
# Requirement already satisfied: termcolor<2.4.0,>=2.2.0 in /home/magalylica/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from yaspin->fief-client[cli]->codecarbon) (2.3.0)

# %%
import os
import pandas as pd
import torch
from datasets import Dataset
from transformers import (
    AutoTokenizer, AutoModelForCausalLM,
)

import pickle
import numpy as np

# %%
# ------------------
# Configurações
# ------------------
# MODEL_NAME = "meta-llama/Meta-Llama-3-8B"
MODEL_NAME = 'Qwen/Qwen3-14B-Base'
SEED = 42
LABELS = ["BAIXA", "MÉDIA", "ALTA"]

torch.manual_seed(SEED)
os.environ["TOKENIZERS_PARALLELISM"] = "false"
# torch.utils.checkpoint.use_reentrant = False

# ------------------
# Prompt
# ------------------
PROMPT_TMPL = """You are a thematic relevance evaluator.
Classify how related an academic work (title and abstract) is to a strategic theme.

TITLE: {title}
KEYWORDS: {keywords}
ABSTRACT: {abstract}

Answer with a number 0, 1, or 2 for RELEVANCE LEVEL (2-HIGH, 1-MEDIUM, 0-LOW) to the strategic theme: "{category}".

GENERAL CRITERIA:
- HIGH: the topic is central to the research; strong semantic coherence.
- MEDIUM: partial/indirect or secondary relation to the topic.
- LOW: weak or tangential relation; the topic is not the main focus of the work.

ANSWER: """

# %%
with open("my_data.pickle", "rb") as file:
    split_train = pickle.load(file)
    split_eval = pickle.load(file)
    split_test = pickle.load(file)

# %%
print( len(split_train) , len(split_eval), len(split_test) )
# Out:
# 33620 4203 4203

# %%
# ------------------
# Tokenizer
# ------------------
tok = AutoTokenizer.from_pretrained(MODEL_NAME)
if tok.pad_token is None:
    tok.pad_token = tok.eos_token

# %%
torch.cuda.empty_cache()
torch.cuda.reset_peak_memory_stats()
memory_before = torch.cuda.memory_allocated()
print(f"Memória usada antes de carregar modelo: {memory_before/1024**2:.2f} MB")
# Out:
# Memória usada antes de carregar modelo: 0.00 MB

# %%
model = AutoModelForCausalLM.from_pretrained(
    MODEL_NAME,
    device_map="auto",
    trust_remote_code=True,
    # quantization_config=bnb_config
)
# model = prepare_model_for_kbit_training(raw_model)

print( 'Model loaded in ', model.device)
# Out:
# Loading checkpoint shards:   0%|          | 0/8 [00:00<?, ?it/s]
# Some parameters are on the meta device because they were offloaded to the cpu.
# Model loaded in  cuda:0

# %%
# Após um batch ou epoch
memory_after = torch.cuda.memory_allocated()
print(f"Memória atualmente alocada: {torch.cuda.memory_allocated()/1024**2:.2f} MB")
print(f"Máxima memória usada até agora: {torch.cuda.max_memory_allocated()/1024**2:.2f} MB")
print(f"Memória usada pelo modelo: {(memory_after-memory_before)/1024**2:.2f} MB")
# Out:
# Memória atualmente alocada: 18087.98 MB
# Máxima memória usada até agora: 18087.98 MB
# Memória usada pelo modelo: 18087.98 MB

# %%
import torch

if torch.cuda.is_available():
    print("Dispositivo:", torch.cuda.get_device_name(0))
    print("Suporta bf16?", torch.cuda.is_bf16_supported())
else:
    print("Nenhuma GPU disponível")
# Out:
# Dispositivo: NVIDIA RTX A5000
# Suporta bf16? True

# %%
from collections import Counter

# pega todos os rótulos
labels = split_test["modelo_nivel"]

# conta quantos de cada
contagem = Counter(labels)

# imprime
for k, v in contagem.items():
    print(f"{k}: {v}")

class_counts = [contagem[x.replace('É','E')] for x in LABELS]
print("Contagem de rótulos:", class_counts)
# Out:
# MEDIA: 1284
# BAIXA: 2056
# ALTA: 863
# Contagem de rótulos: [2056, 1284, 863]

# %%
model.device
# Out:
# device(type='cuda', index=0)

# %%
# ------------------
# Predict (next token)
# ------------------
import torch
import torch.nn.functional as F

# tokens de interesse
target_tokens = [tok.encode("0", add_special_tokens=False)[0], tok.encode("1", add_special_tokens=False)[0], tok.encode("2", add_special_tokens=False)[0]]

def predict_class(prompt_text):
    # tokeniza
    tokenized = tok(prompt_text, return_tensors="pt")
    input_ids = tokenized.input_ids.cuda()
    attention_mask = tokenized.attention_mask.cuda()

    # forward no modelo (sem generate)
    with torch.no_grad():
        outputs = model(input_ids=input_ids, attention_mask=attention_mask)
        # logits do último token
        last_token_logits = outputs.logits[0, -1, :]
        # softmax para probabilidades
        probs = F.softmax(last_token_logits, dim=-1)

    # pegar probabilidades apenas para os tokens 0,1,2
    target_probs = {tok.decode([t]): probs[t].item() for t in target_tokens}

    # escolher token mais provável
    pred_token = max(target_probs, key=target_probs.get)

    return pred_token, target_probs


# Exemplo
example = split_test[0]
processed_key_words = '\n- '.join(example["descricao_keyword"].split(';'))

    # Cria prompt
example_prompt = PROMPT_TMPL.format(
        title=example["nome_producao"],
        abstract=example["descricao_abstract"],
        keywords=processed_key_words,
        category=example["tema"]
    )
print("Predicted class:", predict_class(example_prompt))
# Out:
# Predicted class: ('1', {'0': 0.054772380739450455, '1': 0.680815577507019, '2': 0.22283849120140076})

# %%
np.mean([len(x) for x in split_test['descricao_abstract']])
len([len(x) for x in split_test['descricao_abstract'] if len(x) > 5000])
# Out:
# 23

# %%
from sklearn.metrics import accuracy_score, f1_score, classification_report
from tqdm import tqdm
from codecarbon import EmissionsTracker # para calcular emissões de CO2
import time
tracker = EmissionsTracker( output_file='sem_fine_tuning_emissions.csv' )
tracker.start()

y_true = []
y_pred = []

start_time = time.time()

torch.cuda.empty_cache()
torch.cuda.reset_peak_memory_stats()
memory_before = torch.cuda.memory_allocated()
print(f"Memória usada antes: {torch.cuda.memory_allocated()/1024**2:.2f} MB")


max_description=5000

# .select(range(30))

for example in tqdm(split_test.select(range(100)), desc="Inferindo"):  # percorre todo o dataset de teste
    # ---------------------
    # Prepara prompt
    processed_key_words = '\n- '.join(example["descricao_keyword"].split(';'))
    example_prompt = PROMPT_TMPL.format(
        title=example["nome_producao"],
        abstract=example["descricao_abstract"][:max_description],
        keywords=processed_key_words,
        category=example["tema"]
    )

    # Predição
    pred = predict_class(example_prompt)
    y_pred.append(["0","1","2"].index(pred[0]))

    # Rótulo real
    gold = str(example["modelo_nivel"]).strip().upper()
    if gold == "MEDIA":
        gold = "MÉDIA"
    assert gold in LABELS
    y_true.append(LABELS.index(gold))

memory_after = torch.cuda.memory_allocated()
print(f"Memória atualmente alocada: {torch.cuda.memory_allocated()/1024**2:.2f} MB")
print(f"Máxima memória usada até agora: {torch.cuda.max_memory_allocated()/1024**2:.2f} MB")
print(f"Memória usada no treinamento: {(memory_after-memory_before)/1024**2:.2f} MB")

# Marca o tempo final
end_time = time.time()

# Tempo total em segundos
elapsed_time = end_time - start_time
print(f"\nTempo total de execução: {elapsed_time:.2f} segundos")


emissions: float = tracker.stop()
print("\n\nTotal de emissões (detalhes em emissions.csv): ",emissions)

# ---------------------
# Métricas
acc = accuracy_score(y_true, y_pred)
f1_macro = f1_score(y_true, y_pred, average="macro")
f1_weighted = f1_score(y_true, y_pred, average="weighted")

print("Acurácia:", acc)
print("F1-macro:", f1_macro)
print("F1-weighted:", f1_weighted)

# Relatório detalhado (por classe)
print("\nRelatório de classificação:")
print(classification_report(y_true, y_pred, target_names=LABELS))
# Out:
# [codecarbon WARNING @ 14:53:56] Multiple instances of codecarbon are allowed to run at the same time.
# [codecarbon INFO @ 14:53:56] [setup] RAM Tracking...
# [codecarbon INFO @ 14:53:56] [setup] CPU Tracking...
# [codecarbon WARNING @ 14:53:57] We saw that you have a Intel(R) Core(TM) i9-14900KF but we don't know it. Please contact us.
# [codecarbon WARNING @ 14:53:57] We will use the default power consumption of 4 W per thread for your 32 CPU, so 128W.
# [codecarbon WARNING @ 14:53:57] No CPU tracking mode found. Falling back on estimation based on TDP for CPU.
#  Linux OS detected: Please ensure RAPL files exist at /sys/class/powercap/intel-rapl/subsystem to measure CPU
#
# [codecarbon INFO @ 14:53:57] CPU Model on constant consumption mode: Intel(R) Core(TM) i9-14900KF
# [codecarbon WARNING @ 14:53:57] No CPU tracking mode found. Falling back on CPU load mode.
# [codecarbon INFO @ 14:53:57] [setup] GPU Tracking...
# [codecarbon INFO @ 14:53:57] Tracking Nvidia GPU via pynvml
# [codecarbon INFO @ 14:53:57] The below tracking methods have been set up:
#                 RAM Tracking Method: RAM power estimation model
#                 CPU Tracking Method: cpu_load
#                 GPU Tracking Method: pynvml
#
# [codecarbon INFO @ 14:53:57] >>> Tracker's metadata:
# [codecarbon INFO @ 14:53:57]   Platform system: Linux-6.14.0-29-generic-x86_64-with-glibc2.39
# [codecarbon INFO @ 14:53:57]   Python version: 3.11.5
# [codecarbon INFO @ 14:53:57]   CodeCarbon version: 3.0.4
# [codecarbon INFO @ 14:53:57]   Available RAM : 125.634 GB
# [codecarbon INFO @ 14:53:57]   CPU count: 32 thread(s) in 1 physical CPU(s)
# [codecarbon INFO @ 14:53:57]   CPU model: Intel(R) Core(TM) i9-14900KF
# [codecarbon INFO @ 14:53:57]   GPU count: 1
# [codecarbon INFO @ 14:53:57]   GPU model: 1 x NVIDIA RTX A5000
# [codecarbon INFO @ 14:54:00] Emissions data (if any) will be saved to file /exp/magalylica/experimentos/challenge_bonito/challenge_bonito/sem_fine_tuning_emissions.csv
# Memória usada antes: 18096.11 MB
# Inferindo:   2%|▏         | 2/100 [00:12<09:45,  5.97s/it][codecarbon INFO @ 14:54:16] Energy consumed for RAM : 0.000164 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 14:54:16] Delta energy consumed for CPU with cpu_load : 0.000055 kWh, power : 12.812110952960007 W
# [codecarbon INFO @ 14:54:16] Energy consumed for All CPU : 0.000055 kWh
# [codecarbon INFO @ 14:54:16] Energy consumed for all GPUs : 0.000669 kWh. Total GPU Power : 150.43673090483685 W
# [codecarbon INFO @ 14:54:16] 0.000888 kWh of electricity used since the beginning.
# Inferindo:   4%|▍         | 4/100 [00:24<09:55,  6.20s/it][codecarbon INFO @ 14:54:31] Energy consumed for RAM : 0.000317 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 14:54:31] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.817127676800002 W
# [codecarbon INFO @ 14:54:31] Energy consumed for All CPU : 0.000107 kWh
# [codecarbon INFO @ 14:54:31] Energy consumed for all GPUs : 0.001314 kWh. Total GPU Power : 154.98197573858445 W
# [codecarbon INFO @ 14:54:31] 0.001738 kWh of electricity used since the beginning.
# Inferindo:   7%|▋         | 7/100 [00:42<09:16,  5.98s/it][codecarbon INFO @ 14:54:46] Energy consumed for RAM : 0.000470 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 14:54:46] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.807681096800001 W
# [codecarbon INFO @ 14:54:46] Energy consumed for All CPU : 0.000158 kWh
# [codecarbon INFO @ 14:54:46] Energy consumed for all GPUs : 0.001980 kWh. Total GPU Power : 159.81166577382686 W
# [codecarbon INFO @ 14:54:46] 0.002608 kWh of electricity used since the beginning.
# Inferindo:   9%|▉         | 9/100 [00:56<10:00,  6.60s/it][codecarbon INFO @ 14:55:01] Energy consumed for RAM : 0.000623 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 14
kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 15:01:46] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.814695257600002 W
# [codecarbon INFO @ 15:01:46] Energy consumed for All CPU : 0.001603 kWh
# [codecarbon INFO @ 15:01:46] Energy consumed for all GPUs : 0.020979 kWh. Total GPU Power : 165.6202509179468 W
# [codecarbon INFO @ 15:01:46] 0.027336 kWh of electricity used since the beginning.
# Inferindo:  78%|███████▊  | 78/100 [07:57<02:25,  6.61s/it][codecarbon INFO @ 15:02:01] Energy consumed for RAM : 0.004907 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 15:02:01] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.808916235200002 W
# [codecarbon INFO @ 15:02:01] Energy consumed for All CPU : 0.001654 kWh
# [codecarbon INFO @ 15:02:01] Energy consumed for all GPUs : 0.021665 kWh. Total GPU Power : 164.72043950511141 W
# [codecarbon INFO @ 15:02:01] 0.028227 kWh of electricity used since the beginning.
# [codecarbon INFO @ 15:02:01] 0.005825 g.CO2eq/s mean an estimation of 183.70883694450137 kg.CO2eq/year
# Inferindo:  80%|████████  | 80/100 [08:09<02:06,  6.34s/it][codecarbon INFO @ 15:02:16] Energy consumed for RAM : 0.005060 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 15:02:16] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.815939108000002 W
# [codecarbon INFO @ 15:02:16] Energy consumed for All CPU : 0.001706 kWh
# [codecarbon INFO @ 15:02:16] Energy consumed for all GPUs : 0.022345 kWh. Total GPU Power : 163.25668623478126 W
# [codecarbon INFO @ 15:02:16] 0.029112 kWh of electricity used since the beginning.
# Inferindo:  82%|████████▏ | 82/100 [08:25<02:07,  7.08s/it][codecarbon INFO @ 15:02:31] Energy consumed for RAM : 0.005213 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 15:02:31] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.821167222400002 W
# [codecarbon INFO @ 15:02:31] Energy consumed for All CPU : 0.001758 kWh
# [codecarbon INFO @ 15:02:31] Energy consumed for all GPUs : 0.023039 kWh. Total GPU Power : 166.52288074235915 W
# [codecarbon INFO @ 15:02:31] 0.030010 kWh of electricity used since the beginning.
# Inferindo:  85%|████████▌ | 85/100 [08:44<01:37,  6.52s/it][codecarbon INFO @ 15:02:46] Energy consumed for RAM : 0.005366 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 15:02:46] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.809297504 W
# [codecarbon INFO @ 15:02:46] Energy consumed for All CPU : 0.001809 kWh
# [codecarbon INFO @ 15:02:46] Energy consumed for all GPUs : 0.023729 kWh. Total GPU Power : 165.62481315069417 W
# [codecarbon INFO @ 15:02:46] 0.030905 kWh of electricity used since the beginning.
# Inferindo:  87%|████████▋ | 87/100 [08:57<01:26,  6.64s/it][codecarbon INFO @ 15:03:01] Energy consumed for RAM : 0.005519 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 15:03:01] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.8170178336 W
# [codecarbon INFO @ 15:03:01] Energy consumed for All CPU : 0.001861 kWh
# [codecarbon INFO @ 15:03:01] Energy consumed for all GPUs : 0.024416 kWh. Total GPU Power : 164.87675187457654 W
# [codecarbon INFO @ 15:03:01] 0.031796 kWh of electricity used since the beginning.
# Inferindo:  89%|████████▉ | 89/100 [09:10<01:10,  6.41s/it][codecarbon INFO @ 15:03:16] Energy consumed for RAM : 0.005672 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 15:03:16] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.822259887200003 W
# [codecarbon INFO @ 15:03:16] Energy consumed for All CPU : 0.001912 kWh
# [codecarbon INFO @ 15:03:16] Energy consumed for all GPUs : 0.025097 kWh. Total GPU Power : 163.30702177642124 W
# [codecarbon INFO @ 15:03:16] 0.032682 kWh of electricity used since the beginning.
# Inferindo:  91%|█████████ | 91/100 [09:24<01:00,  6.73s/it][codecarbon INFO @ 15:03:31] Energy consumed for RAM : 0.005825 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 15:03:31] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.815952485600002 W
# [codecarbon INFO @ 15:03:31] Energy consumed for All CPU : 0.001964 kWh
# [codecarbon INFO @ 15:03:31] Energy consumed for all GPUs : 0.025789 kWh. Total GPU Power : 166.03628308786665 W
# [codecarbon INFO @ 15:03:31] 0.033578 kWh of electricity used since the beginning.
# Inferindo:  94%|█████████▍| 94/100 [09:44<00:40,  6.79s/it][codecarbon INFO @ 15:03:46] Energy consumed for RAM : 0.005978 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 15:03:46] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.811652552000002 W
# [codecarbon INFO @ 15:03:46] Energy consumed for All CPU : 0.002016 kWh
# [codecarbon INFO @ 15:03:46] Energy consumed for all GPUs : 0.026486 kWh. Total GPU Power : 167.4599431416649 W
# [codecarbon INFO @ 15:03:46] 0.034480 kWh of electricity used since the beginning.
# Inferindo:  96%|█████████▌| 96/100 [09:56<00:25,  6.31s/it][codecarbon INFO @ 15:04:01] Energy consumed for RAM : 0.006131 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 15:04:01] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.821997101600001 W
# [codecarbon INFO @ 15:04:01] Energy consumed for All CPU : 0.002067 kWh
# [codecarbon INFO @ 15:04:01] Energy consumed for all GPUs : 0.027147 kWh. Total GPU Power : 158.59526043259982 W
# [codecarbon INFO @ 15:04:01] 0.035346 kWh of electricity used since the beginning.
# [codecarbon INFO @ 15:04:01] 0.005834 g.CO2eq/s mean an estimation of 183.98058239792113 kg.CO2eq/year
# Inferindo:  99%|█████████▉| 99/100 [10:13<00:05,  5.82s/it][codecarbon INFO @ 15:04:16] Energy consumed for RAM : 0.006284 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 15:04:16] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.8178330032 W
# [codecarbon INFO @ 15:04:16] Energy consumed for All CPU : 0.002119 kWh
# [codecarbon INFO @ 15:04:16] Energy consumed for all GPUs : 0.027825 kWh. Total GPU Power : 162.73959205519853 W
# [codecarbon INFO @ 15:04:16] 0.036228 kWh of electricity used since the beginning.
# Inferindo: 100%|██████████| 100/100 [10:22<00:00,  6.22s/it]
# [codecarbon INFO @ 15:04:23] Energy consumed for RAM : 0.006356 kWh. RAM Power : 38.0 W
# Memória atualmente alocada: 18096.11 MB
# Máxima memória usada até agora: 22534.59 MB
# Memória usada no treinamento: 0.00 MB
#
# Tempo total de execução: 622.28 segundos
# [codecarbon INFO @ 15:04:23] Delta energy consumed for CPU with cpu_load : 0.000024 kWh, power : 12.8068105808 W
# [codecarbon INFO @ 15:04:23] Energy consumed for All CPU : 0.002143 kWh
# [codecarbon INFO @ 15:04:23] Energy consumed for all GPUs : 0.028143 kWh. Total GPU Power : 157.5355158694394 W
# [codecarbon INFO @ 15:04:23] 0.036641 kWh of electricity used since the beginning.
# Total de emissões (detalhes em emissions.csv):  0.003603576517339924
# Acurácia: 0.38
# F1-macro: 0.30620155038759694
# F1-weighted: 0.2819767441860465
#
# Relatório de classificação:
#               precision    recall  f1-score   support
#
#        BAIXA       0.00      0.00      0.00        41
#        MÉDIA       0.40      0.67      0.50        43
#         ALTA       0.33      0.56      0.42        16
#
#     accuracy                           0.38       100
#    macro avg       0.24      0.41      0.31       100
# weighted avg       0.22      0.38      0.28       100
# /home/magalylica/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /home/magalylica/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /home/magalylica/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
