# %%
# !pip install codecarbon # reiniciar apos instalar este pacote se você estiver em um notebook
# Out:
# Requirement already satisfied: codecarbon in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (3.0.4)
# Requirement already satisfied: arrow in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from codecarbon) (1.3.0)
# Requirement already satisfied: click in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from codecarbon) (8.2.1)
# Requirement already satisfied: fief-client[cli] in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from codecarbon) (0.20.0)
# Requirement already satisfied: pandas in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from codecarbon) (2.2.3)
# Requirement already satisfied: prometheus_client in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from codecarbon) (0.22.1)
# Requirement already satisfied: psutil>=6.0.0 in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from codecarbon) (7.0.0)
# Requirement already satisfied: py-cpuinfo in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from codecarbon) (9.0.0)
# Requirement already satisfied: pydantic in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from codecarbon) (2.11.7)
# Requirement already satisfied: pynvml in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from codecarbon) (12.0.0)
# Requirement already satisfied: rapidfuzz in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from codecarbon) (3.13.0)
# Requirement already satisfied: requests in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from codecarbon) (2.32.4)
# Requirement already satisfied: questionary in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from codecarbon) (2.1.0)
# Requirement already satisfied: rich in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from codecarbon) (14.1.0)
# Requirement already satisfied: typer in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from codecarbon) (0.16.0)
# Requirement already satisfied: python-dateutil>=2.7.0 in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from arrow->codecarbon) (2.9.0.post0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from arrow->codecarbon) (2.9.0.20250809)
# Requirement already satisfied: six>=1.5 in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from python-dateutil>=2.7.0->arrow->codecarbon) (1.17.0)
# Requirement already satisfied: httpx<0.28.0,>=0.21.3 in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from fief-client[cli]->codecarbon) (0.27.2)
# Requirement already satisfied: jwcrypto<2.0.0,>=1.4 in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from fief-client[cli]->codecarbon) (1.5.6)
# Requirement already satisfied: yaspin in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from fief-client[cli]->codecarbon) (3.1.0)
# Requirement already satisfied: anyio in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from httpx<0.28.0,>=0.21.3->fief-client[cli]->codecarbon) (4.10.0)
# Requirement already satisfied: certifi in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from httpx<0.28.0,>=0.21.3->fief-client[cli]->codecarbon) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from httpx<0.28.0,>=0.21.3->fief-client[cli]->codecarbon) (1.0.9)
# Requirement already satisfied: idna in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from httpx<0.28.0,>=0.21.3->fief-client[cli]->codecarbon) (3.10)
# Requirement already satisfied: sniffio in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from httpx<0.28.0,>=0.21.3->fief-client[cli]->codecarbon) (1.3.1)
# Requirement already satisfied: h11>=0.16 in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from httpcore==1.*->httpx<0.28.0,>=0.21.3->fief-client[cli]->codecarbon) (0.16.0)
# Requirement already satisfied: cryptography>=3.4 in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from jwcrypto<2.0.0,>=1.4->fief-client[cli]->codecarbon) (45.0.6)
# Requirement already satisfied: typing-extensions>=4.5.0 in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from jwcrypto<2.0.0,>=1.4->fief-client[cli]->codecarbon) (4.12.2)
# Requirement already satisfied: cffi>=1.14 in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from cryptography>=3.4->jwcrypto<2.0.0,>=1.4->fief-client[cli]->codecarbon) (1.17.1)
# Requirement already satisfied: pycparser in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from cffi>=1.14->cryptography>=3.4->jwcrypto<2.0.0,>=1.4->fief-client[cli]->codecarbon) (2.22)
# Requirement already satisfied: numpy>=1.23.2 in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from pandas->codecarbon) (2.1.2)
# Requirement already satisfied: pytz>=2020.1 in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from pandas->codecarbon) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from pandas->codecarbon) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from pydantic->codecarbon) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from pydantic->codecarbon) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from pydantic->codecarbon) (0.4.1)
# Requirement already satisfied: nvidia-ml-py<13.0.0a0,>=12.0.0 in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from pynvml->codecarbon) (12.575.51)
# Requirement already satisfied: prompt_toolkit<4.0,>=2.0 in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from questionary->codecarbon) (3.0.51)
# Requirement already satisfied: wcwidth in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from prompt_toolkit<4.0,>=2.0->questionary->codecarbon) (0.2.13)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from requests->codecarbon) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from requests->codecarbon) (2.5.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from rich->codecarbon) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from rich->codecarbon) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->codecarbon) (0.1.2)
# Requirement already satisfied: shellingham>=1.3.0 in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from typer->codecarbon) (1.5.4)
# Requirement already satisfied: termcolor<2.4.0,>=2.2.0 in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from yaspin->fief-client[cli]->codecarbon) (2.3.0)

# %%
import os
import pandas as pd
import torch
from datasets import Dataset
from transformers import (
    AutoTokenizer, AutoModelForCausalLM,
    BitsAndBytesConfig, Trainer, TrainingArguments,
    DataCollatorForLanguageModeling, EarlyStoppingCallback,
    DataCollatorForSeq2Seq
)
from peft import LoraConfig, get_peft_model, prepare_model_for_kbit_training

from peft import PeftModel
import pickle
import time

# %%
# ------------------
# Configurações
# ------------------
# MODEL_NAME = "meta-llama/Meta-Llama-3-8B"
MODEL_NAME = 'Qwen/Qwen3-14B-Base'
OUTPUT_DIR = "./qlora-aderencia-classes.balanced"
SEED = 42
LABELS = ["BAIXA", "MÉDIA", "ALTA"]

torch.manual_seed(SEED)
os.environ["TOKENIZERS_PARALLELISM"] = "false"
torch.utils.checkpoint.use_reentrant = False

# ------------------
# Prompt
# ------------------
PROMPT_TMPL = """You are a thematic relevance evaluator.
Classify how related an academic work (title and abstract) is to a strategic theme.

TITLE: {title}
KEYWORDS: {keywords}
ABSTRACT: {abstract}

Answer with a number 0, 1, or 2 for RELEVANCE LEVEL (2-HIGH, 1-MEDIUM, 0-LOW) to the strategic theme: "{category}".

GENERAL CRITERIA:
- HIGH: the topic is central to the research; strong semantic coherence.
- MEDIUM: partial/indirect or secondary relation to the topic.
- LOW: weak or tangential relation; the topic is not the main focus of the work.

ANSWER: """

# %%
with open("my_data.pickle", "rb") as file:
    split_train = pickle.load(file)
    split_eval = pickle.load(file)
    split_test = pickle.load(file)

# %%
print( len(split_train) , len(split_eval), len(split_test) )
# Out:
# 33620 4203 4203

# %%
# ------------------
# Tokenizer
# ------------------
tok = AutoTokenizer.from_pretrained(MODEL_NAME)
if tok.pad_token is None:
    tok.pad_token = tok.eos_token



# ------------------
# Função de preprocessamento
# ------------------
def preprocess(example, max_input_length=1024, max_description=512):
    processed_key_words = '\n- '.join(example["descricao_keyword"].split(';'))
    gold = str(example["modelo_nivel"]).strip().upper()
    if gold == "MEDIA":
        gold = "MÉDIA"
    assert gold in LABELS
    gold_idx = LABELS.index(gold)  # 0,1,2

    # Cria prompt
    prompt = PROMPT_TMPL.format(
        title=example["nome_producao"],
        abstract=example["descricao_abstract"][:max_description],
        keywords=processed_key_words,
        category=example["tema"]
    )

    # Tokeniza prompt
    input_enc = tok(prompt, truncation=True, max_length=max_input_length, add_special_tokens=False)
    input_ids = input_enc["input_ids"]

    # Token do próximo token (classe)
    label_id = tok(str(gold_idx), add_special_tokens=False)["input_ids"][0]

    if label_id not in [15, 16, 17]:
        print( label_id )

    # labels: -100 no prompt, token da classe no final
    labels = [-100] * len(input_ids) + [label_id]
    input_ids_full = input_ids + [label_id]
    attention_mask = [1] * len(input_ids_full)
    # labels = [label_id]
    # attention_mask = [1] * len(input_ids)

    if example["modelo_nivel"].replace('E','É') not in LABELS:
        print("ERRO:", example["modelo_nivel"], "->", gold, "(", label_id, ")")
        print("PROMPT:", prompt)
        print("INPUT_IDS:", input_ids)
        print("LABELS:", labels)
        # raise ValueError("Label inválida")

    return {
        "input_ids": input_ids_full,
        "attention_mask": attention_mask,
        "labels": labels
    }

# ------------------
# Criação do Dataset
# ------------------
train_ds = split_train.map(preprocess, batched=False, remove_columns=split_train.column_names)
eval_ds = split_eval.map(preprocess, batched=False, remove_columns=split_eval.column_names)
# Out:
# Map:   0%|          | 0/33620 [00:00<?, ? examples/s]
# Map:   0%|          | 0/4203 [00:00<?, ? examples/s]

# %%
for i in range(len(train_ds)):
    if train_ds['labels'][i][-1] not in [15,16,17]:
        print(i)
        print(train_ds['labels'][i][-1])

# %%
# ------------------
# Modelo base com quantização 4-bit
# ------------------
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.bfloat16 if torch.cuda.is_available() else torch.float32,
)

raw_model = AutoModelForCausalLM.from_pretrained(
    MODEL_NAME,
    device_map="auto",
    trust_remote_code=True,
    quantization_config=bnb_config
)
raw_model = prepare_model_for_kbit_training(raw_model)

print( 'Model loaded in ', raw_model.device)
# Out:
# Loading checkpoint shards:   0%|          | 0/8 [00:00<?, ?it/s]
# Model loaded in  cuda:0

# %%
for name, module in raw_model.named_modules():
    print(name)
# Out:
# model
# model.embed_tokens
# model.layers
# model.layers.0
# model.layers.0.self_attn
# model.layers.0.self_attn.q_proj
# model.layers.0.self_attn.k_proj
# model.layers.0.self_attn.v_proj
# model.layers.0.self_attn.o_proj
# model.layers.0.self_attn.q_norm
# model.layers.0.self_attn.k_norm
# model.layers.0.mlp
# model.layers.0.mlp.gate_proj
# model.layers.0.mlp.up_proj
# model.layers.0.mlp.down_proj
# model.layers.0.mlp.act_fn
# model.layers.0.input_layernorm
# model.layers.0.post_attention_layernorm
# model.layers.1
# model.layers.1.self_attn
# model.layers.1.self_attn.q_proj
# model.layers.1.self_attn.k_proj
# model.layers.1.self_attn.v_proj
# model.layers.1.self_attn.o_proj
# model.layers.1.self_attn.q_norm
# model.layers.1.self_attn.k_norm
# model.layers.1.mlp
# model.layers.1.mlp.gate_proj
# model.layers.1.mlp.up_proj
# model.layers.1.mlp.down_proj
# model.layers.1.mlp.act_fn
# model.layers.1.input_layernorm
# model.layers.1.post_attention_layernorm
# model.layers.2
# model.layers.2.self_attn
# model.layers.2.self_attn.q_proj
# model.layers.2.self_attn.k_proj
# model.layers.2.self_attn.v_proj
# model.layers.2.self_attn.o_proj
# model.layers.2.self_attn.q_norm
# model.layers.2.self_attn.k_norm
# model.layers.2.mlp
# model.layers.2.mlp.gate_proj
# model.layers.2.mlp.up_proj
# model.layers.2.mlp.down_proj
# model.layers.2.mlp.act_fn
# model.layers.2.input_layernorm
# model.layers.2.post_attention_layernorm
# model.layers.3
# model.layers.3.self_attn
# model.layers.3.self_attn.q_proj
# model.layers.3.self_attn.k_proj
# model.layers.3.self_attn.v_proj
# model.layers.3.self_attn.o_proj
# model.layers.3.self_attn.q_norm
# model.layers.3.self_attn.k_norm
# model.layers.3.mlp
# model.layers.3.mlp.gate_proj
# model.layers.3.mlp.up_proj
# model.layers.3.mlp.down_proj
# model.layers.3.mlp.act_fn
# model.layers.3.input_layernorm
# model.layers.3.post_attention_layernorm
# model.layers.4
# model.layers.4.self_attn
# model.layers.4.self_attn.q_proj
# model.layers.4.self_attn.k_proj
# model.layers.4.self_attn.v_proj
# model.layers.4.self_attn.o_proj
# model.layers.4.self_attn.q_norm
# model.layers.4.self_attn.k_norm
# model.layers.4.mlp
# model.layers.4.mlp.gate_proj
# model.layers.4.mlp.up_proj
# model.layers.4.mlp.down_proj
# model.layers.4.mlp.act_fn
# model.layers.4.input_layernorm
# model.layers.4.post_attention_layernorm
# model.layers.5
# model.layers.5.self_attn
# model.layers.5.self_attn.q_proj
# model.layers.5.self_attn.k_proj
# model.layers.5.self_attn.v_proj
# model.layers.5.self_attn.o_proj
# model.layers.5.self_attn.q_norm
# model.layers.5.self_attn.k_norm
# model.layers.5.mlp
# model.layers.5.mlp.gate_proj
# model.layers.5.mlp.up_proj
# model.layers.5.mlp.down_proj
# model.layers.5.mlp.act_fn
# model.layers.5.input_layernorm
# model.layers.5.post_attention_layernorm
# model.layers.6
# model.layers.6.self_attn
# model.layers.6.self_attn.q_proj
# model.layers.6.self_attn.k_proj
# model.layers.6.self_attn.v_proj
# model.layers.6.self_attn.o_proj
# model.layers.6.self_attn.q_norm
# model.layers.6.self_attn.k_norm
# model.layers.6.mlp
# model.layers.6.mlp.gate_proj
# model.layers.6.mlp.up_proj
# model.layers.6.mlp.down_proj
# model.layers.6.mlp.act_fn
# model.layers.6.input_layernorm
# model.layers.6.post_attention_layernorm
# model.layers.7
# model.layers.7.self_attn
# model.layers.7.self_attn.q_proj
# model.layers.7.self_attn.k_proj
# model.layers.7.self_attn.v_proj
# model.layers.7.self_attn.o_proj
# model.layers.7.self_attn.q_norm
# model.layers.7.self_attn.k_norm
# model.layers.7.mlp
# model.layers.7.mlp.gate_proj
# model.layers.7.mlp.up_proj
# model.layers.7.mlp.down_proj
# model.layers.7.mlp.act_fn
# model.layers.7.input_layernorm
# model.layers.7.post_attention_layernorm
# model.layers.8
# model.layers.8.self_attn
# model.layers.8.self_attn.q_proj
# model.layers.8.self_attn.k_proj
# model.layers.8.self_attn.v_proj
# model.layers.8.self_attn.o_proj
# model.layers.8.self_attn.q_norm
# model.layers.8.self_attn.k_norm
# model.layers.8.mlp
# model.layers.8.mlp.gate_proj
# model.layers.8.mlp.up_proj
# model.layers.8.mlp.down_proj
# model.layers.8.mlp.act_fn
# model.layers.8.input_layernorm
# model.layers.8.post_attention_layernorm
# model.layers.9
# model.layers.9.self_attn
# model.layers.9.self_attn.q_proj
# model.layers.9.self_attn.k_proj
# model.layers.9.self_attn.v_proj
# model.layers.9.self_attn.o_proj
# model.layers.9.self_attn.q_norm
# model.layers.9.self_attn.k_norm
# model.layers.9.mlp
# model.layers.9.mlp.gate_proj
# model.layers.9.mlp.up_proj
# model.layers.9.mlp.down_proj
# model.layers.9.mlp.act_fn
# model.layers.9.input_layernorm
# model.layers.9.post_attention_layernorm
# model.layers.10
# model.layers.10.self_attn
# model.layers.10.self_attn.q_proj
# model.layers.10.self_attn.k_proj
# model.layers.10.self_attn.v_proj
# model.layers.10.self_attn.o_proj
# model.layers.10.self_attn.q_norm
# model.layers.10.self_attn.k_norm
# model.layers.10.mlp
# model.layers.10.mlp.gate_proj
# model.layers.10.mlp.up_proj
# model.layers.10.mlp.down_proj
# model.layers.10.mlp.act_fn
# model.layers.10.input_layernorm
# model.layers.10.post_attention_layernorm
# model.layers.11
# model.layers.11.self_attn
# model.layers.11.self_attn.q_proj
# model.layers.11.self_attn.k_proj
# model.layers.11.self_attn.v_proj
# model.layers.11.self_attn.o_proj
# model.layers.11.self_attn.q_norm
# model.layers.11.self_attn.k_norm
# model.layers.11.mlp
# model.layers.11.mlp.gate_proj
# model.layers.11.mlp.up_proj
# model.layers.11.mlp.down_proj
# model.layers.11.mlp.act_fn
# model.layers.11.input_layernorm
# model.layers.11.post_attention_layernorm
# model.layers.12
# model.layers.12.self_attn
# model.layers.12.self_attn.q_proj
# model.layers.12.self_attn.k_proj
# model.layers.12.self_attn.v_proj
# model.layers.12.self_attn.o_proj
# model.layers.12.self_attn.q_norm
# model.layers.12.self_attn.k_norm
# model.layers.12.mlp
# model.layers.12.mlp.gate_proj
# model.layers.12.mlp.up_proj
# model.layers.12.mlp.down_proj
# model.layers.12.mlp.act_fn
# model.layers.12.input_layernorm
# model.layers.12.post_attention_layernorm
# model.layers.13
# model.layers.13.self_attn
# model.layers.13.self_attn.q_proj
# model.layers.13.self_attn.k_proj
# model.layers.13.self_attn.v_proj
# model.layers.13.self_attn.o_proj
# model.layers.13.self_attn.q_norm
# model.layers.13.self_attn.k_norm
# model.layers.13.mlp
# model.layers.13.mlp.gate_proj
# model.layers.13.mlp.up_proj
# model.layers.13.mlp.down_proj
# model.layers.13.mlp.act_fn
# model.layers.13.input_layernorm
# model.layers.13.post_attention_layernorm
# model.layers.14
# model.layers.14.self_attn
# model.layers.14.self_attn.q_proj
# model.layers.14.self_attn.k_proj
# model.layers.14.self_attn.v_proj
# model.layers.14.self_attn.o_proj
# model.layers.14.self_attn.q_norm
# model.layers.14.self_attn.k_norm
# model.layers.14.mlp
# model.layers.14.mlp.gate_proj
# model.layers.14.mlp.up_proj
# model.layers.14.mlp.down_proj
# model.layers.14.mlp.act_fn
# model.layers.14.input_layernorm
# model.layers.14.post_attention_layernorm
# model.layers.15
# model.layers.15.self_attn
# model.layers.15.self_attn.q_proj
# model.layers.15.self_attn.k_proj
# model.layers.15.self_attn.v_proj
# model.layers.15.self_attn.o_proj
# model.layers.15.self_attn.q_norm
# model.layers.15.self_attn.k_norm
# model.layers.15.mlp
# model.layers.15.mlp.gate_proj
# model.layers.15.mlp.up_proj
# model.layers.15.mlp.down_proj
# model.layers.15.mlp.act_fn
# model.layers.15.input_layernorm
# model.layers.15.post_attention_layernorm
# model.layers.16
# model.layers.16.self_attn
# model.layers.16.self_attn.q_proj
# model.layers.16.self_attn.k_proj
# model.layers.16.self_attn.v_proj
# model.layers.16.self_attn.o_proj
# model.layers.16.self_attn.q_norm
# model.layers.16.self_attn.k_norm
# model.layers.16.mlp
# model.layers.16.mlp.gate_proj
# model.layers.16.mlp.up_proj
# model.layers.16.mlp.down_proj
# model.layers.16.mlp.act_fn
# model.layers.16.input_layernorm
# model.layers.16.post_attention_layernorm
# model.layers.17
# model.layers.17.self_attn
# model.layers.17.self_attn.q_proj
# model.layers.17.self_attn.k_proj
# model.layers.17.self_attn.v_proj
# model.layers.17.self_attn.o_proj
# model.layers.17.self_attn.q_norm
# model.layers.17.self_attn.k_norm
# model.layers.17.mlp
# model.layers.17.mlp.gate_proj
# model.layers.17.mlp.up_proj
# model.layers.17.mlp.down_proj
# model.layers.17.mlp.act_fn
# model.layers.17.input_layernorm
# model.layers.17.post_attention_layernorm
# model.layers.18
# model.layers.18.self_attn
# model.layers.18.self_attn.q_proj
# model.layers.18.self_attn.k_proj
# model.layers.18.self_attn.v_proj
# model.layers.18.self_attn.o_proj
# model.layers.18.self_attn.q_norm
# model.layers.18.self_attn.k_norm
# model.layers.18.mlp
# model.layers.18.mlp.gate_proj
# model.layers.18.mlp.up_proj
# model.layers.18.mlp.down_proj
# model.layers.18.mlp.act_fn
# model.layers.18.input_layernorm
# model.layers.18.post_attention_layernorm
# model.layers.19
# model.layers.19.self_attn
# model.layers.19.self_attn.q_proj
# model.layers.19.self_attn.k_proj
# model.layers.19.self_attn.v_proj
# model.layers.19.self_attn.o_proj
# model.layers.19.self_attn.q_norm
# model.layers.19.self_attn.k_norm
# model.layers.19.mlp
# model.layers.19.mlp.gate_proj
# model.layers.19.mlp.up_proj
# model.layers.19.mlp.down_proj
# model.layers.19.mlp.act_fn
# model.layers.19.input_layernorm
# model.layers.19.post_attention_layernorm
# model.layers.20
# model.layers.20.self_attn
# model.layers.20.self_attn.q_proj
# model.layers.20.self_attn.k_proj
# model.layers.20.self_attn.v_proj
# model.layers.20.self_attn.o_proj
# model.layers.20.self_attn.q_norm
# model.layers.20.self_attn.k_norm
# model.layers.20.mlp
# model.layers.20.mlp.gate_proj
# model.layers.20.mlp.up_proj
# model.layers.20.mlp.down_proj
# model.layers.20.mlp.act_fn
# model.layers.20.input_layernorm
# model.layers.20.post_attention_layernorm
# model.layers.21
# model.layers.21.self_attn
# model.layers.21.self_attn.q_proj
# model.layers.21.self_attn.k_proj
# model.layers.21.self_attn.v_proj
# model.layers.21.self_attn.o_proj
# model.layers.21.self_attn.q_norm
# model.layers.21.self_attn.k_norm
# model.layers.21.mlp
# model.layers.21.mlp.gate_proj
# model.layers.21.mlp.up_proj
# model.layers.21.mlp.down_proj
# model.layers.21.mlp.act_fn
# model.layers.21.input_layernorm
# model.layers.21.post_attention_layernorm
# model.layers.22
# model.layers.22.self_attn
# model.layers.22.self_attn.q_proj
# model.layers.22.self_attn.k_proj
# model.layers.22.self_attn.v_proj
# model.layers.22.self_attn.o_proj
# model.layers.22.self_attn.q_norm
# model.layers.22.self_attn.k_norm
# model.layers.22.mlp
# model.layers.22.mlp.gate_proj
# model.layers.22.mlp.up_proj
# model.layers.22.mlp.down_proj
# model.layers.22.mlp.act_fn
# model.layers.22.input_layernorm
# model.layers.22.post_attention_layernorm
# model.layers.23
# model.layers.23.self_attn
# model.layers.23.self_attn.q_proj
# model.layers.23.self_attn.k_proj
# model.layers.23.self_attn.v_proj
# model.layers.23.self_attn.o_proj
# model.layers.23.self_attn.q_norm
# model.layers.23.self_attn.k_norm
# model.layers.23.mlp
# model.layers.23.mlp.gate_proj
# model.layers.23.mlp.up_proj
# model.layers.23.mlp.down_proj
# model.layers.23.mlp.act_fn
# model.layers.23.input_layernorm
# model.layers.23.post_attention_layernorm
# model.layers.24
# model.layers.24.self_attn
# model.layers.24.self_attn.q_proj
# model.layers.24.self_attn.k_proj
# model.layers.24.self_attn.v_proj
# model.layers.24.self_attn.o_proj
# model.layers.24.self_attn.q_norm
# model.layers.24.self_attn.k_norm
# model.layers.24.mlp
# model.layers.24.mlp.gate_proj
# model.layers.24.mlp.up_proj
# model.layers.24.mlp.down_proj
# model.layers.24.mlp.act_fn
# model.layers.24.input_layernorm
# model.layers.24.post_attention_layernorm
# model.layers.25
# model.layers.25.self_attn
# model.layers.25.self_attn.q_proj
# model.layers.25.self_attn.k_proj
# model.layers.25.self_attn.v_proj
# model.layers.25.self_attn.o_proj
# model.layers.25.self_attn.q_norm
# model.layers.25.self_attn.k_norm
# model.layers.25.mlp
# model.layers.25.mlp.gate_proj
# model.layers.25.mlp.up_proj
# model.layers.25.mlp.down_proj
# model.layers.25.mlp.act_fn
# model.layers.25.input_layernorm
# model.layers.25.post_attention_layernorm
# model.layers.26
# model.layers.26.self_attn
# model.layers.26.self_attn.q_proj
# model.layers.26.self_attn.k_proj
# model.layers.26.self_attn.v_proj
# model.layers.26.self_attn.o_proj
# model.layers.26.self_attn.q_norm
# model.layers.26.self_attn.k_norm
# model.layers.26.mlp
# model.layers.26.mlp.gate_proj
# model.layers.26.mlp.up_proj
# model.layers.26.mlp.down_proj
# model.layers.26.mlp.act_fn
# model.layers.26.input_layernorm
# model.layers.26.post_attention_layernorm
# model.layers.27
# model.layers.27.self_attn
# model.layers.27.self_attn.q_proj
# model.layers.27.self_attn.k_proj
# model.layers.27.self_attn.v_proj
# model.layers.27.self_attn.o_proj
# model.layers.27.self_attn.q_norm
# model.layers.27.self_attn.k_norm
# model.layers.27.mlp
# model.layers.27.mlp.gate_proj
# model.layers.27.mlp.up_proj
# model.layers.27.mlp.down_proj
# model.layers.27.mlp.act_fn
# model.layers.27.input_layernorm
# model.layers.27.post_attention_layernorm
# model.layers.28
# model.layers.28.self_attn
# model.layers.28.self_attn.q_proj
# model.layers.28.self_attn.k_proj
# model.layers.28.self_attn.v_proj
# model.layers.28.self_attn.o_proj
# model.layers.28.self_attn.q_norm
# model.layers.28.self_attn.k_norm
# model.layers.28.mlp
# model.layers.28.mlp.gate_proj
# model.layers.28.mlp.up_proj
# model.layers.28.mlp.down_proj
# model.layers.28.mlp.act_fn
# model.layers.28.input_layernorm
# model.layers.28.post_attention_layernorm
# model.layers.29
# model.layers.29.self_attn
# model.layers.29.self_attn.q_proj
# model.layers.29.self_attn.k_proj
# model.layers.29.self_attn.v_proj
# model.layers.29.self_attn.o_proj
# model.layers.29.self_attn.q_norm
# model.layers.29.self_attn.k_norm
# model.layers.29.mlp
# model.layers.29.mlp.gate_proj
# model.layers.29.mlp.up_proj
# model.layers.29.mlp.down_proj
# model.layers.29.mlp.act_fn
# model.layers.29.input_layernorm
# model.layers.29.post_attention_layernorm
# model.layers.30
# model.layers.30.self_attn
# model.layers.30.self_attn.q_proj
# model.layers.30.self_attn.k_proj
# model.layers.30.self_attn.v_proj
# model.layers.30.self_attn.o_proj
# model.layers.30.self_attn.q_norm
# model.layers.30.self_attn.k_norm
# model.layers.30.mlp
# model.layers.30.mlp.gate_proj
# model.layers.30.mlp.up_proj
# model.layers.30.mlp.down_proj
# model.layers.30.mlp.act_fn
# model.layers.30.input_layernorm
# model.layers.30.post_attention_layernorm
# model.layers.31
# model.layers.31.self_attn
# model.layers.31.self_attn.q_proj
# model.layers.31.self_attn.k_proj
# model.layers.31.self_attn.v_proj
# model.layers.31.self_attn.o_proj
# model.layers.31.self_attn.q_norm
# model.layers.31.self_attn.k_norm
# model.layers.31.mlp
# model.layers.31.mlp.gate_proj
# model.layers.31.mlp.up_proj
# model.layers.31.mlp.down_proj
# model.layers.31.mlp.act_fn
# model.layers.31.input_layernorm
# model.layers.31.post_attention_layernorm
# model.layers.32
# model.layers.32.self_attn
# model.layers.32.self_attn.q_proj
# model.layers.32.self_attn.k_proj
# model.layers.32.self_attn.v_proj
# model.layers.32.self_attn.o_proj
# model.layers.32.self_attn.q_norm
# model.layers.32.self_attn.k_norm
# model.layers.32.mlp
# model.layers.32.mlp.gate_proj
# model.layers.32.mlp.up_proj
# model.layers.32.mlp.down_proj
# model.layers.32.mlp.act_fn
# model.layers.32.input_layernorm
# model.layers.32.post_attention_layernorm
# model.layers.33
# model.layers.33.self_attn
# model.layers.33.self_attn.q_proj
# model.layers.33.self_attn.k_proj
# model.layers.33.self_attn.v_proj
# model.layers.33.self_attn.o_proj
# model.layers.33.self_attn.q_norm
# model.layers.33.self_attn.k_norm
# model.layers.33.mlp
# model.layers.33.mlp.gate_proj
# model.layers.33.mlp.up_proj
# model.layers.33.mlp.down_proj
# model.layers.33.mlp.act_fn
# model.layers.33.input_layernorm
# model.layers.33.post_attention_layernorm
# model.layers.34
# model.layers.34.self_attn
# model.layers.34.self_attn.q_proj
# model.layers.34.self_attn.k_proj
# model.layers.34.self_attn.v_proj
# model.layers.34.self_attn.o_proj
# model.layers.34.self_attn.q_norm
# model.layers.34.self_attn.k_norm
# model.layers.34.mlp
# model.layers.34.mlp.gate_proj
# model.layers.34.mlp.up_proj
# model.layers.34.mlp.down_proj
# model.layers.34.mlp.act_fn
# model.layers.34.input_layernorm
# model.layers.34.post_attention_layernorm
# model.layers.35
# model.layers.35.self_attn
# model.layers.35.self_attn.q_proj
# model.layers.35.self_attn.k_proj
# model.layers.35.self_attn.v_proj
# model.layers.35.self_attn.o_proj
# model.layers.35.self_attn.q_norm
# model.layers.35.self_attn.k_norm
# model.layers.35.mlp
# model.layers.35.mlp.gate_proj
# model.layers.35.mlp.up_proj
# model.layers.35.mlp.down_proj
# model.layers.35.mlp.act_fn
# model.layers.35.input_layernorm
# model.layers.35.post_attention_layernorm
# model.layers.36
# model.layers.36.self_attn
# model.layers.36.self_attn.q_proj
# model.layers.36.self_attn.k_proj
# model.layers.36.self_attn.v_proj
# model.layers.36.self_attn.o_proj
# model.layers.36.self_attn.q_norm
# model.layers.36.self_attn.k_norm
# model.layers.36.mlp
# model.layers.36.mlp.gate_proj
# model.layers.36.mlp.up_proj
# model.layers.36.mlp.down_proj
# model.layers.36.mlp.act_fn
# model.layers.36.input_layernorm
# model.layers.36.post_attention_layernorm
# model.layers.37
# model.layers.37.self_attn
# model.layers.37.self_attn.q_proj
# model.layers.37.self_attn.k_proj
# model.layers.37.self_attn.v_proj
# model.layers.37.self_attn.o_proj
# model.layers.37.self_attn.q_norm
# model.layers.37.self_attn.k_norm
# model.layers.37.mlp
# model.layers.37.mlp.gate_proj
# model.layers.37.mlp.up_proj
# model.layers.37.mlp.down_proj
# model.layers.37.mlp.act_fn
# model.layers.37.input_layernorm
# model.layers.37.post_attention_layernorm
# model.layers.38
# model.layers.38.self_attn
# model.layers.38.self_attn.q_proj
# model.layers.38.self_attn.k_proj
# model.layers.38.self_attn.v_proj
# model.layers.38.self_attn.o_proj
# model.layers.38.self_attn.q_norm
# model.layers.38.self_attn.k_norm
# model.layers.38.mlp
# model.layers.38.mlp.gate_proj
# model.layers.38.mlp.up_proj
# model.layers.38.mlp.down_proj
# model.layers.38.mlp.act_fn
# model.layers.38.input_layernorm
# model.layers.38.post_attention_layernorm
# model.layers.39
# model.layers.39.self_attn
# model.layers.39.self_attn.q_proj
# model.layers.39.self_attn.k_proj
# model.layers.39.self_attn.v_proj
# model.layers.39.self_attn.o_proj
# model.layers.39.self_attn.q_norm
# model.layers.39.self_attn.k_norm
# model.layers.39.mlp
# model.layers.39.mlp.gate_proj
# model.layers.39.mlp.up_proj
# model.layers.39.mlp.down_proj
# model.layers.39.mlp.act_fn
# model.layers.39.input_layernorm
# model.layers.39.post_attention_layernorm
# model.norm
# model.rotary_emb
# lm_head

# %%
# ------------------
# LoRA
# ------------------

# pegar nomes das últimas camadas
n_last = 4
num_total_layers = len(raw_model.model.layers)
target_modules = []
for i in range(num_total_layers - n_last, num_total_layers):
    for proj in ["q_proj", "k_proj", "v_proj", "o_proj"]:
        target_modules.append(f"model.layers.{i}.self_attn.{proj}")
    for proj in ["up_proj", "down_proj"]:  # se quiser também adaptar o MLP
        target_modules.append(f"model.layers.{i}.mlp.{proj}")
print( target_modules )
# Out:
# ['model.layers.36.self_attn.q_proj', 'model.layers.36.self_attn.k_proj', 'model.layers.36.self_attn.v_proj', 'model.layers.36.self_attn.o_proj', 'model.layers.36.mlp.up_proj', 'model.layers.36.mlp.down_proj', 'model.layers.37.self_attn.q_proj', 'model.layers.37.self_attn.k_proj', 'model.layers.37.self_attn.v_proj', 'model.layers.37.self_attn.o_proj', 'model.layers.37.mlp.up_proj', 'model.layers.37.mlp.down_proj', 'model.layers.38.self_attn.q_proj', 'model.layers.38.self_attn.k_proj', 'model.layers.38.self_attn.v_proj', 'model.layers.38.self_attn.o_proj', 'model.layers.38.mlp.up_proj', 'model.layers.38.mlp.down_proj', 'model.layers.39.self_attn.q_proj', 'model.layers.39.self_attn.k_proj', 'model.layers.39.self_attn.v_proj', 'model.layers.39.self_attn.o_proj', 'model.layers.39.mlp.up_proj', 'model.layers.39.mlp.down_proj']

# %%
lora_config = LoraConfig(
    r=16,
    lora_alpha=16,
    lora_dropout=0.05,
    bias="none",
    task_type="CAUSAL_LM",
    target_modules=target_modules
)
model = get_peft_model(raw_model, lora_config)

# %%
import torch

if torch.cuda.is_available():
    print("Dispositivo:", torch.cuda.get_device_name(0))
    print("Suporta bf16?", torch.cuda.is_bf16_supported())
else:
    print("Nenhuma GPU disponível")
# Out:
# Dispositivo: NVIDIA RTX A5000
# Suporta bf16? True

# %%
from collections import Counter

# pega todos os rótulos
labels = split_train["modelo_nivel"]

# conta quantos de cada
contagem = Counter(labels)

# imprime
for k, v in contagem.items():
    print(f"{k}: {v}")

class_counts = [contagem[x.replace('É','E')] for x in LABELS]
print("Contagem de rótulos:", class_counts)
# Out:
# MEDIA: 10369
# BAIXA: 16091
# ALTA: 7160
# Contagem de rótulos: [16091, 10369, 7160]

# %%
# IDs dos tokens "0","1","2"
id_0 = tok("0", add_special_tokens=False).input_ids[0]
id_1 = tok("1", add_special_tokens=False).input_ids[0]
id_2 = tok("2", add_special_tokens=False).input_ids[0]

vocab_size = model.config.vocab_size
weights = torch.zeros(vocab_size, device=model.device)

# inverso da frequência (ajustado para só 3 classes)
class_counts = torch.tensor(class_counts, dtype=torch.float, device=model.device)
class_weights = 1.0 / class_counts
class_weights = class_weights / class_weights.sum() * len(class_counts)

# coloca nos índices corretos do vocab
weights[id_0] = class_weights[0]
weights[id_1] = class_weights[1]
weights[id_2] = class_weights[2]

# %%
import torch.nn as nn
from typing import Any, Optional, Union
from codecarbon import EmissionsTracker # para calcular emissões de CO2

# Supondo que você já tenha contado os exemplos por classe
# class_counts = [100, 300, 50]  # Exemplo para 3 classes
# class_weights = [1.0 / c for c in class_counts]  # inversamente proporcional à frequência
# class_weights = torch.tensor(class_weights, dtype=torch.float).to("cuda")

loss_fn = nn.CrossEntropyLoss(weight=weights)


class WeightedTrainer(Trainer):
    def compute_loss(self, model, inputs, return_outputs=False,
        num_items_in_batch: Optional[torch.Tensor] = None):
        labels = inputs.get("labels")

        # print(inputs)
        
        # Forward normal
        outputs = model(input_ids=inputs['input_ids'], attention_mask=inputs['attention_mask'])
        logits = outputs.get("logits")

        # Índice do último token válido em cada exemplo
        last_idx = inputs['attention_mask'].sum(dim=1) - 1 # [batch_size]

        # Logits do último token
        batch_size = logits.size(0)
        last_logits = logits[torch.arange(batch_size), last_idx-1, :]  # [batch_size, vocab_size]

        # print( 'input ids shape', inputs['input_ids'].shape)
        # print( 'batch size', batch_size)
        # print( 'last idx', last_idx)

        # Labels do último token
        last_labels = labels[torch.arange(batch_size), last_idx]     # [batch_size]



        # print( last_logits.shape )
        # pred_ids = torch.argmax(last_logits, dim=-1)  # shape: [batch_size]

        # # converte os IDs de volta para strings
        # pred_tokens = [tok.decode([i]) for i in pred_ids]
        # print( 'previstos', pred_ids, pred_tokens )
        # print( 'reais', last_labels )

        # decoded_texts = []
        # input_ids = inputs['input_ids']
        # for i in range(input_ids.size(0)):
        #     # pega do início até last_idx[i] (inclusive)
        #     tokens = input_ids[i, : last_idx[i]]  # +1 porque slice é exclusive
        #     decoded = tok.decode(tokens)
        #     decoded_texts.append(decoded)

        # # printar
        # for i, text in enumerate(decoded_texts):
        #     print(f"Exemplo {i}: {text}")


        # Calcula a loss
        loss = loss_fn(last_logits, last_labels)


        return (loss, outputs) if return_outputs else loss
    
def train_all():

    # ------------------
    # Data collator para Causal LM
    # ------------------
    collator = DataCollatorForSeq2Seq(tokenizer=tok, padding=True)

    # ------------------
    # TrainingArguments
    # ------------------
    args = TrainingArguments(
        output_dir=OUTPUT_DIR,
        num_train_epochs=1,
        per_device_train_batch_size=3,
        per_device_eval_batch_size=4,
        gradient_accumulation_steps=10,
        learning_rate=2e-4,
        warmup_ratio=0.03,
        logging_steps=100,
        eval_strategy="epoch",
        save_strategy="epoch",
        save_total_limit=2,
        bf16=torch.cuda.is_available(),
        optim="paged_adamw_32bit",
        seed=SEED,
        report_to="none",
        dataloader_num_workers=4,
        load_best_model_at_end=True,
        metric_for_best_model="loss",
        greater_is_better=False,
        logging_strategy="steps",      
        log_level="info",
    )

    # ------------------
    # Trainer
    # ------------------
    trainer = WeightedTrainer(
        model=model,
        args=args,
        train_dataset=train_ds,
        eval_dataset=eval_ds,
        tokenizer=tok,
        data_collator=collator,
        callbacks=[EarlyStoppingCallback(early_stopping_patience=2)]
    )

    # ------------------
    # Treino
    # ------------------
    start_time = time.time()

    tracker_train = EmissionsTracker( output_file='balanced_fine_tuning_emissions_train_logs.csv' )
    tracker_train.start()

    trainer.train()

    end_time = time.time()
    elapsed_time = end_time - start_time
    print(f"\nTempo total de execução: {elapsed_time:.2f} segundos")

    emissions: float = tracker_train.stop()
    print("\n\nTotal de emissões (detalhes em balanced_fine_tuning_emissions_train_logs.csv): ",emissions)

    trainer.save_model(OUTPUT_DIR)
    tok.save_pretrained(OUTPUT_DIR)

    print("Treino finalizado. Modelo salvo em", OUTPUT_DIR)


train_all()
# Out:
# /tmp/ipykernel_1823863/2806503771.py:101: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `WeightedTrainer.__init__`. Use `processing_class` instead.
#   trainer = WeightedTrainer(
# `use_cache=True` is incompatible with gradient checkpointing. Setting `use_cache=False`.
# /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
#     <div>
#
#       <progress value='6726' max='11210' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 6726/11210 49:09:46 < 32:47:06, 0.04 it/s, Epoch 6/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>8.097600</td>
#       <td>0.872778</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>8.943300</td>
#       <td>0.874344</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>7.916100</td>
#       <td>0.799221</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>7.813300</td>
#       <td>0.791155</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>7.053200</td>
#       <td>0.816951</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>6.547400</td>
#       <td>0.815776</td>
#     </tr>
#   </tbody>
# </table><p>
# /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# Tempo total de execução: 177013.12 segundos
# Treino finalizado. Modelo salvo em ./qlora-aderencia-classes.balanced

# %%
del model
del raw_model
loss_fn = None
# del trainer
torch.cuda.empty_cache()

# %%
checkpoint_dir= os.path.join(OUTPUT_DIR, "checkpoint-4484")  # ajuste conforme necessário
# ------------------
# Modelo base com quantização 4-bit
# ------------------
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.bfloat16 if torch.cuda.is_available() else torch.float32,
)

model = AutoModelForCausalLM.from_pretrained(
    MODEL_NAME,
    device_map="auto",
    trust_remote_code=True,
    quantization_config=bnb_config
)

# Aplicar o LoRA / PEFT checkpoint
model = PeftModel.from_pretrained(
    model,
    checkpoint_dir,
    device_map="auto",           # mantém a mesma distribuição
)

tok = AutoTokenizer.from_pretrained(checkpoint_dir)
# Out:
# Loading checkpoint shards:   0%|          | 0/8 [00:00<?, ?it/s]

# %%
model.device
# Out:
# device(type='cuda', index=0)

# %%
# ------------------
# Predict (next token)
# ------------------
import torch
import torch.nn.functional as F

# tokens de interesse
target_tokens = [tok.encode("0", add_special_tokens=False)[0], tok.encode("1", add_special_tokens=False)[0], tok.encode("2", add_special_tokens=False)[0]]

def predict_class(prompt_text):
    # tokeniza
    tokenized = tok(prompt_text, return_tensors="pt")
    input_ids = tokenized.input_ids.cuda()
    attention_mask = tokenized.attention_mask.cuda()

    # forward no modelo (sem generate)
    with torch.no_grad():
        outputs = model(input_ids=input_ids, attention_mask=attention_mask)
        # logits do último token
        last_token_logits = outputs.logits[0, -1, :]
        # softmax para probabilidades
        probs = F.softmax(last_token_logits, dim=-1)

    # pegar probabilidades apenas para os tokens 0,1,2
    target_probs = {tok.decode([t]): probs[t].item() for t in target_tokens}

    # escolher token mais provável
    pred_token = max(target_probs, key=target_probs.get)

    return pred_token, target_probs


# Exemplo
example = split_test[0]
processed_key_words = '\n- '.join(example["descricao_keyword"].split(';'))

    # Cria prompt
example_prompt = PROMPT_TMPL.format(
        title=example["nome_producao"],
        abstract=example["descricao_abstract"],
        keywords=processed_key_words,
        category=example["tema"]
    )
print("Predicted class:", predict_class(example_prompt))
# Out:
# Predicted class: ('1', {'0': 0.20361328125, '1': 0.466064453125, '2': 0.330322265625})

# %%
# !pip show scikit-learn
# Out:
# Name: scikit-learn
# Version: 1.7.1
# Summary: A set of python modules for machine learning and data mining
# Home-page: https://scikit-learn.org
# Author:
# Author-email:
# License-Expression: BSD-3-Clause
# Location: /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages
# Requires: joblib, numpy, scipy, threadpoolctl
# Required-by:

# %%
from sklearn.metrics import accuracy_score, f1_score, classification_report
from tqdm import tqdm
from codecarbon import EmissionsTracker # para calcular emissões de CO2

tracker = EmissionsTracker( output_file='balanced_fine_tuning_emissions.csv' )
tracker.start()

y_true = []
y_pred = []

start_time = time.time()

# .select(range(30))

for example in tqdm(split_test, desc="Inferindo"):  # percorre todo o dataset de teste
    # ---------------------
    # Prepara prompt
    processed_key_words = '\n- '.join(example["descricao_keyword"].split(';'))
    example_prompt = PROMPT_TMPL.format(
        title=example["nome_producao"],
        abstract=example["descricao_abstract"],
        keywords=processed_key_words,
        category=example["tema"]
    )

    # Predição
    pred = predict_class(example_prompt)
    y_pred.append(["0","1","2"].index(pred[0]))

    # Rótulo real
    gold = str(example["modelo_nivel"]).strip().upper()
    if gold == "MEDIA":
        gold = "MÉDIA"
    assert gold in LABELS
    y_true.append(LABELS.index(gold))

# Marca o tempo final
end_time = time.time()

# Tempo total em segundos
elapsed_time = end_time - start_time
print(f"\nTempo total de execução: {elapsed_time:.2f} segundos")


emissions: float = tracker.stop()
print("\n\nTotal de emissões (detalhes em emissions.csv): ",emissions)

# ---------------------
# Métricas
acc = accuracy_score(y_true, y_pred)
f1_macro = f1_score(y_true, y_pred, average="macro")
f1_weighted = f1_score(y_true, y_pred, average="weighted")

print("Acurácia:", acc)
print("F1-macro:", f1_macro)
print("F1-weighted:", f1_weighted)

# Relatório detalhado (por classe)
print("\nRelatório de classificação:")
print(classification_report(y_true, y_pred, target_names=LABELS))
# Out:
# [codecarbon WARNING @ 09:00:20] Multiple instances of codecarbon are allowed to run at the same time.
# [codecarbon INFO @ 09:00:20] [setup] RAM Tracking...
# [codecarbon INFO @ 09:00:20] [setup] CPU Tracking...
# [codecarbon WARNING @ 09:00:21] We saw that you have a Intel(R) Core(TM) i9-14900KF but we don't know it. Please contact us.
# [codecarbon WARNING @ 09:00:21] We will use the default power consumption of 4 W per thread for your 32 CPU, so 128W.
# [codecarbon WARNING @ 09:00:21] No CPU tracking mode found. Falling back on estimation based on TDP for CPU.
#  Linux OS detected: Please ensure RAPL files exist at /sys/class/powercap/intel-rapl/subsystem to measure CPU
#
# [codecarbon INFO @ 09:00:21] CPU Model on constant consumption mode: Intel(R) Core(TM) i9-14900KF
# [codecarbon WARNING @ 09:00:21] No CPU tracking mode found. Falling back on CPU load mode.
# [codecarbon INFO @ 09:00:21] [setup] GPU Tracking...
# [codecarbon INFO @ 09:00:21] Tracking Nvidia GPU via pynvml
# [codecarbon INFO @ 09:00:21] The below tracking methods have been set up:
#                 RAM Tracking Method: RAM power estimation model
#                 CPU Tracking Method: cpu_load
#                 GPU Tracking Method: pynvml
#
# [codecarbon INFO @ 09:00:21] >>> Tracker's metadata:
# [codecarbon INFO @ 09:00:21]   Platform system: Linux-6.9.3-76060903-generic-x86_64-with-glibc2.35
# [codecarbon INFO @ 09:00:21]   Python version: 3.11.5
# [codecarbon INFO @ 09:00:21]   CodeCarbon version: 3.0.4
# [codecarbon INFO @ 09:00:21]   Available RAM : 125.634 GB
# [codecarbon INFO @ 09:00:21]   CPU count: 32 thread(s) in 1 physical CPU(s)
# [codecarbon INFO @ 09:00:21]   CPU model: Intel(R) Core(TM) i9-14900KF
# [codecarbon INFO @ 09:00:21]   GPU count: 1
# [codecarbon INFO @ 09:00:21]   GPU model: 1 x NVIDIA RTX A5000
# [codecarbon INFO @ 09:00:24] Emissions data (if any) will be saved to file /exp/rvsantin/projetos/challenge_bonito/balanced_fine_tuning_emissions.csv
# Inferindo:   1%|          | 23/4203 [00:14<38:06,  1.83it/s][codecarbon INFO @ 09:00:39] Energy consumed for RAM : 0.000164 kWh. RAM Power : 38.0 W
# Inferindo:   1%|          | 24/4203 [00:15<39:47,  1.75it/s][codecarbon INFO @ 09:00:40] Delta energy consumed for CPU with cpu_load : 0.000056 kWh, power : 12.9154540544 W
# [codecarbon INFO @ 09:00:40] Energy consumed for All CPU : 0.000056 kWh
# [codecarbon INFO @ 09:00:40] Energy consumed for all GPUs : 0.000982 kWh. Total GPU Power : 220.96258552016397 W
# [codecarbon INFO @ 09:00:40] 0.001202 kWh of electricity used since the beginning.
# Inferindo:   1%|          | 47/4203 [00:29<44:03,  1.57it/s][codecarbon INFO @ 09:00:54] Energy consumed for RAM : 0.000317 kWh. RAM Power : 38.0 W
# Inferindo:   1%|          | 48/4203 [00:30<43:55,  1.58it/s][codecarbon INFO @ 09:00:55] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.913194389600003 W
# [codecarbon INFO @ 09:00:55] Energy consumed for All CPU : 0.000108 kWh
# [codecarbon INFO @ 09:00:55] Energy consumed for all GPUs : 0.001933 kWh. Total GPU Power : 228.07102721564712 W
# [codecarbon INFO @ 09:00:55] 0.002357 kWh of electricity used since the beginning.
# Inferindo:   2%|▏         | 69/4203 [00:44<47:23,  1.45it/s][codecarbon INFO @ 09:01:09] Energy consumed for RAM : 0.000470 kWh. RAM Power : 38.0 W
# Inferindo:   2%|▏         | 70/4203 [00:45<46:23,  1.48it/s][codecarbon INFO @ 09:01:10] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12
10] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.846031119200001 W
# [codecarbon INFO @ 09:13:10] Energy consumed for All CPU : 0.002646 kWh
# [codecarbon INFO @ 09:13:10] Energy consumed for all GPUs : 0.048564 kWh. Total GPU Power : 227.93910319571705 W
# [codecarbon INFO @ 09:13:10] 0.059024 kWh of electricity used since the beginning.
# Inferindo:  28%|██▊       | 1171/4203 [12:59<33:04,  1.53it/s][codecarbon INFO @ 09:13:24] Energy consumed for RAM : 0.007967 kWh. RAM Power : 38.0 W
# Inferindo:  28%|██▊       | 1172/4203 [13:00<31:53,  1.58it/s][codecarbon INFO @ 09:13:25] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.846581552 W
# [codecarbon INFO @ 09:13:25] Energy consumed for All CPU : 0.002698 kWh
# [codecarbon INFO @ 09:13:25] Energy consumed for all GPUs : 0.049515 kWh. Total GPU Power : 228.37740700547565 W
# [codecarbon INFO @ 09:13:25] 0.060180 kWh of electricity used since the beginning.
# Inferindo:  28%|██▊       | 1193/4203 [13:14<33:41,  1.49it/s][codecarbon INFO @ 09:13:39] Energy consumed for RAM : 0.008120 kWh. RAM Power : 38.0 W
# Inferindo:  28%|██▊       | 1194/4203 [13:15<33:18,  1.51it/s][codecarbon INFO @ 09:13:40] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.855888646400002 W
# [codecarbon INFO @ 09:13:40] Energy consumed for All CPU : 0.002750 kWh
# [codecarbon INFO @ 09:13:40] Energy consumed for all GPUs : 0.050469 kWh. Total GPU Power : 228.81896967684654 W
# [codecarbon INFO @ 09:13:40] 0.061338 kWh of electricity used since the beginning.
# Inferindo:  29%|██▉       | 1215/4203 [13:29<38:35,  1.29it/s][codecarbon INFO @ 09:13:54] Energy consumed for RAM : 0.008273 kWh. RAM Power : 38.0 W
# Inferindo:  29%|██▉       | 1216/4203 [13:30<37:16,  1.34it/s][codecarbon INFO @ 09:13:55] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.849647765600002 W
# [codecarbon INFO @ 09:13:55] Energy consumed for All CPU : 0.002801 kWh
# [codecarbon INFO @ 09:13:55] Energy consumed for all GPUs : 0.051421 kWh. Total GPU Power : 228.66097091397884 W
# [codecarbon INFO @ 09:13:55] 0.062495 kWh of electricity used since the beginning.
# Inferindo:  29%|██▉       | 1237/4203 [13:44<35:22,  1.40it/s][codecarbon INFO @ 09:14:09] Energy consumed for RAM : 0.008426 kWh. RAM Power : 38.0 W
# Inferindo:  29%|██▉       | 1238/4203 [13:45<35:09,  1.41it/s][codecarbon INFO @ 09:14:10] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.848803436 W
# [codecarbon INFO @ 09:14:10] Energy consumed for All CPU : 0.002853 kWh
# [codecarbon INFO @ 09:14:10] Energy consumed for all GPUs : 0.052372 kWh. Total GPU Power : 228.24453295030725 W
# [codecarbon INFO @ 09:14:10] 0.063651 kWh of electricity used since the beginning.
# Inferindo:  30%|██▉       | 1260/4203 [13:59<34:00,  1.44it/s][codecarbon INFO @ 09:14:24] Energy consumed for RAM : 0.008579 kWh. RAM Power : 38.0 W
# Inferindo:  30%|███       | 1261/4203 [14:00<33:19,  1.47it/s][codecarbon INFO @ 09:14:25] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.857392697600002 W
# [codecarbon INFO @ 09:14:25] Energy consumed for All CPU : 0.002905 kWh
# [codecarbon INFO @ 09:14:25] Energy consumed for all GPUs : 0.053325 kWh. Total GPU Power : 228.7793694942143 W
# [codecarbon INFO @ 09:14:25] 0.064809 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:14:25] 0.007587 g.CO2eq/s mean an estimation of 239.27019946739517 kg.CO2eq/year
# Inferindo:  30%|███       | 1281/4203 [14:14<31:14,  1.56it/s][codecarbon INFO @ 09:14:39] Energy consumed for RAM : 0.008732 kWh. RAM Power : 38.0 W
# Inferindo:  31%|███       | 1282/4203 [14:15<34:01,  1.43it/s][codecarbon INFO @ 09:14:40] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.851142953600002 W
# [codecarbon INFO @ 09:14:40] Energy consumed for All CPU : 0.002957 kWh
# [codecarbon INFO @ 09:14:40] Energy consumed for all GPUs : 0.054278 kWh. Total GPU Power : 228.87853090557724 W
# [codecarbon INFO @ 09:14:40] 0.065967 kWh of electricity used since the beginning.
# Inferindo:  31%|███       | 1303/4203 [14:29<35:04,  1.38it/s][codecarbon INFO @ 09:14:54] Energy consumed for RAM : 0.008885 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 09:14:55] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.852566148800001 W
# [codecarbon INFO @ 09:14:55] Energy consumed for All CPU : 0.003008 kWh
# [codecarbon INFO @ 09:14:55] Energy consumed for all GPUs : 0.055231 kWh. Total GPU Power : 228.6433615245394 W
# [codecarbon INFO @ 09:14:55] 0.067124 kWh of electricity used since the beginning.
# Inferindo:  32%|███▏      | 1325/4203 [14:44<32:04,  1.50it/s][codecarbon INFO @ 09:15:09] Energy consumed for RAM : 0.009038 kWh. RAM Power : 38.0 W
# Inferindo:  32%|███▏      | 1326/4203 [14:45<32:26,  1.48it/s][codecarbon INFO @ 09:15:10] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.852939044000003 W
# [codecarbon INFO @ 09:15:10] Energy consumed for All CPU : 0.003060 kWh
# [codecarbon INFO @ 09:15:10] Energy consumed for all GPUs : 0.056182 kWh. Total GPU Power : 228.2681772150897 W
# [codecarbon INFO @ 09:15:10] 0.068280 kWh of electricity used since the beginning.
# Inferindo:  32%|███▏      | 1347/4203 [14:59<34:00,  1.40it/s][codecarbon INFO @ 09:15:24] Energy consumed for RAM : 0.009191 kWh. RAM Power : 38.0 W
# Inferindo:  32%|███▏      | 1348/4203 [15:00<32:44,  1.45it/s][codecarbon INFO @ 09:15:25] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.8609917688 W
# [codecarbon INFO @ 09:15:25] Energy consumed for All CPU : 0.003112 kWh
# [codecarbon INFO @ 09:15:25] Energy consumed for all GPUs : 0.057134 kWh. Total GPU Power : 228.61023221241197 W
# [codecarbon INFO @ 09:15:25] 0.069437 kWh of electricity used since the beginning.
# Inferindo:  33%|███▎      | 1371/4203 [15:14<30:15,  1.56it/s][codecarbon INFO @ 09:15:39] Energy consumed for RAM : 0.009344 kWh. RAM Power : 38.0 W
# Inferindo:  33%|███▎      | 1372/4203 [15:15<30:28,  1.55it/s][codecarbon INFO @ 09:15:40] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.844917459200005 W
# [codecarbon INFO @ 09:15:40] Energy consumed for All CPU : 0.003164 kWh
# [codecarbon INFO @ 09:15:40] Energy consumed for all GPUs : 0.058087 kWh. Total GPU Power : 228.62790434994432 W
# [codecarbon INFO @ 09:15:40] 0.070594 kWh of electricity used since the beginning.
# Inferindo:  33%|███▎      | 1393/4203 [15:29<31:33,  1.48it/s][codecarbon INFO @ 09:15:54] Energy consumed for RAM : 0.009497 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 09:15:55] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.
25] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.851609096 W
# [codecarbon INFO @ 09:17:25] Energy consumed for All CPU : 0.003526 kWh
# [codecarbon INFO @ 09:17:25] Energy consumed for all GPUs : 0.064762 kWh. Total GPU Power : 229.9094651610528 W
# [codecarbon INFO @ 09:17:25] 0.078703 kWh of electricity used since the beginning.
# Inferindo:  37%|███▋      | 1547/4203 [17:15<32:48,  1.35it/s][codecarbon INFO @ 09:17:39] Energy consumed for RAM : 0.010568 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 09:17:40] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.849918291200002 W
# [codecarbon INFO @ 09:17:40] Energy consumed for All CPU : 0.003578 kWh
# [codecarbon INFO @ 09:17:40] Energy consumed for all GPUs : 0.065715 kWh. Total GPU Power : 228.73352894835665 W
# [codecarbon INFO @ 09:17:40] 0.079861 kWh of electricity used since the beginning.
# Inferindo:  37%|███▋      | 1569/4203 [17:29<31:22,  1.40it/s][codecarbon INFO @ 09:17:54] Energy consumed for RAM : 0.010721 kWh. RAM Power : 38.0 W
# Inferindo:  37%|███▋      | 1570/4203 [17:30<31:48,  1.38it/s][codecarbon INFO @ 09:17:55] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.8540979128 W
# [codecarbon INFO @ 09:17:55] Energy consumed for All CPU : 0.003630 kWh
# [codecarbon INFO @ 09:17:55] Energy consumed for all GPUs : 0.066666 kWh. Total GPU Power : 228.4634949239183 W
# [codecarbon INFO @ 09:17:55] 0.081017 kWh of electricity used since the beginning.
# Inferindo:  38%|███▊      | 1591/4203 [17:44<28:45,  1.51it/s][codecarbon INFO @ 09:18:09] Energy consumed for RAM : 0.010874 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 09:18:10] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.852079047200002 W
# [codecarbon INFO @ 09:18:10] Energy consumed for All CPU : 0.003682 kWh
# [codecarbon INFO @ 09:18:10] Energy consumed for all GPUs : 0.067618 kWh. Total GPU Power : 228.53156779815572 W
# [codecarbon INFO @ 09:18:10] 0.082174 kWh of electricity used since the beginning.
# Inferindo:  38%|███▊      | 1615/4203 [17:59<26:08,  1.65it/s][codecarbon INFO @ 09:18:24] Energy consumed for RAM : 0.011027 kWh. RAM Power : 38.0 W
# Inferindo:  38%|███▊      | 1616/4203 [18:00<25:38,  1.68it/s][codecarbon INFO @ 09:18:25] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.847950149599999 W
# [codecarbon INFO @ 09:18:25] Energy consumed for All CPU : 0.003733 kWh
# [codecarbon INFO @ 09:18:25] Energy consumed for all GPUs : 0.068573 kWh. Total GPU Power : 229.0885971624101 W
# [codecarbon INFO @ 09:18:25] 0.083333 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:18:25] 0.007592 g.CO2eq/s mean an estimation of 239.4362235256101 kg.CO2eq/year
# Inferindo:  39%|███▉      | 1637/4203 [18:14<30:52,  1.39it/s][codecarbon INFO @ 09:18:39] Energy consumed for RAM : 0.011180 kWh. RAM Power : 38.0 W
# Inferindo:  39%|███▉      | 1638/4203 [18:15<28:59,  1.47it/s][codecarbon INFO @ 09:18:40] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.8560885904 W
# [codecarbon INFO @ 09:18:40] Energy consumed for All CPU : 0.003785 kWh
# [codecarbon INFO @ 09:18:40] Energy consumed for all GPUs : 0.069527 kWh. Total GPU Power : 229.00594681032453 W
# [codecarbon INFO @ 09:18:40] 0.084492 kWh of electricity used since the beginning.
# Inferindo:  40%|███▉      | 1661/4203 [18:30<25:48,  1.64it/s][codecarbon INFO @ 09:18:54] Energy consumed for RAM : 0.011333 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 09:18:55] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.858854290400002 W
# [codecarbon INFO @ 09:18:55] Energy consumed for All CPU : 0.003837 kWh
# [codecarbon INFO @ 09:18:55] Energy consumed for all GPUs : 0.070477 kWh. Total GPU Power : 228.15148210104385 W
# [codecarbon INFO @ 09:18:55] 0.085647 kWh of electricity used since the beginning.
# Inferindo:  40%|████      | 1682/4203 [18:44<28:37,  1.47it/s][codecarbon INFO @ 09:19:09] Energy consumed for RAM : 0.011486 kWh. RAM Power : 38.0 W
# Inferindo:  40%|████      | 1683/4203 [18:45<28:04,  1.50it/s][codecarbon INFO @ 09:19:10] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.856512958400003 W
# [codecarbon INFO @ 09:19:10] Energy consumed for All CPU : 0.003889 kWh
# [codecarbon INFO @ 09:19:10] Energy consumed for all GPUs : 0.071429 kWh. Total GPU Power : 228.40870039031003 W
# [codecarbon INFO @ 09:19:10] 0.086803 kWh of electricity used since the beginning.
# Inferindo:  41%|████      | 1704/4203 [18:59<28:05,  1.48it/s][codecarbon INFO @ 09:19:24] Energy consumed for RAM : 0.011639 kWh. RAM Power : 38.0 W
# Inferindo:  41%|████      | 1705/4203 [19:00<27:48,  1.50it/s][codecarbon INFO @ 09:19:25] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.9073524824 W
# [codecarbon INFO @ 09:19:25] Energy consumed for All CPU : 0.003941 kWh
# [codecarbon INFO @ 09:19:25] Energy consumed for all GPUs : 0.072382 kWh. Total GPU Power : 228.8501108352701 W
# [codecarbon INFO @ 09:19:25] 0.087962 kWh of electricity used since the beginning.
# Inferindo:  41%|████      | 1726/4203 [19:14<28:38,  1.44it/s][codecarbon INFO @ 09:19:39] Energy consumed for RAM : 0.011792 kWh. RAM Power : 38.0 W
# Inferindo:  41%|████      | 1727/4203 [19:15<29:05,  1.42it/s][codecarbon INFO @ 09:19:40] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.867617755999998 W
# [codecarbon INFO @ 09:19:40] Energy consumed for All CPU : 0.003992 kWh
# [codecarbon INFO @ 09:19:40] Energy consumed for all GPUs : 0.073336 kWh. Total GPU Power : 228.9061886111295 W
# [codecarbon INFO @ 09:19:40] 0.089120 kWh of electricity used since the beginning.
# Inferindo:  42%|████▏     | 1750/4203 [19:30<29:15,  1.40it/s][codecarbon INFO @ 09:19:54] Energy consumed for RAM : 0.011945 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 09:19:55] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.868490086400005 W
# [codecarbon INFO @ 09:19:55] Energy consumed for All CPU : 0.004044 kWh
# [codecarbon INFO @ 09:19:55] Energy consumed for all GPUs : 0.074288 kWh. Total GPU Power : 228.60117112165156 W
# ...
# Inferindo:  87%|████████▋ | 3653/4203 [40:00<05:28,  1.68it/s][codecarbon INFO @ 09:40:25] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.854448077600003 W
# [codecarbon INFO @ 09:40:25] Energy consumed for All CPU : 0.008289 kWh
# [codecarbon INFO @ 09:40:25] Energy consumed for all GPUs : 0.152432 kWh. Total GPU Power : 228.48907566421389 W
# [codecarbon INFO @ 09:40:25] 0.185212 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:40:25] 0.007579 g.CO2eq/s mean an estimation of 239.00758408131577 kg.CO2eq/year
# Inferindo:  87%|████████▋ | 3676/4203 [40:14<05:24,  1.63it/s][codecarbon INFO @ 09:40:39] Energy consumed for RAM : 0.024644 kWh. RAM Power : 38.0 W
# Inferindo:  87%|████████▋ | 3677/4203 [40:15<05:32,  1.58it/s][codecarbon INFO @ 09:40:40] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.850435899200003 W
# [codecarbon INFO @ 09:40:40] Energy consumed for All CPU : 0.008341 kWh
# [codecarbon INFO @ 09:40:40] Energy consumed for all GPUs : 0.153385 kWh. Total GPU Power : 228.6145462395346 W
# [codecarbon INFO @ 09:40:40] 0.186369 kWh of electricity used since the beginning.
# Inferindo:  88%|████████▊ | 3700/4203 [40:30<04:58,  1.69it/s][codecarbon INFO @ 09:40:54] Energy consumed for RAM : 0.024797 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 09:40:55] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.8636958224 W
# [codecarbon INFO @ 09:40:55] Energy consumed for All CPU : 0.008392 kWh
# [codecarbon INFO @ 09:40:55] Energy consumed for all GPUs : 0.154340 kWh. Total GPU Power : 229.36535115803238 W
# [codecarbon INFO @ 09:40:55] 0.187530 kWh of electricity used since the beginning.
# Inferindo:  89%|████████▊ | 3723/4203 [40:44<05:09,  1.55it/s][codecarbon INFO @ 09:41:09] Energy consumed for RAM : 0.024950 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 09:41:10] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.8599037768 W
# [codecarbon INFO @ 09:41:10] Energy consumed for All CPU : 0.008444 kWh
# [codecarbon INFO @ 09:41:10] Energy consumed for all GPUs : 0.155295 kWh. Total GPU Power : 229.1780565944133 W
# [codecarbon INFO @ 09:41:10] 0.188689 kWh of electricity used since the beginning.
# Inferindo:  89%|████████▉ | 3745/4203 [40:59<05:20,  1.43it/s][codecarbon INFO @ 09:41:24] Energy consumed for RAM : 0.025103 kWh. RAM Power : 38.0 W
# Inferindo:  89%|████████▉ | 3746/4203 [41:00<04:59,  1.52it/s][codecarbon INFO @ 09:41:25] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.854192859200003 W
# [codecarbon INFO @ 09:41:25] Energy consumed for All CPU : 0.008496 kWh
# [codecarbon INFO @ 09:41:25] Energy consumed for all GPUs : 0.156250 kWh. Total GPU Power : 229.16314731154148 W
# [codecarbon INFO @ 09:41:25] 0.189849 kWh of electricity used since the beginning.
# Inferindo:  90%|████████▉ | 3768/4203 [41:14<04:25,  1.64it/s][codecarbon INFO @ 09:41:39] Energy consumed for RAM : 0.025256 kWh. RAM Power : 38.0 W
# Inferindo:  90%|████████▉ | 3769/4203 [41:15<04:27,  1.62it/s][codecarbon INFO @ 09:41:40] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.845837144000004 W
# [codecarbon INFO @ 09:41:40] Energy consumed for All CPU : 0.008548 kWh
# [codecarbon INFO @ 09:41:40] Energy consumed for all GPUs : 0.157203 kWh. Total GPU Power : 228.8969245286885 W
# [codecarbon INFO @ 09:41:40] 0.191007 kWh of electricity used since the beginning.
# Inferindo:  90%|█████████ | 3791/4203 [41:29<04:32,  1.51it/s][codecarbon INFO @ 09:41:54] Energy consumed for RAM : 0.025409 kWh. RAM Power : 38.0 W
# Inferindo:  90%|█████████ | 3792/4203 [41:30<04:30,  1.52it/s][codecarbon INFO @ 09:41:55] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.856829736800004 W
# [codecarbon INFO @ 09:41:55] Energy consumed for All CPU : 0.008599 kWh
# [codecarbon INFO @ 09:41:55] Energy consumed for all GPUs : 0.158161 kWh. Total GPU Power : 229.77763161371814 W
# [codecarbon INFO @ 09:41:55] 0.192169 kWh of electricity used since the beginning.
# Inferindo:  91%|█████████ | 3814/4203 [41:44<04:17,  1.51it/s][codecarbon INFO @ 09:42:09] Energy consumed for RAM : 0.025562 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 09:42:10] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.856728886400001 W
# [codecarbon INFO @ 09:42:10] Energy consumed for All CPU : 0.008651 kWh
# [codecarbon INFO @ 09:42:10] Energy consumed for all GPUs : 0.159113 kWh. Total GPU Power : 228.55357662798062 W
# [codecarbon INFO @ 09:42:10] 0.193326 kWh of electricity used since the beginning.
# Inferindo:  91%|█████████▏| 3836/4203 [41:59<03:56,  1.55it/s][codecarbon INFO @ 09:42:24] Energy consumed for RAM : 0.025715 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 09:42:25] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.857140733600003 W
# [codecarbon INFO @ 09:42:25] Energy consumed for All CPU : 0.008703 kWh
# [codecarbon INFO @ 09:42:25] Energy consumed for all GPUs : 0.160065 kWh. Total GPU Power : 228.61581439364596 W
# [codecarbon INFO @ 09:42:25] 0.194483 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:42:25] 0.007598 g.CO2eq/s mean an estimation of 239.61169759899798 kg.CO2eq/year
# Inferindo:  92%|█████████▏| 3858/4203 [42:14<04:30,  1.27it/s][codecarbon INFO @ 09:42:39] Energy consumed for RAM : 0.025868 kWh. RAM Power : 38.0 W
# Inferindo:  92%|█████████▏| 3859/4203 [42:15<04:08,  1.39it/s][codecarbon INFO @ 09:42:40] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.854088056 W
# [codecarbon INFO @ 09:42:40] Energy consumed for All CPU : 0.008755 kWh
# [codecarbon INFO @ 09:42:40] Energy consumed for all GPUs : 0.161018 kWh. Total GPU Power : 228.59934865147042 W
# [codecarbon INFO @ 09:42:40] 0.195640 kWh of electricity used since the beginning.
# Inferindo:  92%|█████████▏| 3880/4203 [42:29<04:06,  1.31it/s][codecarbon INFO @ 09:42:54] Energy consumed for RAM : 0.026021 kWh. RAM Power : 38.0 W
# Inferindo:  92%|█████████▏| 3881/4203 [42:30<03:54,  1.37it/s][codecarbon INFO @ 09:42:55] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.858751272799998 W
# [codecarbon INFO @ 09:42:55] Energy consumed for All CPU : 0.008807 kWh
# [codecarbon INFO @ 09:42:55] Energy consumed for all GPUs : 0.161969 kWh. Total GPU Power : 228.39208999542356 W
# [codecarbon INFO @ 09:42:55] 0.196797 kWh of electricity used since the beginning.
# Inferindo:  93%|█████████▎| 3903/4203 [42:44<03:10,  1.57it/s][codecarbon INFO @ 09:43:09] Energy consumed for RAM : 0.026174 kWh. RAM Power : 38.0 W
# Inferindo:  93%|█████████▎| 3904/4203 [42:45<03:01,  1.64it/s][codecarbon INFO @ 09:43:10] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.860274396800001 W
# [codecarbon INFO @ 09:43:10] Energy consumed for All CPU : 0.008858 kWh
# [codecarbon INFO @ 09:43:10] Energy consumed for all GPUs : 0.162925 kWh. Total GPU Power : 229.38086686643553 W
# [codecarbon INFO @ 09:43:10] 0.197957 kWh of electricity used since the beginning.
# Inferindo:  93%|█████████▎| 3925/4203 [42:59<03:19,  1.40it/s][codecarbon INFO @ 09:43:24] Energy consumed for RAM : 0.026327 kWh. RAM Power : 38.0 W
# Inferindo:  93%|█████████▎| 3926/4203 [43:00<03:21,  1.37it/s][codecarbon INFO @ 09:43:25] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.860153984000002 W
# [codecarbon INFO @ 09:43:25] Energy consumed for All CPU : 0.008910 kWh
# [codecarbon INFO @ 09:43:25] Energy consumed for all GPUs : 0.163878 kWh. Total GPU Power : 228.69391851230966 W
# [codecarbon INFO @ 09:43:25] 0.199115 kWh of electricity used since the beginning.
# Inferindo:  94%|█████████▍| 3948/4203 [43:15<02:47,  1.53it/s][codecarbon INFO @ 09:43:39] Energy consumed for RAM : 0.026480 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 09:43:40] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.8540167616 W
# [codecarbon INFO @ 09:43:40] Energy consumed for All CPU : 0.008962 kWh
# [codecarbon INFO @ 09:43:40] Energy consumed for all GPUs : 0.164830 kWh. Total GPU Power : 228.71584079481346 W
# [codecarbon INFO @ 09:43:40] 0.200272 kWh of electricity used since the beginning.
# Inferindo:  94%|█████████▍| 3971/4203 [43:30<02:37,  1.47it/s][codecarbon INFO @ 09:43:54] Energy consumed for RAM : 0.026633 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 09:43:55] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.854326649599999 W
# [codecarbon INFO @ 09:43:55] Energy consumed for All CPU : 0.009014 kWh
# [codecarbon INFO @ 09:43:55] Energy consumed for all GPUs : 0.165784 kWh. Total GPU Power : 228.90864298240044 W
# [codecarbon INFO @ 09:43:55] 0.201431 kWh of electricity used since the beginning.
# Inferindo:  95%|█████████▌| 3993/4203 [43:44<02:05,  1.67it/s][codecarbon INFO @ 09:44:09] Energy consumed for RAM : 0.026786 kWh. RAM Power : 38.0 W
# Inferindo:  95%|█████████▌| 3994/4203 [43:45<02:00,  1.74it/s][codecarbon INFO @ 09:44:10] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.8584726976 W
# [codecarbon INFO @ 09:44:10] Energy consumed for All CPU : 0.009065 kWh
# [codecarbon INFO @ 09:44:10] Energy consumed for all GPUs : 0.166740 kWh. Total GPU Power : 229.52991513405183 W
# [codecarbon INFO @ 09:44:10] 0.202591 kWh of electricity used since the beginning.
# Inferindo:  96%|█████████▌| 4015/4203 [43:59<02:09,  1.45it/s][codecarbon INFO @ 09:44:24] Energy consumed for RAM : 0.026939 kWh. RAM Power : 38.0 W
# Inferindo:  96%|█████████▌| 4016/4203 [44:00<02:06,  1.48it/s][codecarbon INFO @ 09:44:25] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.8460232208 W
# [codecarbon INFO @ 09:44:25] Energy consumed for All CPU : 0.009117 kWh
# [codecarbon INFO @ 09:44:25] Energy consumed for all GPUs : 0.167693 kWh. Total GPU Power : 228.74517435366593 W
# [codecarbon INFO @ 09:44:25] 0.203749 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:44:25] 0.007594 g.CO2eq/s mean an estimation of 239.4711001178705 kg.CO2eq/year
# Inferindo:  96%|█████████▌| 4037/4203 [44:14<01:55,  1.44it/s][codecarbon INFO @ 09:44:39] Energy consumed for RAM : 0.027092 kWh. RAM Power : 38.0 W
# Inferindo:  96%|█████████▌| 4038/4203 [44:15<01:43,  1.59it/s][codecarbon INFO @ 09:44:40] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.8532626768 W
# [codecarbon INFO @ 09:44:40] Energy consumed for All CPU : 0.009169 kWh
# [codecarbon INFO @ 09:44:40] Energy consumed for all GPUs : 0.168645 kWh. Total GPU Power : 228.63611398799168 W
# [codecarbon INFO @ 09:44:40] 0.204906 kWh of electricity used since the beginning.
# Inferindo:  97%|█████████▋| 4061/4203 [44:29<01:40,  1.42it/s][codecarbon INFO @ 09:44:54] Energy consumed for RAM : 0.027245 kWh. RAM Power : 38.0 W
# Inferindo:  97%|█████████▋| 4062/4203 [44:30<01:33,  1.50it/s][codecarbon INFO @ 09:44:55] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.876285094400004 W
# [codecarbon INFO @ 09:44:55] Energy consumed for All CPU : 0.009221 kWh
# [codecarbon INFO @ 09:44:55] Energy consumed for all GPUs : 0.169600 kWh. Total GPU Power : 229.2493590007893 W
# [codecarbon INFO @ 09:44:55] 0.206066 kWh of electricity used since the beginning.
# Inferindo:  97%|█████████▋| 4084/4203 [44:44<01:12,  1.63it/s][codecarbon INFO @ 09:45:09] Energy consumed for RAM : 0.027398 kWh. RAM Power : 38.0 W
# Inferindo:  97%|█████████▋| 4085/4203 [44:45<01:09,  1.71it/s][codecarbon INFO @ 09:45:10] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.856957040000005 W
# [codecarbon INFO @ 09:45:10] Energy consumed for All CPU : 0.009272 kWh
# [codecarbon INFO @ 09:45:10] Energy consumed for all GPUs : 0.170556 kWh. Total GPU Power : 229.42815239204543 W
# [codecarbon INFO @ 09:45:10] 0.207226 kWh of electricity used since the beginning.
# Inferindo:  98%|█████████▊| 4107/4203 [44:59<01:02,  1.54it/s][codecarbon INFO @ 09:45:24] Energy consumed for RAM : 0.027551 kWh. RAM Power : 38.0 W
# Inferindo:  98%|█████████▊| 4108/4203 [45:00<01:00,  1.58it/s][codecarbon INFO @ 09:45:25] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.862927877600002 W
# [codecarbon INFO @ 09:45:25] Energy consumed for All CPU : 0.009324 kWh
# [codecarbon INFO @ 09:45:25] Energy consumed for all GPUs : 0.171508 kWh. Total GPU Power : 228.44734974494364 W
# [codecarbon INFO @ 09:45:25] 0.208383 kWh of electricity used since the beginning.
# Inferindo:  98%|█████████▊| 4130/4203 [45:14<00:48,  1.51it/s][codecarbon INFO @ 09:45:39] Energy consumed for RAM : 0.027704 kWh. RAM Power : 38.0 W
# Inferindo:  98%|█████████▊| 4131/4203 [45:15<00:44,  1.60it/s][codecarbon INFO @ 09:45:40] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.853513056799999 W
# [codecarbon INFO @ 09:45:40] Energy consumed for All CPU : 0.009376 kWh
# [codecarbon INFO @ 09:45:40] Energy consumed for all GPUs : 0.172460 kWh. Total GPU Power : 228.66985298458692 W
# [codecarbon INFO @ 09:45:40] 0.209540 kWh of electricity used since the beginning.
# Inferindo:  99%|█████████▉| 4153/4203 [45:29<00:32,  1.52it/s][codecarbon INFO @ 09:45:54] Energy consumed for RAM : 0.027857 kWh. RAM Power : 38.0 W
# Inferindo:  99%|█████████▉| 4154/4203 [45:30<00:31,  1.58it/s][codecarbon INFO @ 09:45:55] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.854990000000003 W
# [codecarbon INFO @ 09:45:55] Energy consumed for All CPU : 0.009428 kWh
# [codecarbon INFO @ 09:45:55] Energy consumed for all GPUs : 0.173413 kWh. Total GPU Power : 228.7713385248965 W
# [codecarbon INFO @ 09:45:55] 0.210698 kWh of electricity used since the beginning.
# Inferindo:  99%|█████████▉| 4176/4203 [45:44<00:16,  1.68it/s][codecarbon INFO @ 09:46:09] Energy consumed for RAM : 0.028010 kWh. RAM Power : 38.0 W
# Inferindo:  99%|█████████▉| 4177/4203 [45:45<00:15,  1.64it/s][codecarbon INFO @ 09:46:10] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.852813404000003 W
# [codecarbon INFO @ 09:46:10] Energy consumed for All CPU : 0.009480 kWh
# [codecarbon INFO @ 09:46:10] Energy consumed for all GPUs : 0.174368 kWh. Total GPU Power : 229.09082798502132 W
# [codecarbon INFO @ 09:46:10] 0.211857 kWh of electricity used since the beginning.
# Inferindo: 100%|█████████▉| 4197/4203 [45:59<00:04,  1.29it/s][codecarbon INFO @ 09:46:24] Energy consumed for RAM : 0.028163 kWh. RAM Power : 38.0 W
# Inferindo: 100%|█████████▉| 4198/4203 [46:00<00:03,  1.40it/s][codecarbon INFO @ 09:46:25] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.848715185600003 W
# [codecarbon INFO @ 09:46:25] Energy consumed for All CPU : 0.009531 kWh
# [codecarbon INFO @ 09:46:25] Energy consumed for all GPUs : 0.175320 kWh. Total GPU Power : 228.64566692247908 W
# [codecarbon INFO @ 09:46:25] 0.213014 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:46:25] 0.007593 g.CO2eq/s mean an estimation of 239.4669775068431 kg.CO2eq/year
# Inferindo: 100%|██████████| 4203/4203 [46:03<00:00,  1.52it/s]
# [codecarbon INFO @ 09:46:28] Energy consumed for RAM : 0.028196 kWh. RAM Power : 38.0 W
# Tempo total de execução: 2763.72 segundos
# [codecarbon INFO @ 09:46:29] Delta energy consumed for CPU with cpu_load : 0.000011 kWh, power : 12.848651217920002 W
# [codecarbon INFO @ 09:46:29] Energy consumed for All CPU : 0.009542 kWh
# [codecarbon INFO @ 09:46:29] Energy consumed for all GPUs : 0.175540 kWh. Total GPU Power : 217.18078949632047 W
# [codecarbon INFO @ 09:46:29] 0.213278 kWh of electricity used since the beginning.
# Total de emissões (detalhes em emissions.csv):  0.02097550518709433
# Acurácia: 0.6176540566262194
# F1-macro: 0.5982838430439305
# F1-weighted: 0.621307467904316
#
# Relatório de classificação:
#               precision    recall  f1-score   support
#
#        BAIXA       0.73      0.72      0.73      2056
#        MÉDIA       0.43      0.50      0.47      1284
#         ALTA       0.69      0.53      0.60       863
#
#     accuracy                           0.62      4203
#    macro avg       0.62      0.59      0.60      4203
# weighted avg       0.63      0.62      0.62      4203
