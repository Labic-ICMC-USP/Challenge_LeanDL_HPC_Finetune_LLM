# %%
# !pip install codecarbon # reiniciar apos instalar este pacote se você estiver em um notebook
# Out:
# Requirement already satisfied: codecarbon in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (3.0.4)
# Requirement already satisfied: arrow in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from codecarbon) (1.3.0)
# Requirement already satisfied: click in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from codecarbon) (8.2.1)
# Requirement already satisfied: fief-client[cli] in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from codecarbon) (0.20.0)
# Requirement already satisfied: pandas in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from codecarbon) (2.2.3)
# Requirement already satisfied: prometheus_client in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from codecarbon) (0.22.1)
# Requirement already satisfied: psutil>=6.0.0 in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from codecarbon) (7.0.0)
# Requirement already satisfied: py-cpuinfo in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from codecarbon) (9.0.0)
# Requirement already satisfied: pydantic in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from codecarbon) (2.11.7)
# Requirement already satisfied: pynvml in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from codecarbon) (12.0.0)
# Requirement already satisfied: rapidfuzz in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from codecarbon) (3.13.0)
# Requirement already satisfied: requests in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from codecarbon) (2.32.4)
# Requirement already satisfied: questionary in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from codecarbon) (2.1.0)
# Requirement already satisfied: rich in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from codecarbon) (14.1.0)
# Requirement already satisfied: typer in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from codecarbon) (0.16.0)
# Requirement already satisfied: python-dateutil>=2.7.0 in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from arrow->codecarbon) (2.9.0.post0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from arrow->codecarbon) (2.9.0.20250809)
# Requirement already satisfied: six>=1.5 in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from python-dateutil>=2.7.0->arrow->codecarbon) (1.17.0)
# Requirement already satisfied: httpx<0.28.0,>=0.21.3 in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from fief-client[cli]->codecarbon) (0.27.2)
# Requirement already satisfied: jwcrypto<2.0.0,>=1.4 in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from fief-client[cli]->codecarbon) (1.5.6)
# Requirement already satisfied: yaspin in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from fief-client[cli]->codecarbon) (3.1.0)
# Requirement already satisfied: anyio in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from httpx<0.28.0,>=0.21.3->fief-client[cli]->codecarbon) (4.10.0)
# Requirement already satisfied: certifi in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from httpx<0.28.0,>=0.21.3->fief-client[cli]->codecarbon) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from httpx<0.28.0,>=0.21.3->fief-client[cli]->codecarbon) (1.0.9)
# Requirement already satisfied: idna in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from httpx<0.28.0,>=0.21.3->fief-client[cli]->codecarbon) (3.10)
# Requirement already satisfied: sniffio in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from httpx<0.28.0,>=0.21.3->fief-client[cli]->codecarbon) (1.3.1)
# Requirement already satisfied: h11>=0.16 in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from httpcore==1.*->httpx<0.28.0,>=0.21.3->fief-client[cli]->codecarbon) (0.16.0)
# Requirement already satisfied: cryptography>=3.4 in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from jwcrypto<2.0.0,>=1.4->fief-client[cli]->codecarbon) (45.0.6)
# Requirement already satisfied: typing-extensions>=4.5.0 in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from jwcrypto<2.0.0,>=1.4->fief-client[cli]->codecarbon) (4.12.2)
# Requirement already satisfied: cffi>=1.14 in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from cryptography>=3.4->jwcrypto<2.0.0,>=1.4->fief-client[cli]->codecarbon) (1.17.1)
# Requirement already satisfied: pycparser in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from cffi>=1.14->cryptography>=3.4->jwcrypto<2.0.0,>=1.4->fief-client[cli]->codecarbon) (2.22)
# Requirement already satisfied: numpy>=1.23.2 in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from pandas->codecarbon) (2.1.2)
# Requirement already satisfied: pytz>=2020.1 in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from pandas->codecarbon) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from pandas->codecarbon) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from pydantic->codecarbon) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from pydantic->codecarbon) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from pydantic->codecarbon) (0.4.1)
# Requirement already satisfied: nvidia-ml-py<13.0.0a0,>=12.0.0 in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from pynvml->codecarbon) (12.575.51)
# Requirement already satisfied: prompt_toolkit<4.0,>=2.0 in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from questionary->codecarbon) (3.0.51)
# Requirement already satisfied: wcwidth in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from prompt_toolkit<4.0,>=2.0->questionary->codecarbon) (0.2.13)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from requests->codecarbon) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from requests->codecarbon) (2.5.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from rich->codecarbon) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from rich->codecarbon) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->codecarbon) (0.1.2)
# Requirement already satisfied: shellingham>=1.3.0 in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from typer->codecarbon) (1.5.4)
# Requirement already satisfied: termcolor<2.4.0,>=2.2.0 in /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages (from yaspin->fief-client[cli]->codecarbon) (2.3.0)

# %%
import os
import pandas as pd
import torch
from datasets import Dataset
from transformers import (
    AutoTokenizer, AutoModelForCausalLM,
    BitsAndBytesConfig, Trainer, TrainingArguments,
    DataCollatorForLanguageModeling, EarlyStoppingCallback,
    DataCollatorForSeq2Seq
)
from peft import LoraConfig, get_peft_model, prepare_model_for_kbit_training

from peft import PeftModel
import pickle
import time
from codecarbon import EmissionsTracker # para calcular emissões de CO2

# %%
# ------------------
# Configurações
# ------------------
# MODEL_NAME = "meta-llama/Meta-Llama-3-8B"
MODEL_NAME = 'Qwen/Qwen3-14B-Base'
OUTPUT_DIR = "./qlora-aderencia-classes.finetuning"
SEED = 42
LABELS = ["BAIXA", "MÉDIA", "ALTA"]

torch.manual_seed(SEED)
os.environ["TOKENIZERS_PARALLELISM"] = "false"
torch.utils.checkpoint.use_reentrant = False

# ------------------
# Prompt
# ------------------
PROMPT_TMPL = """You are a thematic relevance evaluator.
Classify how related an academic work (title and abstract) is to a strategic theme.

TITLE: {title}
KEYWORDS: {keywords}
ABSTRACT: {abstract}

Answer with a number 0, 1, or 2 for RELEVANCE LEVEL (2-HIGH, 1-MEDIUM, 0-LOW) to the strategic theme: "{category}".

ANSWER: """

# %%
# ------------------
# Criação do Dataset
# ------------------
# ds = Dataset.from_pandas(dados_df[~dados_df.modelo_nivel.isnull()])
# splits = ds.train_test_split(test_size=0.2, seed=SEED)
# split_train = splits["train"]
# split_tmp = splits["test"]

# splits = split_tmp.train_test_split(test_size=0.1, seed=SEED)
# split_eval = splits["train"]
# split_test = splits["test"]

# with open("my_data.pickle", "wb") as file:
#     pickle.dump(split_train, file)
#     pickle.dump(split_eval, file)
#     pickle.dump(split_test, file)

# %%
with open("my_data.pickle", "rb") as file:
    split_train = pickle.load(file)
    split_eval = pickle.load(file)
    split_test = pickle.load(file)

# %%
print( len(split_train) , len(split_eval), len(split_test) )
# Out:
# 33620 4203 4203

# %%
# ------------------
# Tokenizer
# ------------------
tok = AutoTokenizer.from_pretrained(MODEL_NAME)
if tok.pad_token is None:
    tok.pad_token = tok.eos_token



# ------------------
# Função de preprocessamento
# ------------------
def preprocess(example, max_input_length=512):
    processed_key_words = '\n- '.join(example["descricao_keyword"].split(';'))
    gold = str(example["modelo_nivel"]).strip().upper()
    if gold == "MEDIA":
        gold = "MÉDIA"
    assert gold in LABELS
    gold_idx = LABELS.index(gold)  # 0,1,2

    # Cria prompt
    prompt = PROMPT_TMPL.format(
        title=example["nome_producao"],
        abstract=example["descricao_abstract"],
        keywords=processed_key_words,
        category=example["tema"]
    )

    # Tokeniza prompt
    input_enc = tok(prompt, truncation=True, max_length=max_input_length, add_special_tokens=False)
    input_ids = input_enc["input_ids"]

    # Token do próximo token (classe)
    label_id = tok(str(gold_idx), add_special_tokens=False)["input_ids"][0]

    # labels: -100 no prompt, token da classe no final
    labels = [-100] * len(input_ids) + [label_id]
    input_ids_full = input_ids + [label_id]
    attention_mask = [1] * len(input_ids_full)

    return {
        "input_ids": input_ids_full,
        "attention_mask": attention_mask,
        "labels": labels
    }

# ------------------
# Criação do Dataset
# ------------------
train_ds = split_train.map(preprocess, batched=False, remove_columns=split_train.column_names)
eval_ds = split_eval.map(preprocess, batched=False, remove_columns=split_eval.column_names)
# Out:
# Map:   0%|          | 0/33620 [00:00<?, ? examples/s]
# Map:   0%|          | 0/4203 [00:00<?, ? examples/s]

# %%
# ------------------
# Modelo base com quantização 4-bit
# ------------------
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.bfloat16 if torch.cuda.is_available() else torch.float32,
)

raw_model = AutoModelForCausalLM.from_pretrained(
    MODEL_NAME,
    device_map="auto",
    trust_remote_code=True,
    quantization_config=bnb_config
)
raw_model = prepare_model_for_kbit_training(raw_model)

print( 'Model loaded in ', raw_model.device)
# Out:
# Loading checkpoint shards:   0%|          | 0/8 [00:00<?, ?it/s]
# Model loaded in  cuda:0

# %%
for name, module in raw_model.named_modules():
    print(name)
# Out:
# model
# model.embed_tokens
# model.layers
# model.layers.0
# model.layers.0.self_attn
# model.layers.0.self_attn.q_proj
# model.layers.0.self_attn.k_proj
# model.layers.0.self_attn.v_proj
# model.layers.0.self_attn.o_proj
# model.layers.0.self_attn.q_norm
# model.layers.0.self_attn.k_norm
# model.layers.0.mlp
# model.layers.0.mlp.gate_proj
# model.layers.0.mlp.up_proj
# model.layers.0.mlp.down_proj
# model.layers.0.mlp.act_fn
# model.layers.0.input_layernorm
# model.layers.0.post_attention_layernorm
# model.layers.1
# model.layers.1.self_attn
# model.layers.1.self_attn.q_proj
# model.layers.1.self_attn.k_proj
# model.layers.1.self_attn.v_proj
# model.layers.1.self_attn.o_proj
# model.layers.1.self_attn.q_norm
# model.layers.1.self_attn.k_norm
# model.layers.1.mlp
# model.layers.1.mlp.gate_proj
# model.layers.1.mlp.up_proj
# model.layers.1.mlp.down_proj
# model.layers.1.mlp.act_fn
# model.layers.1.input_layernorm
# model.layers.1.post_attention_layernorm
# model.layers.2
# model.layers.2.self_attn
# model.layers.2.self_attn.q_proj
# model.layers.2.self_attn.k_proj
# model.layers.2.self_attn.v_proj
# model.layers.2.self_attn.o_proj
# model.layers.2.self_attn.q_norm
# model.layers.2.self_attn.k_norm
# model.layers.2.mlp
# model.layers.2.mlp.gate_proj
# model.layers.2.mlp.up_proj
# model.layers.2.mlp.down_proj
# model.layers.2.mlp.act_fn
# model.layers.2.input_layernorm
# model.layers.2.post_attention_layernorm
# model.layers.3
# model.layers.3.self_attn
# model.layers.3.self_attn.q_proj
# model.layers.3.self_attn.k_proj
# model.layers.3.self_attn.v_proj
# model.layers.3.self_attn.o_proj
# model.layers.3.self_attn.q_norm
# model.layers.3.self_attn.k_norm
# model.layers.3.mlp
# model.layers.3.mlp.gate_proj
# model.layers.3.mlp.up_proj
# model.layers.3.mlp.down_proj
# model.layers.3.mlp.act_fn
# model.layers.3.input_layernorm
# model.layers.3.post_attention_layernorm
# model.layers.4
# model.layers.4.self_attn
# model.layers.4.self_attn.q_proj
# model.layers.4.self_attn.k_proj
# model.layers.4.self_attn.v_proj
# model.layers.4.self_attn.o_proj
# model.layers.4.self_attn.q_norm
# model.layers.4.self_attn.k_norm
# model.layers.4.mlp
# model.layers.4.mlp.gate_proj
# model.layers.4.mlp.up_proj
# model.layers.4.mlp.down_proj
# model.layers.4.mlp.act_fn
# model.layers.4.input_layernorm
# model.layers.4.post_attention_layernorm
# model.layers.5
# model.layers.5.self_attn
# model.layers.5.self_attn.q_proj
# model.layers.5.self_attn.k_proj
# model.layers.5.self_attn.v_proj
# model.layers.5.self_attn.o_proj
# model.layers.5.self_attn.q_norm
# model.layers.5.self_attn.k_norm
# model.layers.5.mlp
# model.layers.5.mlp.gate_proj
# model.layers.5.mlp.up_proj
# model.layers.5.mlp.down_proj
# model.layers.5.mlp.act_fn
# model.layers.5.input_layernorm
# model.layers.5.post_attention_layernorm
# model.layers.6
# model.layers.6.self_attn
# model.layers.6.self_attn.q_proj
# model.layers.6.self_attn.k_proj
# model.layers.6.self_attn.v_proj
# model.layers.6.self_attn.o_proj
# model.layers.6.self_attn.q_norm
# model.layers.6.self_attn.k_norm
# model.layers.6.mlp
# model.layers.6.mlp.gate_proj
# model.layers.6.mlp.up_proj
# model.layers.6.mlp.down_proj
# model.layers.6.mlp.act_fn
# model.layers.6.input_layernorm
# model.layers.6.post_attention_layernorm
# model.layers.7
# model.layers.7.self_attn
# model.layers.7.self_attn.q_proj
# model.layers.7.self_attn.k_proj
# model.layers.7.self_attn.v_proj
# model.layers.7.self_attn.o_proj
# model.layers.7.self_attn.q_norm
# model.layers.7.self_attn.k_norm
# model.layers.7.mlp
# model.layers.7.mlp.gate_proj
# model.layers.7.mlp.up_proj
# model.layers.7.mlp.down_proj
# model.layers.7.mlp.act_fn
# model.layers.7.input_layernorm
# model.layers.7.post_attention_layernorm
# model.layers.8
# model.layers.8.self_attn
# model.layers.8.self_attn.q_proj
# model.layers.8.self_attn.k_proj
# model.layers.8.self_attn.v_proj
# model.layers.8.self_attn.o_proj
# model.layers.8.self_attn.q_norm
# model.layers.8.self_attn.k_norm
# model.layers.8.mlp
# model.layers.8.mlp.gate_proj
# model.layers.8.mlp.up_proj
# model.layers.8.mlp.down_proj
# model.layers.8.mlp.act_fn
# model.layers.8.input_layernorm
# model.layers.8.post_attention_layernorm
# model.layers.9
# model.layers.9.self_attn
# model.layers.9.self_attn.q_proj
# model.layers.9.self_attn.k_proj
# model.layers.9.self_attn.v_proj
# model.layers.9.self_attn.o_proj
# model.layers.9.self_attn.q_norm
# model.layers.9.self_attn.k_norm
# model.layers.9.mlp
# model.layers.9.mlp.gate_proj
# model.layers.9.mlp.up_proj
# model.layers.9.mlp.down_proj
# model.layers.9.mlp.act_fn
# model.layers.9.input_layernorm
# model.layers.9.post_attention_layernorm
# model.layers.10
# model.layers.10.self_attn
# model.layers.10.self_attn.q_proj
# model.layers.10.self_attn.k_proj
# model.layers.10.self_attn.v_proj
# model.layers.10.self_attn.o_proj
# model.layers.10.self_attn.q_norm
# model.layers.10.self_attn.k_norm
# model.layers.10.mlp
# model.layers.10.mlp.gate_proj
# model.layers.10.mlp.up_proj
# model.layers.10.mlp.down_proj
# model.layers.10.mlp.act_fn
# model.layers.10.input_layernorm
# model.layers.10.post_attention_layernorm
# model.layers.11
# model.layers.11.self_attn
# model.layers.11.self_attn.q_proj
# model.layers.11.self_attn.k_proj
# model.layers.11.self_attn.v_proj
# model.layers.11.self_attn.o_proj
# model.layers.11.self_attn.q_norm
# model.layers.11.self_attn.k_norm
# model.layers.11.mlp
# model.layers.11.mlp.gate_proj
# model.layers.11.mlp.up_proj
# model.layers.11.mlp.down_proj
# model.layers.11.mlp.act_fn
# model.layers.11.input_layernorm
# model.layers.11.post_attention_layernorm
# model.layers.12
# model.layers.12.self_attn
# model.layers.12.self_attn.q_proj
# model.layers.12.self_attn.k_proj
# model.layers.12.self_attn.v_proj
# model.layers.12.self_attn.o_proj
# model.layers.12.self_attn.q_norm
# model.layers.12.self_attn.k_norm
# model.layers.12.mlp
# model.layers.12.mlp.gate_proj
# model.layers.12.mlp.up_proj
# model.layers.12.mlp.down_proj
# model.layers.12.mlp.act_fn
# model.layers.12.input_layernorm
# model.layers.12.post_attention_layernorm
# model.layers.13
# model.layers.13.self_attn
# model.layers.13.self_attn.q_proj
# model.layers.13.self_attn.k_proj
# model.layers.13.self_attn.v_proj
# model.layers.13.self_attn.o_proj
# model.layers.13.self_attn.q_norm
# model.layers.13.self_attn.k_norm
# model.layers.13.mlp
# model.layers.13.mlp.gate_proj
# model.layers.13.mlp.up_proj
# model.layers.13.mlp.down_proj
# model.layers.13.mlp.act_fn
# model.layers.13.input_layernorm
# model.layers.13.post_attention_layernorm
# model.layers.14
# model.layers.14.self_attn
# model.layers.14.self_attn.q_proj
# model.layers.14.self_attn.k_proj
# model.layers.14.self_attn.v_proj
# model.layers.14.self_attn.o_proj
# model.layers.14.self_attn.q_norm
# model.layers.14.self_attn.k_norm
# model.layers.14.mlp
# model.layers.14.mlp.gate_proj
# model.layers.14.mlp.up_proj
# model.layers.14.mlp.down_proj
# model.layers.14.mlp.act_fn
# model.layers.14.input_layernorm
# model.layers.14.post_attention_layernorm
# model.layers.15
# model.layers.15.self_attn
# model.layers.15.self_attn.q_proj
# model.layers.15.self_attn.k_proj
# model.layers.15.self_attn.v_proj
# model.layers.15.self_attn.o_proj
# model.layers.15.self_attn.q_norm
# model.layers.15.self_attn.k_norm
# model.layers.15.mlp
# model.layers.15.mlp.gate_proj
# model.layers.15.mlp.up_proj
# model.layers.15.mlp.down_proj
# model.layers.15.mlp.act_fn
# model.layers.15.input_layernorm
# model.layers.15.post_attention_layernorm
# model.layers.16
# model.layers.16.self_attn
# model.layers.16.self_attn.q_proj
# model.layers.16.self_attn.k_proj
# model.layers.16.self_attn.v_proj
# model.layers.16.self_attn.o_proj
# model.layers.16.self_attn.q_norm
# model.layers.16.self_attn.k_norm
# model.layers.16.mlp
# model.layers.16.mlp.gate_proj
# model.layers.16.mlp.up_proj
# model.layers.16.mlp.down_proj
# model.layers.16.mlp.act_fn
# model.layers.16.input_layernorm
# model.layers.16.post_attention_layernorm
# model.layers.17
# model.layers.17.self_attn
# model.layers.17.self_attn.q_proj
# model.layers.17.self_attn.k_proj
# model.layers.17.self_attn.v_proj
# model.layers.17.self_attn.o_proj
# model.layers.17.self_attn.q_norm
# model.layers.17.self_attn.k_norm
# model.layers.17.mlp
# model.layers.17.mlp.gate_proj
# model.layers.17.mlp.up_proj
# model.layers.17.mlp.down_proj
# model.layers.17.mlp.act_fn
# model.layers.17.input_layernorm
# model.layers.17.post_attention_layernorm
# model.layers.18
# model.layers.18.self_attn
# model.layers.18.self_attn.q_proj
# model.layers.18.self_attn.k_proj
# model.layers.18.self_attn.v_proj
# model.layers.18.self_attn.o_proj
# model.layers.18.self_attn.q_norm
# model.layers.18.self_attn.k_norm
# model.layers.18.mlp
# model.layers.18.mlp.gate_proj
# model.layers.18.mlp.up_proj
# model.layers.18.mlp.down_proj
# model.layers.18.mlp.act_fn
# model.layers.18.input_layernorm
# model.layers.18.post_attention_layernorm
# model.layers.19
# model.layers.19.self_attn
# model.layers.19.self_attn.q_proj
# model.layers.19.self_attn.k_proj
# model.layers.19.self_attn.v_proj
# model.layers.19.self_attn.o_proj
# model.layers.19.self_attn.q_norm
# model.layers.19.self_attn.k_norm
# model.layers.19.mlp
# model.layers.19.mlp.gate_proj
# model.layers.19.mlp.up_proj
# model.layers.19.mlp.down_proj
# model.layers.19.mlp.act_fn
# model.layers.19.input_layernorm
# model.layers.19.post_attention_layernorm
# model.layers.20
# model.layers.20.self_attn
# model.layers.20.self_attn.q_proj
# model.layers.20.self_attn.k_proj
# model.layers.20.self_attn.v_proj
# model.layers.20.self_attn.o_proj
# model.layers.20.self_attn.q_norm
# model.layers.20.self_attn.k_norm
# model.layers.20.mlp
# model.layers.20.mlp.gate_proj
# model.layers.20.mlp.up_proj
# model.layers.20.mlp.down_proj
# model.layers.20.mlp.act_fn
# model.layers.20.input_layernorm
# model.layers.20.post_attention_layernorm
# model.layers.21
# model.layers.21.self_attn
# model.layers.21.self_attn.q_proj
# model.layers.21.self_attn.k_proj
# model.layers.21.self_attn.v_proj
# model.layers.21.self_attn.o_proj
# model.layers.21.self_attn.q_norm
# model.layers.21.self_attn.k_norm
# model.layers.21.mlp
# model.layers.21.mlp.gate_proj
# model.layers.21.mlp.up_proj
# model.layers.21.mlp.down_proj
# model.layers.21.mlp.act_fn
# model.layers.21.input_layernorm
# model.layers.21.post_attention_layernorm
# model.layers.22
# model.layers.22.self_attn
# model.layers.22.self_attn.q_proj
# model.layers.22.self_attn.k_proj
# model.layers.22.self_attn.v_proj
# model.layers.22.self_attn.o_proj
# model.layers.22.self_attn.q_norm
# model.layers.22.self_attn.k_norm
# model.layers.22.mlp
# model.layers.22.mlp.gate_proj
# model.layers.22.mlp.up_proj
# model.layers.22.mlp.down_proj
# model.layers.22.mlp.act_fn
# model.layers.22.input_layernorm
# model.layers.22.post_attention_layernorm
# model.layers.23
# model.layers.23.self_attn
# model.layers.23.self_attn.q_proj
# model.layers.23.self_attn.k_proj
# model.layers.23.self_attn.v_proj
# model.layers.23.self_attn.o_proj
# model.layers.23.self_attn.q_norm
# model.layers.23.self_attn.k_norm
# model.layers.23.mlp
# model.layers.23.mlp.gate_proj
# model.layers.23.mlp.up_proj
# model.layers.23.mlp.down_proj
# model.layers.23.mlp.act_fn
# model.layers.23.input_layernorm
# model.layers.23.post_attention_layernorm
# model.layers.24
# model.layers.24.self_attn
# model.layers.24.self_attn.q_proj
# model.layers.24.self_attn.k_proj
# model.layers.24.self_attn.v_proj
# model.layers.24.self_attn.o_proj
# model.layers.24.self_attn.q_norm
# model.layers.24.self_attn.k_norm
# model.layers.24.mlp
# model.layers.24.mlp.gate_proj
# model.layers.24.mlp.up_proj
# model.layers.24.mlp.down_proj
# model.layers.24.mlp.act_fn
# model.layers.24.input_layernorm
# model.layers.24.post_attention_layernorm
# model.layers.25
# model.layers.25.self_attn
# model.layers.25.self_attn.q_proj
# model.layers.25.self_attn.k_proj
# model.layers.25.self_attn.v_proj
# model.layers.25.self_attn.o_proj
# model.layers.25.self_attn.q_norm
# model.layers.25.self_attn.k_norm
# model.layers.25.mlp
# model.layers.25.mlp.gate_proj
# model.layers.25.mlp.up_proj
# model.layers.25.mlp.down_proj
# model.layers.25.mlp.act_fn
# model.layers.25.input_layernorm
# model.layers.25.post_attention_layernorm
# model.layers.26
# model.layers.26.self_attn
# model.layers.26.self_attn.q_proj
# model.layers.26.self_attn.k_proj
# model.layers.26.self_attn.v_proj
# model.layers.26.self_attn.o_proj
# model.layers.26.self_attn.q_norm
# model.layers.26.self_attn.k_norm
# model.layers.26.mlp
# model.layers.26.mlp.gate_proj
# model.layers.26.mlp.up_proj
# model.layers.26.mlp.down_proj
# model.layers.26.mlp.act_fn
# model.layers.26.input_layernorm
# model.layers.26.post_attention_layernorm
# model.layers.27
# model.layers.27.self_attn
# model.layers.27.self_attn.q_proj
# model.layers.27.self_attn.k_proj
# model.layers.27.self_attn.v_proj
# model.layers.27.self_attn.o_proj
# model.layers.27.self_attn.q_norm
# model.layers.27.self_attn.k_norm
# model.layers.27.mlp
# model.layers.27.mlp.gate_proj
# model.layers.27.mlp.up_proj
# model.layers.27.mlp.down_proj
# model.layers.27.mlp.act_fn
# model.layers.27.input_layernorm
# model.layers.27.post_attention_layernorm
# model.layers.28
# model.layers.28.self_attn
# model.layers.28.self_attn.q_proj
# model.layers.28.self_attn.k_proj
# model.layers.28.self_attn.v_proj
# model.layers.28.self_attn.o_proj
# model.layers.28.self_attn.q_norm
# model.layers.28.self_attn.k_norm
# model.layers.28.mlp
# model.layers.28.mlp.gate_proj
# model.layers.28.mlp.up_proj
# model.layers.28.mlp.down_proj
# model.layers.28.mlp.act_fn
# model.layers.28.input_layernorm
# model.layers.28.post_attention_layernorm
# model.layers.29
# model.layers.29.self_attn
# model.layers.29.self_attn.q_proj
# model.layers.29.self_attn.k_proj
# model.layers.29.self_attn.v_proj
# model.layers.29.self_attn.o_proj
# model.layers.29.self_attn.q_norm
# model.layers.29.self_attn.k_norm
# model.layers.29.mlp
# model.layers.29.mlp.gate_proj
# model.layers.29.mlp.up_proj
# model.layers.29.mlp.down_proj
# model.layers.29.mlp.act_fn
# model.layers.29.input_layernorm
# model.layers.29.post_attention_layernorm
# model.layers.30
# model.layers.30.self_attn
# model.layers.30.self_attn.q_proj
# model.layers.30.self_attn.k_proj
# model.layers.30.self_attn.v_proj
# model.layers.30.self_attn.o_proj
# model.layers.30.self_attn.q_norm
# model.layers.30.self_attn.k_norm
# model.layers.30.mlp
# model.layers.30.mlp.gate_proj
# model.layers.30.mlp.up_proj
# model.layers.30.mlp.down_proj
# model.layers.30.mlp.act_fn
# model.layers.30.input_layernorm
# model.layers.30.post_attention_layernorm
# model.layers.31
# model.layers.31.self_attn
# model.layers.31.self_attn.q_proj
# model.layers.31.self_attn.k_proj
# model.layers.31.self_attn.v_proj
# model.layers.31.self_attn.o_proj
# model.layers.31.self_attn.q_norm
# model.layers.31.self_attn.k_norm
# model.layers.31.mlp
# model.layers.31.mlp.gate_proj
# model.layers.31.mlp.up_proj
# model.layers.31.mlp.down_proj
# model.layers.31.mlp.act_fn
# model.layers.31.input_layernorm
# model.layers.31.post_attention_layernorm
# model.layers.32
# model.layers.32.self_attn
# model.layers.32.self_attn.q_proj
# model.layers.32.self_attn.k_proj
# model.layers.32.self_attn.v_proj
# model.layers.32.self_attn.o_proj
# model.layers.32.self_attn.q_norm
# model.layers.32.self_attn.k_norm
# model.layers.32.mlp
# model.layers.32.mlp.gate_proj
# model.layers.32.mlp.up_proj
# model.layers.32.mlp.down_proj
# model.layers.32.mlp.act_fn
# model.layers.32.input_layernorm
# model.layers.32.post_attention_layernorm
# model.layers.33
# model.layers.33.self_attn
# model.layers.33.self_attn.q_proj
# model.layers.33.self_attn.k_proj
# model.layers.33.self_attn.v_proj
# model.layers.33.self_attn.o_proj
# model.layers.33.self_attn.q_norm
# model.layers.33.self_attn.k_norm
# model.layers.33.mlp
# model.layers.33.mlp.gate_proj
# model.layers.33.mlp.up_proj
# model.layers.33.mlp.down_proj
# model.layers.33.mlp.act_fn
# model.layers.33.input_layernorm
# model.layers.33.post_attention_layernorm
# model.layers.34
# model.layers.34.self_attn
# model.layers.34.self_attn.q_proj
# model.layers.34.self_attn.k_proj
# model.layers.34.self_attn.v_proj
# model.layers.34.self_attn.o_proj
# model.layers.34.self_attn.q_norm
# model.layers.34.self_attn.k_norm
# model.layers.34.mlp
# model.layers.34.mlp.gate_proj
# model.layers.34.mlp.up_proj
# model.layers.34.mlp.down_proj
# model.layers.34.mlp.act_fn
# model.layers.34.input_layernorm
# model.layers.34.post_attention_layernorm
# model.layers.35
# model.layers.35.self_attn
# model.layers.35.self_attn.q_proj
# model.layers.35.self_attn.k_proj
# model.layers.35.self_attn.v_proj
# model.layers.35.self_attn.o_proj
# model.layers.35.self_attn.q_norm
# model.layers.35.self_attn.k_norm
# model.layers.35.mlp
# model.layers.35.mlp.gate_proj
# model.layers.35.mlp.up_proj
# model.layers.35.mlp.down_proj
# model.layers.35.mlp.act_fn
# model.layers.35.input_layernorm
# model.layers.35.post_attention_layernorm
# model.layers.36
# model.layers.36.self_attn
# model.layers.36.self_attn.q_proj
# model.layers.36.self_attn.k_proj
# model.layers.36.self_attn.v_proj
# model.layers.36.self_attn.o_proj
# model.layers.36.self_attn.q_norm
# model.layers.36.self_attn.k_norm
# model.layers.36.mlp
# model.layers.36.mlp.gate_proj
# model.layers.36.mlp.up_proj
# model.layers.36.mlp.down_proj
# model.layers.36.mlp.act_fn
# model.layers.36.input_layernorm
# model.layers.36.post_attention_layernorm
# model.layers.37
# model.layers.37.self_attn
# model.layers.37.self_attn.q_proj
# model.layers.37.self_attn.k_proj
# model.layers.37.self_attn.v_proj
# model.layers.37.self_attn.o_proj
# model.layers.37.self_attn.q_norm
# model.layers.37.self_attn.k_norm
# model.layers.37.mlp
# model.layers.37.mlp.gate_proj
# model.layers.37.mlp.up_proj
# model.layers.37.mlp.down_proj
# model.layers.37.mlp.act_fn
# model.layers.37.input_layernorm
# model.layers.37.post_attention_layernorm
# model.layers.38
# model.layers.38.self_attn
# model.layers.38.self_attn.q_proj
# model.layers.38.self_attn.k_proj
# model.layers.38.self_attn.v_proj
# model.layers.38.self_attn.o_proj
# model.layers.38.self_attn.q_norm
# model.layers.38.self_attn.k_norm
# model.layers.38.mlp
# model.layers.38.mlp.gate_proj
# model.layers.38.mlp.up_proj
# model.layers.38.mlp.down_proj
# model.layers.38.mlp.act_fn
# model.layers.38.input_layernorm
# model.layers.38.post_attention_layernorm
# model.layers.39
# model.layers.39.self_attn
# model.layers.39.self_attn.q_proj
# model.layers.39.self_attn.k_proj
# model.layers.39.self_attn.v_proj
# model.layers.39.self_attn.o_proj
# model.layers.39.self_attn.q_norm
# model.layers.39.self_attn.k_norm
# model.layers.39.mlp
# model.layers.39.mlp.gate_proj
# model.layers.39.mlp.up_proj
# model.layers.39.mlp.down_proj
# model.layers.39.mlp.act_fn
# model.layers.39.input_layernorm
# model.layers.39.post_attention_layernorm
# model.norm
# model.rotary_emb
# lm_head

# %%
# ------------------
# LoRA
# ------------------

# pegar nomes das últimas camadas
n_last = 4
num_total_layers = len(raw_model.model.layers)
target_modules = []
for i in range(num_total_layers - n_last, num_total_layers):
    for proj in ["q_proj", "k_proj", "v_proj", "o_proj"]:
        target_modules.append(f"model.layers.{i}.self_attn.{proj}")
    for proj in ["up_proj", "down_proj"]:  # se quiser também adaptar o MLP
        target_modules.append(f"model.layers.{i}.mlp.{proj}")
print( target_modules )
# Out:
# ['model.layers.36.self_attn.q_proj', 'model.layers.36.self_attn.k_proj', 'model.layers.36.self_attn.v_proj', 'model.layers.36.self_attn.o_proj', 'model.layers.36.mlp.up_proj', 'model.layers.36.mlp.down_proj', 'model.layers.37.self_attn.q_proj', 'model.layers.37.self_attn.k_proj', 'model.layers.37.self_attn.v_proj', 'model.layers.37.self_attn.o_proj', 'model.layers.37.mlp.up_proj', 'model.layers.37.mlp.down_proj', 'model.layers.38.self_attn.q_proj', 'model.layers.38.self_attn.k_proj', 'model.layers.38.self_attn.v_proj', 'model.layers.38.self_attn.o_proj', 'model.layers.38.mlp.up_proj', 'model.layers.38.mlp.down_proj', 'model.layers.39.self_attn.q_proj', 'model.layers.39.self_attn.k_proj', 'model.layers.39.self_attn.v_proj', 'model.layers.39.self_attn.o_proj', 'model.layers.39.mlp.up_proj', 'model.layers.39.mlp.down_proj']

# %%
lora_config = LoraConfig(
    r=16,
    lora_alpha=16,
    lora_dropout=0.05,
    bias="none",
    task_type="CAUSAL_LM",
    target_modules=target_modules
)
model = get_peft_model(raw_model, lora_config)

# %%
import torch

if torch.cuda.is_available():
    print("Dispositivo:", torch.cuda.get_device_name(0))
    print("Suporta bf16?", torch.cuda.is_bf16_supported())
else:
    print("Nenhuma GPU disponível")
# Out:
# Dispositivo: NVIDIA RTX A5000
# Suporta bf16? True

# %%
def train_all():

    # ------------------
    # Data collator para Causal LM
    # ------------------
    collator = DataCollatorForSeq2Seq(tokenizer=tok, padding=True)

    # ------------------
    # TrainingArguments
    # ------------------
    args = TrainingArguments(
        output_dir=OUTPUT_DIR,
        num_train_epochs=10,
        per_device_train_batch_size=3,
        per_device_eval_batch_size=4,
        gradient_accumulation_steps=10,
        learning_rate=2e-4,
        warmup_ratio=0.03,
        logging_steps=20,
        eval_strategy="epoch",
        save_strategy="epoch",
        save_total_limit=2,
        bf16=torch.cuda.is_available(),
        optim="paged_adamw_32bit",
        seed=SEED,
        report_to="none",
        dataloader_num_workers=4,
        load_best_model_at_end=True,
        metric_for_best_model="loss",
        greater_is_better=False
    )

    # ------------------
    # Trainer
    # ------------------
    trainer = Trainer(
        model=model,
        args=args,
        train_dataset=train_ds,
        eval_dataset=eval_ds,
        tokenizer=tok,
        data_collator=collator,
        callbacks=[EarlyStoppingCallback(early_stopping_patience=2)]
    )

    # ------------------
    # Treino
    # ------------------
    start_time = time.time()
    tracker = EmissionsTracker( output_file='fine_tuning_emissions_trainer.csv', log_level='warning' )
    tracker.start()

    trainer.train()

    emissions: float = tracker.stop()
    print("\n\nTotal de emissões (detalhes em emissions.csv): ",emissions)


    end_time = time.time()
    elapsed_time = end_time - start_time
    print(f"\nTempo total de execução: {elapsed_time:.2f} segundos")


    trainer.save_model(OUTPUT_DIR)
    tok.save_pretrained(OUTPUT_DIR)

    print("Treino finalizado. Modelo salvo em", OUTPUT_DIR)


# train_all()
# Out:
# /tmp/ipykernel_3679292/424385354.py:36: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
# [codecarbon WARNING @ 10:08:40] Multiple instances of codecarbon are allowed to run at the same time.
# [codecarbon WARNING @ 10:08:41] We saw that you have a Intel(R) Core(TM) i9-14900KF but we don't know it. Please contact us.
# [codecarbon WARNING @ 10:08:41] We will use the default power consumption of 4 W per thread for your 32 CPU, so 128W.
# [codecarbon WARNING @ 10:08:41] No CPU tracking mode found. Falling back on estimation based on TDP for CPU.
#  Linux OS detected: Please ensure RAPL files exist at /sys/class/powercap/intel-rapl/subsystem to measure CPU
#
# [codecarbon WARNING @ 10:08:41] No CPU tracking mode found. Falling back on CPU load mode.
# `use_cache=True` is incompatible with gradient checkpointing. Setting `use_cache=False`.
# /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
#     <div>
#
#       <progress value='5605' max='11210' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 5605/11210 55:08:02 < 55:09:13, 0.03 it/s, Epoch 5/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.001300</td>
#       <td>0.999635</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.980500</td>
#       <td>0.956015</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.888900</td>
#       <td>0.945894</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.806600</td>
#       <td>0.999856</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.758400</td>
#       <td>1.104736</td>
#     </tr>
#   </tbody>
# </table><p>
# /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /home/rvsantin/miniconda3/envs/challenge_bonito/lib/python3.11/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# Total de emissões (detalhes em emissions.csv):  1.500121978759484
#
# Tempo total de execução: 198521.63 segundos
# Treino finalizado. Modelo salvo em ./qlora-aderencia-classes.finetuning

# %%
del model
del raw_model
# del trainer
torch.cuda.empty_cache()

# %%
checkpoint_dir= os.path.join(OUTPUT_DIR, "checkpoint-3363")  # ajuste conforme necessário
# ------------------
# Modelo base com quantização 4-bit
# ------------------
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.bfloat16 if torch.cuda.is_available() else torch.float32,
)

model = AutoModelForCausalLM.from_pretrained(
    MODEL_NAME,
    device_map="auto",
    trust_remote_code=True,
    quantization_config=bnb_config
)

# Aplicar o LoRA / PEFT checkpoint
model = PeftModel.from_pretrained(
    model,
    checkpoint_dir,
    device_map="auto",           # mantém a mesma distribuição
)

tok = AutoTokenizer.from_pretrained(checkpoint_dir)
# Out:
# Loading checkpoint shards:   0%|          | 0/8 [00:00<?, ?it/s]

# %%
model.device
# Out:
# device(type='cuda', index=0)

# %%
# ------------------
# Predict (next token)
# ------------------
import torch
import torch.nn.functional as F

# tokens de interesse
target_tokens = [tok.encode("0", add_special_tokens=False)[0], tok.encode("1", add_special_tokens=False)[0], tok.encode("2", add_special_tokens=False)[0]]

def predict_class(prompt_text):
    # tokeniza
    tokenized = tok(prompt_text, return_tensors="pt")
    input_ids = tokenized.input_ids.cuda()
    attention_mask = tokenized.attention_mask.cuda()

    # forward no modelo (sem generate)
    with torch.no_grad():
        outputs = model(input_ids=input_ids, attention_mask=attention_mask)
        # logits do último token
        last_token_logits = outputs.logits[0, -1, :]
        # softmax para probabilidades
        probs = F.softmax(last_token_logits, dim=-1)

    # pegar probabilidades apenas para os tokens 0,1,2
    target_probs = {tok.decode([t]): probs[t].item() for t in target_tokens}

    # escolher token mais provável
    pred_token = max(target_probs, key=target_probs.get)

    return pred_token, target_probs


# Exemplo
example = split_test[0]
processed_key_words = '\n- '.join(example["descricao_keyword"].split(';'))

    # Cria prompt
example_prompt = PROMPT_TMPL.format(
        title=example["nome_producao"],
        abstract=example["descricao_abstract"],
        keywords=processed_key_words,
        category=example["tema"]
    )
print("Predicted class:", predict_class(example_prompt))
# Out:
# Predicted class: ('2', {'0': 0.1593017578125, '1': 0.29296875, '2': 0.54736328125})

# %%
from sklearn.metrics import accuracy_score, f1_score, classification_report
from tqdm import tqdm
# from codecarbon import EmissionsTracker # para calcular emissões de CO2
tracker = EmissionsTracker( output_file='fine_tuning_emissions.csv' )
tracker.start()

y_true = []
y_pred = []

# .select(range(30))

start_time = time.time()

for example in tqdm(split_test, desc="Inferindo"):  # percorre todo o dataset de teste
    # ---------------------
    # Prepara prompt
    processed_key_words = '\n- '.join(example["descricao_keyword"].split(';'))
    example_prompt = PROMPT_TMPL.format(
        title=example["nome_producao"],
        abstract=example["descricao_abstract"],
        keywords=processed_key_words,
        category=example["tema"]
    )

    # Predição
    pred = predict_class(example_prompt)
    y_pred.append(["0","1","2"].index(pred[0]))

    # Rótulo real
    gold = str(example["modelo_nivel"]).strip().upper()
    if gold == "MEDIA":
        gold = "MÉDIA"
    assert gold in LABELS
    y_true.append(LABELS.index(gold))

# Marca o tempo final
end_time = time.time()

# Tempo total em segundos
elapsed_time = end_time - start_time
print(f"\nTempo total de execução: {elapsed_time:.2f} segundos")


emissions: float = tracker.stop()
print("\n\nTotal de emissões (detalhes em emissions.csv): ",emissions)

# ---------------------
# Métricas
acc = accuracy_score(y_true, y_pred)
f1_macro = f1_score(y_true, y_pred, average="macro")
f1_weighted = f1_score(y_true, y_pred, average="weighted")

print("Acurácia:", acc)
print("F1-macro:", f1_macro)
print("F1-weighted:", f1_weighted)

# Relatório detalhado (por classe)
print("\nRelatório de classificação:")
print(classification_report(y_true, y_pred, target_names=LABELS))
# Out:
# [codecarbon WARNING @ 18:04:46] Multiple instances of codecarbon are allowed to run at the same time.
# [codecarbon INFO @ 18:04:46] [setup] RAM Tracking...
# [codecarbon INFO @ 18:04:46] [setup] CPU Tracking...
# [codecarbon WARNING @ 18:04:47] We saw that you have a Intel(R) Core(TM) i9-14900KF but we don't know it. Please contact us.
# [codecarbon WARNING @ 18:04:47] We will use the default power consumption of 4 W per thread for your 32 CPU, so 128W.
# [codecarbon WARNING @ 18:04:47] No CPU tracking mode found. Falling back on estimation based on TDP for CPU.
#  Linux OS detected: Please ensure RAPL files exist at /sys/class/powercap/intel-rapl/subsystem to measure CPU
#
# [codecarbon INFO @ 18:04:47] CPU Model on constant consumption mode: Intel(R) Core(TM) i9-14900KF
# [codecarbon WARNING @ 18:04:47] No CPU tracking mode found. Falling back on CPU load mode.
# [codecarbon INFO @ 18:04:47] [setup] GPU Tracking...
# [codecarbon INFO @ 18:04:47] Tracking Nvidia GPU via pynvml
# [codecarbon INFO @ 18:04:47] The below tracking methods have been set up:
#                 RAM Tracking Method: RAM power estimation model
#                 CPU Tracking Method: cpu_load
#                 GPU Tracking Method: pynvml
#
# [codecarbon INFO @ 18:04:47] >>> Tracker's metadata:
# [codecarbon INFO @ 18:04:47]   Platform system: Linux-6.9.3-76060903-generic-x86_64-with-glibc2.35
# [codecarbon INFO @ 18:04:47]   Python version: 3.11.5
# [codecarbon INFO @ 18:04:47]   CodeCarbon version: 3.0.4
# [codecarbon INFO @ 18:04:47]   Available RAM : 125.634 GB
# [codecarbon INFO @ 18:04:47]   CPU count: 32 thread(s) in 1 physical CPU(s)
# [codecarbon INFO @ 18:04:47]   CPU model: Intel(R) Core(TM) i9-14900KF
# [codecarbon INFO @ 18:04:47]   GPU count: 1
# [codecarbon INFO @ 18:04:47]   GPU model: 1 x NVIDIA RTX A5000
# [codecarbon INFO @ 18:04:49] Emissions data (if any) will be saved to file /exp/rvsantin/projetos/challenge_bonito/fine_tuning_emissions.csv
# Inferindo:   1%|          | 24/4203 [00:14<38:02,  1.83it/s][codecarbon INFO @ 18:05:05] Energy consumed for RAM : 0.000164 kWh. RAM Power : 38.0 W
# Inferindo:   1%|          | 25/4203 [00:15<38:25,  1.81it/s][codecarbon INFO @ 18:05:05] Delta energy consumed for CPU with cpu_load : 0.000055 kWh, power : 12.859446018560002 W
# [codecarbon INFO @ 18:05:05] Energy consumed for All CPU : 0.000055 kWh
# [codecarbon INFO @ 18:05:05] Energy consumed for all GPUs : 0.000980 kWh. Total GPU Power : 220.41231330766144 W
# [codecarbon INFO @ 18:05:05] 0.001199 kWh of electricity used since the beginning.
# Inferindo:   1%|          | 48/4203 [00:29<44:06,  1.57it/s][codecarbon INFO @ 18:05:20] Energy consumed for RAM : 0.000317 kWh. RAM Power : 38.0 W
# Inferindo:   1%|          | 49/4203 [00:30<46:42,  1.48it/s][codecarbon INFO @ 18:05:20] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.851864847200003 W
# [codecarbon INFO @ 18:05:20] Energy consumed for All CPU : 0.000107 kWh
# [codecarbon INFO @ 18:05:20] Energy consumed for all GPUs : 0.001930 kWh. Total GPU Power : 228.1114605289466 W
# [codecarbon INFO @ 18:05:20] 0.002354 kWh of electricity used since the beginning.
# Inferindo:   2%|▏         | 71/4203 [00:44<44:46,  1.54it/s][codecarbon INFO @ 18:05:35] Energy consumed for RAM : 0.000470 kWh. RAM Power : 38.0 W
# Inferindo:   2%|▏         | 72/4203 [00:45<42:23,  1.62it/s][codecarbon INFO @ 18:05:35] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.848237213600001 W
# [codecarbon INFO @ 18:05:35] Energy consumed for All CPU : 0.000159 kWh
# [codecarbon INFO @ 18:05:35] Energy consumed for all GPUs : 0.002885 kWh. Total GPU Power : 229.15825948473946 W
# [codecarbon INFO @ 18:05:35] 0.003513 kWh of electricity used since the beginning.
# Inferindo:   2%|▏         | 93/4203 [00:59<46:04,  1.49it/s][codecarbon INFO @ 18:05:50] Energy consumed for RAM : 0.000623 kWh. RAM Power : 38.0 W
# Inferindo:   2%|▏         | 94/4203 [01:00<48:03,  1.42it/s][codecarbon INFO @ 18:05:50] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.858326775200004 W
# [codecarbon INFO @ 18:05:50] Energy consumed for All CPU : 0.000211 kWh
# [codecarbon INFO @ 18:05:50] Energy consumed for all GPUs : 0.003843 kWh. Total GPU Power : 229.9481563229414 W
# [codecarbon INFO @ 18:05:50] 0.004676 kWh of electricity used since the beginning.
# Inferindo:   3%|▎         | 115/4203 [01:14<44:37,  1.53it/s][codecarbon INFO @ 18:06:05] Energy consumed for RAM : 0.000776 kWh. RAM Power : 38.0 W
# Inferindo:   3%|▎         | 116/4203 [01:15<48:10,  1.41it/s][codecarbon INFO @ 18:06:05] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.855990324800002 W
# [codecarbon INFO @ 18:06:05] Energy consumed for All CPU : 0.000262 kWh
# [codecarbon INFO @ 18:06:05] Energy consumed for all GPUs : 0.004795 kWh. Total GPU Power : 228.42272623888888 W
# [codecarbon INFO @ 18:06:05] 0.005833 kWh of electricity used since the beginning.
# Inferindo:   3%|▎         | 138/4203 [01:29<46:54,  1.44it/s][codecarbon INFO @ 18:06:20] Energy consumed for RAM : 0.000929 kWh. RAM Power : 38.0 W
# Inferindo:   3%|▎         | 139/4203 [01:30<44:51,  1.51it/s][codecarbon INFO @ 18:06:20] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.852133738400003 W
# [codecarbon INFO @ 18:06:20] Energy consumed for All CPU : 0.000314 kWh
# [codecarbon INFO @ 18:06:20] Energy consumed for all GPUs : 0.005751 kWh. Total GPU Power : 229.5545938554872 W
# [codecarbon INFO @ 18:06:20] 0.006994 kWh of electricity used since the beginning.
# Inferindo:   4%|▍         | 161/4203 [01:44<47:06,  1.43it/s][codecarbon INFO @ 18:06:35] Energy consumed for RAM : 0.001082 kWh. RAM Power : 38.0 W
# Inferindo:   4%|▍         | 162/4203 [01:45<46:01,  1.46it/s][codecarbon INFO @ 18:06:35] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.851228252000002 W
# [codecarbon INFO @ 18:06:35] Energy consumed for All CPU : 0.000366 kWh
# [codecarbon INFO @ 18:06:35] Energy consumed for all GPUs : 0.006703 kWh. Total GPU Power : 228.62909299320762 W
# [codecarbon INFO @ 18:06:35] 0.008151 kWh of electricity used since the beginning.
# Inferindo:   4%|▍         | 184/4203 [01:59<42:16,  1.58it/s][codecarbon INFO @ 18:06:50] Energy consumed for RAM : 0.001235 kWh. RAM Power : 38.0 W
# Inferindo:   4%|▍         | 185/4203 [02:00<41:17,  1.62it/s][codecarbon INFO @ 18:06:50] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.854104270400002 W
# [codecarbon INFO @ 18:06:50] Energy consumed for All CPU : 0.000418 kWh
# [codecarbon INFO @ 18:06:50] Energy consumed for all GPUs : 0.007655 kWh. Total GPU Power : 228.34861412952478 W
# [codecarbon INFO @ 18:06:50] 0.009307 kWh of electricity used since the beginning.
# [codecarbon INFO @ 18:06:50] 0.007564 g.CO2eq/s mean an estimation of 238.5393258984284 kg.CO2eq/year
# Inferindo:   5%|▍         | 207/4203 [02:14<43:57,  1.52it/s][codecarbon INFO @ 18:07:05] Energy consumed for RAM : 0.001388 kWh. RAM Power : 38.0 W
# Inferindo:   5%|▍         | 208/4203 [02:15<47:23,  1.40it/s][codecarbon INFO @ 18:07:05] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.847805890400002 W
# [codecarbon INFO @ 18:07:05] Energy consumed for All CPU : 0.000469 kWh
# [codecarbon INFO @ 18:07:05] Energy consumed for all GPUs : 0.008610 kWh. Total GPU Power : 229.3091025365854 W
# [codecarbon INFO @ 18:07:05] 0.010467 kWh of electricity used since the beginning.
# Inferindo:   5%|▌         | 229/4203 [02:29<45:24,  1.46it/s][codecarbon INFO @ 18:07:20] Energy consumed for RAM : 0.001541 kWh. RAM Power : 38.0 W
# Inferindo:   5%|▌         | 230/4203 [02:30<44:33,  1.49it/s][codecarbon INFO @ 18:07:20] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.8520889256 W
# [codecarbon INFO @ 18:07:20] Energy consumed for All CPU : 0.000521 kWh
# [codecarbon INFO @ 18:07:20] Energy consumed for all GPUs : 0.009565 kWh. Total GPU Power : 229.1715751889046 W
# [codecarbon INFO @ 18:07:20] 0.011627 kWh of electricity used since the beginning.
# Inferindo:   6%|▌         | 252/4203 [02:44<44:36,  1.48it/s][codecarbon INFO @ 18:07:35] Energy consumed for RAM : 0.001694 kWh. RAM Power : 38.0 W
# Inferindo:   6%|▌         | 253/4203 [02:45<44:03,  1.49it/s][codecarbon INFO @ 18:07:35] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.8563937048 W
# [codecarbon INFO @ 18:07:35] Energy consumed for All CPU : 0.000573 kWh
# [codecarbon INFO @ 18:07:35] Energy consumed for all GPUs : 0.010517 kWh. Total GPU Power : 228.58685257601303 W
# [codecarbon INFO @ 18:07:35] 0.012784 kWh of electricity used since the beginning.
# Inferindo:   7%|▋         | 275/4203 [02:59<46:23,  1.41it/s][codecarbon INFO @ 18:07:50] Energy consumed for RAM : 0.001847 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 18:07:50] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.861643325600003 W
# [codecarbon INFO @ 18:07:50] Energy consumed for All CPU : 0.000625 kWh
# [codecarbon INFO @ 18:07:50] Energy consumed for all GPUs : 0.011469 kWh. Total GPU Power : 228.50858360708364 W
# [codecarbon INFO @ 18:07:50] 0.013940 kWh of electricity used since the beginning.
# Inferindo:   7%|▋         | 297/4203 [03:14<40:05,  1.62it/s][codecarbon INFO @ 18:08:05] Energy consumed for RAM : 0.002000 kWh. RAM Power : 38.0 W
# Inferindo:   7%|▋         | 298/4203 [03:15<44:20,  1.47it/s][codecarbon INFO @ 18:08:05] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.850276124000004 W
# [codecarbon INFO @ 18:08:05] Energy consumed for All CPU : 0.000676 kWh
# [codecarbon INFO @ 18:08:05] Energy consumed for all GPUs : 0.012425 kWh. Total GPU Power : 229.44050251435323 W
# [codecarbon INFO @ 18:08:05] 0.015101 kWh of electricity used since the beginning.
# Inferindo:   8%|▊         | 317/4203 [03:29<40:32,  1.60it/s]  [codecarbon INFO @ 18:08:20] Energy consumed for RAM : 0.002153 kWh. RAM Power : 38.0 W
# Inferindo:   8%|▊         | 318/4203 [03:30<38:53,  1.67it/s][codecarbon INFO @ 18:08:20] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.854097034400002 W
# [codecarbon INFO @ 18:08:20] Energy consumed for All CPU : 0.000728 kWh
# [codecarbon INFO @ 18:08:20] Energy consumed for all GPUs : 0.013378 kWh. Total GPU Power : 228.80921983091739 W
# [codecarbon INFO @ 18:08:20] 0.016259 kWh of electricity used since the beginning.
# Inferindo:   8%|▊         | 343/4203 [03:44<32:41,  1.97it/s][codecarbon INFO @ 18:08:35] Energy consumed for RAM : 0.002306 kWh. RAM Power : 38.0 W
# Inferindo:   8%|▊         | 344/4203 [03:45<37:57,  1.69it/s][codecarbon INFO @ 18:08:35] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.840357432800003 W
# [codecarbon INFO @ 18:08:35] Energy consumed for All CPU : 0.000780 kWh
# [codecarbon INFO @ 18:08:35] Energy consumed for all GPUs : 0.014331 kWh. Total GPU Power : 228.81651593083365 W
# [codecarbon INFO @ 18:08:35] 0.017417 kWh of electricity used since the beginning.
# Inferindo:   9%|▊         | 367/4203 [03:59<42:07,  1.52it/s][codecarbon INFO @ 18:08:50] Energy consumed for RAM : 0.002459 kWh. RAM Power : 38.0 W
# Inferindo:   9%|▉         | 368/4203 [04:00<41:56,  1.52it/s][codecarbon INFO @ 18:08:50] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.840288348800003 W
# [codecarbon INFO @ 18:08:50] Energy consumed for All CPU : 0.000832 kWh
# [codecarbon INFO @ 18:08:50] Energy consumed for all GPUs : 0.015284 kWh. Total GPU Power : 228.55072906610923 W
# [codecarbon INFO @ 18:08:50] 0.018574 kWh of electricity used since the beginning.
# [codecarbon INFO @ 18:08:50] 0.007595 g.CO2eq/s mean an estimation of 239.50255209569934 kg.CO2eq/year
# Inferindo:   9%|▉         | 393/4203 [04:14<34:45,  1.83it/s][codecarbon INFO @ 18:09:05] Energy consumed for RAM : 0.002612 kWh. RAM Power : 38.0 W
# Inferindo:   9%|▉         | 394/4203 [04:15<35:55,  1.77it/s][codecarbon INFO @ 18:09:05] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.842483189600001 W
# [codecarbon INFO @ 18:09:05] Energy consumed for All CPU : 0.000883 kWh
# [codecarbon INFO @ 18:09:05] Energy consumed for all GPUs : 0.016237 kWh. Total GPU Power : 228.814408114496 W
# [codecarbon INFO @ 18:09:05] 0.019732 kWh of electricity used since the beginning.
# Inferindo:  10%|▉         | 417/4203 [04:29<40:16,  1.57it/s][codecarbon INFO @ 18:09:20] Energy consumed for RAM : 0.002765 kWh. RAM Power : 38.0 W
# Inferindo:  10%|▉         | 418/4203 [04:30<41:37,  1.52it/s][codecarbon INFO @ 18:09:20] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.836949716000003 W
# [codecarbon INFO @ 18:09:20] Energy consumed for All CPU : 0.000935 kWh
# [codecarbon INFO @ 18:09:20] Energy consumed for all GPUs : 0.017190 kWh. Total GPU Power : 228.86831623486438 W
# [codecarbon INFO @ 18:09:20] 0.020890 kWh of electricity used since the beginning.
# Inferindo:  11%|█         | 442/4203 [04:44<40:48,  1.54it/s][codecarbon INFO @ 18:09:35] Energy consumed for RAM : 0.002918 kWh. RAM Power : 38.0 W
# Inferindo:  11%|█         | 443/4203 [04:45<41:51,  1.50it/s][codecarbon INFO @ 18:09:35] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.838951524800004 W
# [codecarbon INFO @ 18:09:35] Energy consumed for All CPU : 0.000987 kWh
# [codecarbon INFO @ 18:09:35] Energy consumed for all GPUs : 0.018143 kWh. Total GPU Power : 228.8214321106538 W
# [codecarbon INFO @ 18:09:35] 0.022048 kWh of electricity used since the beginning.
# Inferindo:  11%|█         | 467/4203 [04:59<37:20,  1.67it/s][codecarbon INFO @ 18:09:50] Energy consumed for RAM : 0.003071 kWh. RAM Power : 38.0 W
# Inferindo:  11%|█         | 468/4203 [05:00<35:23,  1.76it/s][codecarbon INFO @ 18:09:50] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.8408233376 W
# [codecarbon INFO @ 18:09:50] Energy consumed for All CPU : 0.001038 kWh
# [codecarbon INFO @ 18:09:50] Energy consumed for all GPUs : 0.019097 kWh. Total GPU Power : 228.8435978001087 W
# [codecarbon INFO @ 18:09:50] 0.023206 kWh of electricity used since the beginning.
# Inferindo:  12%|█▏        | 491/4203 [05:14<45:28,  1.36it/s][codecarbon INFO @ 18:10:05] Energy consumed for RAM : 0.003224 kWh. RAM Power : 38.0 W
# Inferindo:  12%|█▏        | 492/4203 [05:15<43:19,  1.43it/s][codecarbon INFO @ 18:10:05] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.845384854399999 W
# [codecarbon INFO @ 18:10:05] Energy consumed for All CPU : 0.001090 kWh
# [codecarbon INFO @ 18:10:05] Energy consumed for all GPUs : 0.020049 kWh. Total GPU Power : 228.63875760455582 W
# [codecarbon INFO @ 18:10:05] 0.024363 kWh of electricity used since the beginning.
# Inferindo:  12%|█▏        | 515/4203 [05:29<38:48,  1.58it/s][codecarbon INFO @ 18:10:20] Energy consumed for RAM : 0.003377 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 18:10:20] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.839108355200004 W
# [codecarbon INFO @ 18:10:20] Energy consumed for All CPU : 0.001142 kWh
# [codecarbon INFO @ 18:10:20] Energy consumed for all GPUs : 0.021004 kWh. Total GPU Power : 229.0640200866626 W
# [codecarbon INFO @ 18:10:20] 0.025522 kWh of electricity used since the beginning.
# Inferindo:  13%|█▎        | 537/4203 [05:44<38:22,  1.59it/s][codecarbon INFO @ 18:10:35] Energy consumed for RAM : 0.003530 kWh. RAM Power : 38.0 W
# Inferindo:  13%|█▎        | 538/4203 [05:45<39:51,  1.53it/s][codecarbon INFO @ 18:10:35] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.838411438400003 W
# [codecarbon INFO @ 18:10:35] Energy consumed for All CPU : 0.001194 kWh
# [codecarbon INFO @ 18:10:35] Energy consumed for all GPUs : 0.021957 kWh. Total GPU Power : 228.77275153403892 W
# [codecarbon INFO @ 18:10:35] 0.026680 kWh of electricity used since the beginning.
# Inferindo:  13%|█▎        | 562/4203 [05:59<34:39,  1.75it/s][codecarbon INFO @ 18:10:50] Energy consumed for RAM : 0.003683 kWh. RAM Power : 38.0 W
# Inferindo:  13%|█▎        | 563/4203 [06:00<31:19,  1.94it/s][codecarbon INFO @ 18:10:50] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.8572015952 W
# [codecarbon INFO @ 18:10:50] Energy consumed for All CPU : 0.001245 kWh
# [codecarbon INFO @ 18:10:50] Energy consumed for all GPUs : 0.022916 kWh. Total GPU Power : 230.34055637032102 W
# [codecarbon INFO @ 18:10:50] 0.027845 kWh of electricity used since the beginning.
# [codecarbon INFO @ 18:10:50] 0.007598 g.CO2eq/s mean an estimation of 239.5956167292833 kg.CO2eq/year
# Inferindo:  14%|█▍        | 587/4203 [06:14<34:42,  1.74it/s][codecarbon INFO @ 18:11:05] Energy consumed for RAM : 0.003836 kWh. RAM Power : 38.0 W
# Inferindo:  14%|█▍        | 588/4203 [06:15<38:26,  1.57it/s][codecarbon INFO @ 18:11:05] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.847890893600002 W
# [codecarbon INFO @ 18:11:05] Energy consumed for All CPU : 0.001297 kWh
# [codecarbon INFO @ 18:11:05] Energy consumed for all GPUs : 0.023869 kWh. Total GPU Power : 228.78488775588545 W
# [codecarbon INFO @ 18:11:05] 0.029002 kWh of electricity used since the beginning.
# Inferindo:  15%|█▍        | 612/4203 [06:29<37:35,  1.59it/s][codecarbon INFO @ 18:11:20] Energy consumed for RAM : 0.003989 kWh. RAM Power : 38.0 W
# Inferindo:  15%|█▍        | 613/4203 [06:30<35:22,  1.69it/s][codecarbon INFO @ 18:11:20] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.8441933264 W
# [codecarbon INFO @ 18:11:20] Energy consumed for All CPU : 0.001349 kWh
# [codecarbon INFO @ 18:11:20] Energy consumed for all GPUs : 0.024822 kWh. Total GPU Power : 228.74288952016602 W
# [codecarbon INFO @ 18:11:20] 0.030160 kWh of electricity used since the beginning.
# Inferindo:  15%|█▌        | 636/4203 [06:44<34:07,  1.74it/s][codecarbon INFO @ 18:11:35] Energy consumed for RAM : 0.004142 kWh. RAM Power : 38.0 W
# Inferindo:  15%|█▌        | 637/4203 [06:45<36:30,  1.63it/s][codecarbon INFO @ 18:11:35] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.8498276792 W
# [codecarbon INFO @ 18:11:35] Energy consumed for All CPU : 0.001401 kWh
# [codecarbon INFO @ 18:11:35] Energy consumed for all GPUs : 0.025776 kWh. Total GPU Power : 228.89307687711775 W
# [codecarbon INFO @ 18:11:35] 0.031318 kWh of electricity used since the beginning.
# Inferindo:  16%|█▌        | 661/4203 [06:59<33:19,  1.77it/s][codecarbon INFO @ 18:11:50] Energy consumed for RAM : 0.004295 kWh. RAM Power : 38.0 W
# Inferindo:  16%|█▌        | 662/4203 [07:00<34:06,  1.73it/s][codecarbon INFO @ 18:11:50] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.8420554736 W
# [codecarbon INFO @ 18:11:50] Energy consumed for All CPU : 0.001452 kWh
# [codecarbon INFO @ 18:11:50] Energy consumed for all GPUs : 0.026729 kWh. Total GPU Power : 228.73971131235763 W
# [codecarbon INFO @ 18:11:50] 0.032476 kWh of electricity used since the beginning.
# Inferindo:  16%|█▋        | 685/4203 [07:14<34:49,  1.68it/s][codecarbon INFO @ 18:12:05] Energy consumed for RAM : 0.004448 kWh. RAM Power : 38.0 W
# Inferindo:  16%|█▋        | 686/4203 [07:15<35:53,  1.63it/s][codecarbon INFO @ 18:12:05] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.841658141600004 W
# [codecarbon INFO @ 18:12:05] Energy consumed for All CPU : 0.001504 kWh
# [codecarbon INFO @ 18:12:05] Energy consumed for all GPUs : 0.027684 kWh. Total GPU Power : 229.28509135525056 W
# [codecarbon INFO @ 18:12:05] 0.033635 kWh of electricity used since the beginning.
# Inferindo:  17%|█▋        | 711/4203 [07:29<28:58,  2.01it/s][codecarbon INFO @ 18:12:20] Energy consumed for RAM : 0.004601 kWh. RAM Power : 38.0 W
# Inferindo:  17%|█▋        | 712/4203 [07:30<31:47,  1.83it/s][codecarbon INFO @ 18:12:20] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.8442340208 W
# [codecarbon INFO @ 18:12:20] Energy consumed for All CPU : 0.001556 kWh
# [codecarbon INFO @ 18:12:20] Energy consumed for all GPUs : 0.028638 kWh. Total GPU Power : 229.10094136454464 W
# [codecarbon INFO @ 18:12:20] 0.034795 kWh of electricity used since the beginning.
# Inferindo:  18%|█▊        | 736/4203 [07:44<31:41,  1.82it/s][codecarbon INFO @ 18:12:35] Energy consumed for RAM : 0.004754 kWh. RAM Power : 38.0 W
# Inferindo:  18%|█▊        | 737/4203 [07:45<31:31,  1.83it/s][codecarbon INFO @ 18:12:35] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.844083800000002 W
# [codecarbon INFO @ 18:12:35] Energy consumed for All CPU : 0.001607 kWh
# [codecarbon INFO @ 18:12:35] Energy consumed for all GPUs : 0.029592 kWh. Total GPU Power : 229.0118956283836 W
# [codecarbon INFO @ 18:12:35] 0.035953 kWh of electricity used since the beginning.
# Inferindo:  18%|█▊        | 762/4203 [07:59<34:35,  1.66it/s][codecarbon INFO @ 18:12:50] Energy consumed for RAM : 0.004907 kWh. RAM Power : 38.0 W
# Inferindo:  18%|█▊        | 764/4203 [08:00<29:46,  1.92it/s][codecarbon INFO @ 18:12:50] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.842472144800002 W
# [codecarbon INFO @ 18:12:50] Energy consumed for All CPU : 0.001659 kWh
# [codecarbon INFO @ 18:12:50] Energy consumed for all GPUs : 0.030546 kWh. Total GPU Power : 228.9671142833444 W
# [codecarbon INFO @ 18:12:50] 0.037112 kWh of electricity used since the beginning.
# [codecarbon INFO @ 18:12:50] 0.007595 g.CO2eq/s mean an estimation of 239.51947056391091 kg.CO2eq/year
# Inferindo:  19%|█▊        | 788/4203 [08:14<32:29,  1.75it/s][codecarbon INFO @ 18:13:05] Energy consumed for RAM : 0.005060 kWh. RAM Power : 38.0 W
# Inferindo:  19%|█▉        | 789/4203 [08:15<31:27,  1.81it/s][codecarbon INFO @ 18:13:05] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.8508397616 W
# [codecarbon INFO @ 18:13:05] Energy consumed for All CPU : 0.001711 kWh
# [codecarbon INFO @ 18:13:05] Energy consumed for all GPUs : 0.031501 kWh. Total GPU Power : 229.15115932349258 W
# [codecarbon INFO @ 18:13:05] 0.038271 kWh of electricity used since the beginning.
# Inferindo:  19%|█▉        | 811/4203 [08:29<36:38,  1.54it/s][codecarbon INFO @ 18:13:20] Energy consumed for RAM : 0.005213 kWh. RAM Power : 38.0 W
# Inferindo:  19%|█▉        | 812/4203 [08:30<39:39,  1.42it/s][codecarbon INFO @ 18:13:20] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.840722285600002 W
# [codecarbon INFO @ 18:13:20] Energy consumed for All CPU : 0.001763 kWh
# [codecarbon INFO @ 18:13:20] Energy consumed for all GPUs : 0.032455 kWh. Total GPU Power : 229.14887646656544 W
# [codecarbon INFO @ 18:13:20] 0.039430 kWh of electricity used since the beginning.
# Inferindo:  20%|█▉        | 836/4203 [08:44<34:16,  1.64it/s][codecarbon INFO @ 18:13:35] Energy consumed for RAM : 0.005366 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 18:13:35] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.841946695999999 W
# [codecarbon INFO @ 18:13:35] Energy consumed for All CPU : 0.001814 kWh
# [codecarbon INFO @ 18:13:35] Energy consumed for all GPUs : 0.033409 kWh. Total GPU Power : 228.95194943041204 W
# [codecarbon INFO @ 18:13:35] 0.040589 kWh of electricity used since the beginning.
# Inferindo:  20%|██        | 860/4203 [08:59<34:35,  1.61it/s][codecarbon INFO @ 18:13:50] Energy consumed for RAM : 0.005519 kWh. RAM Power : 38.0 W
# Inferindo:  20%|██        | 861/4203 [09:00<34:26,  1.62it/s][codecarbon INFO @ 18:13:50] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.842277456800002 W
# [codecarbon INFO @ 18:13:50] Energy consumed for All CPU : 0.001866 kWh
# [codecarbon INFO @ 18:13:50] Energy consumed for all GPUs : 0.034361 kWh. Total GPU Power : 228.5306212076914 W
# [codecarbon INFO @ 18:13:50] 0.041746 kWh of electricity used since the beginning.
# Inferindo:  21%|██        | 885/4203 [09:14<29:51,  1.85it/s][codecarbon INFO @ 18:14:05] Energy consumed for RAM : 0.005672 kWh. RAM Power : 38.0 W
# Inferindo:  21%|██        | 886/4203 [09:15<31:46,  1.74it/s][codecarbon INFO @ 18:14:05] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.842346360800002 W
# [codecarbon INFO @ 18:14:05] Energy consumed for All CPU : 0.001918 kWh
# [codecarbon INFO @ 18:14:05] Energy consumed for all GPUs : 0.035315 kWh. Total GPU Power : 228.98695243950337 W
# [codecarbon INFO @ 18:14:05] 0.042904 kWh of electricity used since the beginning.
# Inferindo:  22%|██▏       | 911/4203 [09:30<31:27,  1.74it/s][codecarbon INFO @ 18:14:20] Energy consumed for RAM : 0.005825 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 18:14:20] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.840750063200002 W
# [codecarbon INFO @ 18:14:20] Energy consumed for All CPU : 0.001969 kWh
# [codecarbon INFO @ 18:14:20] Energy consumed for all GPUs : 0.036269 kWh. Total GPU Power : 228.97692443669126 W
# [codecarbon INFO @ 18:14:20] 0.044063 kWh of electricity used since the beginning.
# Inferindo:  22%|██▏       | 936/4203 [09:44<34:06,  1.60it/s][codecarbon INFO @ 18:14:35] Energy consumed for RAM : 0.005978 kWh. RAM Power : 38.0 W
# Inferindo:  22%|██▏       | 937/4203 [09:45<32:44,  1.66it/s][codecarbon INFO @ 18:14:35] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.840304944800003 W
# [codecarbon INFO @ 18:14:35] Energy consumed for All CPU : 0.002021 kWh
# [codecarbon INFO @ 18:14:35] Energy consumed for all GPUs : 0.037222 kWh. Total GPU Power : 228.9164332521386 W
# [codecarbon INFO @ 18:14:35] 0.045221 kWh of electricity used since the beginning.
# Inferindo:  23%|██▎       | 962/4203 [10:00<30:05,  1.79it/s][codecarbon INFO @ 18:14:50] Energy consumed for RAM : 0.006131 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 18:14:50] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.843311095999999 W
# [codecarbon INFO @ 18:14:50] Energy consumed for All CPU : 0.002073 kWh
# [codecarbon INFO @ 18:14:50] Energy consumed for all GPUs : 0.038176 kWh. Total GPU Power : 228.91178786311855 W
# [codecarbon INFO @ 18:14:50] 0.046380 kWh of electricity used since the beginning.
# [codecarbon INFO @ 18:14:50] 0.007595 g.CO2eq/s mean an estimation of 239.5278757619087 kg.CO2eq/year
# Inferindo:  23%|██▎       | 987/4203 [10:14<32:56,  1.63it/s][codecarbon INFO @ 18:15:05] Energy consumed for RAM : 0.006284 kWh. RAM Power : 38.0 W
# Inferindo:  24%|██▎       | 988/4203 [10:15<30:04,  1.78it/s][codecarbon INFO @ 18:15:05] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.853873330400003 W
# [codecarbon INFO @ 18:15:05] Energy consumed for All CPU : 0.002125 kWh
# [codecarbon INFO @ 18:15:05] Energy consumed for all GPUs : 0.039130 kWh. Total GPU Power : 228.95599770296337 W
# [codecarbon INFO @ 18:15:05] 0.047538 kWh of electricity used since the beginning.
# Inferindo:  24%|██▍       | 1012/4203 [10:29<33:14,  1.60it/s][codecarbon INFO @ 18:15:20] Energy consumed for RAM : 0.006437 kWh. RAM Power : 38.0 W
# Inferindo:  24%|██▍       | 1013/4203 [10:30<32:26,  1.64it/s][codecarbon INFO @ 18:15:20] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.8543147552 W
# [codecarbon INFO @ 18:15:20] Energy consumed for All CPU : 0.002176 kWh
# [codecarbon INFO @ 18:15:20] Energy consumed for all GPUs : 0.040083 kWh. Total GPU Power : 228.74867142060873 W
# [codecarbon INFO @ 18:15:20] 0.048696 kWh of electricity used since the beginning.
# Inferindo:  25%|██▍       | 1038/4203 [10:44<35:23,  1.49it/s][codecarbon INFO @ 18:15:35] Energy consumed for RAM : 0.006590 kWh. RAM Power : 38.0 W
# Inferindo:  25%|██▍       | 1039/4203 [10:45<35:10,  1.50it/s][codecarbon INFO @ 18:15:35] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.853640806400001 W
# [codecarbon INFO @ 18:15:35] Energy consumed for All CPU : 0.002228 kWh
# [codecarbon INFO @ 18:15:35] Energy consumed for all GPUs : 0.041035 kWh. Total GPU Power : 228.4985527445347 W
# [codecarbon INFO @ 18:15:35] 0.049853 kWh of electricity used since the beginning.
# Inferindo:  25%|██▌       | 1063/4203 [10:59<29:10,  1.79it/s][codecarbon INFO @ 18:15:50] Energy consumed for RAM : 0.006743 kWh. RAM Power : 38.0 W
# Inferindo:  25%|██▌       | 1064/4203 [11:00<29:03,  1.80it/s][codecarbon INFO @ 18:15:50] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.843271899200001 W
# [codecarbon INFO @ 18:15:50] Energy consumed for All CPU : 0.002280 kWh
# [codecarbon INFO @ 18:15:50] Energy consumed for all GPUs : 0.041994 kWh. Total GPU Power : 230.18013208250665 W
# [codecarbon INFO @ 18:15:50] 0.051016 kWh of electricity used since the beginning.
# Inferindo:  26%|██▌       | 1090/4203 [11:14<30:21,  1.71it/s][codecarbon INFO @ 18:16:05] Energy consumed for RAM : 0.006896 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 18:16:05] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.848693211200004 W
# [codecarbon INFO @ 18:16:05] Energy consumed for All CPU : 0.002331 kWh
# [codecarbon INFO @ 18:16:05] Energy consumed for all GPUs : 0.042948 kWh. Total GPU Power : 229.02306638934493 W
# [codecarbon INFO @ 18:16:05] 0.052175 kWh of electricity used since the beginning.
# Inferindo:  27%|██▋       | 1114/4203 [11:29<30:03,  1.71it/s][codecarbon INFO @ 18:16:20] Energy consumed for RAM : 0.007049 kWh. RAM Power : 38.0 W
# Inferindo:  27%|██▋       | 1115/4203 [11:30<27:42,  1.86it/s][codecarbon INFO @ 18:16:20] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.848139848000002 W
# [codecarbon INFO @ 18:16:20] Energy consumed for All CPU : 0.002383 kWh
# [codecarbon INFO @ 18:16:20] Energy consumed for all GPUs : 0.043901 kWh. Total GPU Power : 228.75997634592568 W
# [codecarbon INFO @ 18:16:20] 0.053333 kWh of electricity used since the beginning.
# Inferindo:  27%|██▋       | 1141/4203 [11:44<26:54,  1.90it/s][codecarbon INFO @ 18:16:35] Energy consumed for RAM : 0.007202 kWh. RAM Power : 38.0 W
# Inferindo:  27%|██▋       | 1142/4203 [11:45<26:36,  1.92it/s][codecarbon INFO @ 18:16:35] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.850222332800007 W
# [codecarbon INFO @ 18:16:35] Energy consumed for All CPU : 0.002435 kWh
# [codecarbon INFO @ 18:16:35] Energy consumed for all GPUs : 0.044854 kWh. Total GPU Power : 228.93274487776247 W
# [codecarbon INFO @ 18:16:35] 0.054491 kWh of electricity used since the beginning.
# Inferindo:  28%|██▊       | 1165/4203 [11:59<29:13,  1.73it/s][codecarbon INFO @ 18:16:50] Energy consumed for RAM : 0.007355 kWh. RAM Power : 38.0 W
# Inferindo:  28%|██▊       | 1166/4203 [12:00<30:22,  1.67it/s][codecarbon INFO @ 18:16:50] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.851135048000003 W
# [codecarbon INFO @ 18:16:50] Energy consumed for All CPU : 0.002487 kWh
# [codecarbon INFO @ 18:16:50] Energy consumed for all GPUs : 0.045807 kWh. Total GPU Power : 228.63429727090903 W
# [codecarbon INFO @ 18:16:50] 0.055648 kWh of electricity used since the beginning.
# [codecarbon INFO @ 18:16:50] 0.007596 g.CO2eq/s mean an estimation of 239.55370371032495 kg.CO2eq/year
# Inferindo:  28%|██▊       | 1189/4203 [12:14<31:00,  1.62it/s][codecarbon INFO @ 18:17:05] Energy consumed for RAM : 0.007508 kWh. RAM Power : 38.0 W
# Inferindo:  28%|██▊       | 1190/4203 [12:15<33:39,  1.49it/s][codecarbon INFO @ 18:17:05] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.8497682792 W
# [codecarbon INFO @ 18:17:05] Energy consumed for All CPU : 0.002538 kWh
# [codecarbon INFO @ 18:17:05] Energy consumed for all GPUs : 0.046759 kWh. Total GPU Power : 228.51836508517061 W
# [codecarbon INFO @ 18:17:05] 0.056805 kWh of electricity used since the beginning.
# Inferindo:  29%|██▉       | 1213/4203 [12:29<34:56,  1.43it/s][codecarbon INFO @ 18:17:20] Energy consumed for RAM : 0.007661 kWh. RAM Power : 38.0 W
# Inferindo:  29%|██▉       | 1214/4203 [12:30<37:05,  1.34it/s][codecarbon INFO @ 18:17:20] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.843723454400001 W
# [codecarbon INFO @ 18:17:20] Energy consumed for All CPU : 0.002590 kWh
# [codecarbon INFO @ 18:17:20] Energy consumed for all GPUs : 0.047713 kWh. Total GPU Power : 228.93937776842674 W
# [codecarbon INFO @ 18:17:20] 0.057964 kWh of electricity used since the beginning.
# Inferindo:  29%|██▉       | 1237/4203 [12:44<32:30,  1.52it/s][codecarbon INFO @ 18:17:35] Energy consumed for RAM : 0.007814 kWh. RAM Power : 38.0 W
# Inferindo:  29%|██▉       | 1238/4203 [12:45<32:25,  1.52it/s][codecarbon INFO @ 18:17:35] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.8556537896 W
# [codecarbon INFO @ 18:17:35] Energy consumed for All CPU : 0.002642 kWh
# [codecarbon INFO @ 18:17:35] Energy consumed for all GPUs : 0.048666 kWh. Total GPU Power : 228.81637065185092 W
# [codecarbon INFO @ 18:17:35] 0.059122 kWh of electricity used since the beginning.
# Inferindo:  30%|███       | 1262/4203 [12:59<28:50,  1.70it/s][codecarbon INFO @ 18:17:50] Energy consumed for RAM : 0.007967 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 18:17:50] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.844635075200001 W
# [codecarbon INFO @ 18:17:50] Energy consumed for All CPU : 0.002694 kWh
# [codecarbon INFO @ 18:17:50] Energy consumed for all GPUs : 0.049619 kWh. Total GPU Power : 228.71210543690893 W
# [codecarbon INFO @ 18:17:50] 0.060279 kWh of electricity used since the beginning.
# Inferindo:  31%|███       | 1284/4203 [13:14<32:44,  1.49it/s][codecarbon INFO @ 18:18:05] Energy consumed for RAM : 0.008120 kWh. RAM Power : 38.0 W
# Inferindo:  31%|███       | 1285/4203 [13:15<33:27,  1.45it/s][codecarbon INFO @ 18:18:05] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.848617308800005 W
# [codecarbon INFO @ 18:18:05] Energy consumed for All CPU : 0.002745 kWh
# [codecarbon INFO @ 18:18:05] Energy consumed for all GPUs : 0.050572 kWh. Total GPU Power : 228.81605987351065 W
# [codecarbon INFO @ 18:18:05] 0.061437 kWh of electricity used since the beginning.
# Inferindo:  31%|███       | 1308/4203 [13:29<32:04,  1.50it/s][codecarbon INFO @ 18:18:20] Energy consumed for RAM : 0.008273 kWh. RAM Power : 38.0 W
# Inferindo:  31%|███       | 1309/4203 [13:30<30:18,  1.59it/s][codecarbon INFO @ 18:18:20] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.84837914 W
# [codecarbon INFO @ 18:18:20] Energy consumed for All CPU : 0.002797 kWh
# [codecarbon INFO @ 18:18:20] Energy consumed for all GPUs : 0.051526 kWh. Total GPU Power : 228.98422366468475 W
# [codecarbon INFO @ 18:18:20] 0.062596 kWh of electricity used since the beginning.
# Inferindo:  32%|███▏      | 1333/4203 [13:44<28:16,  1.69it/s][codecarbon INFO @ 18:18:35] Energy consumed for RAM : 0.008426 kWh. RAM Power : 38.0 W
# Inferindo:  32%|███▏      | 1334/4203 [13:45<28:39,  1.67it/s][codecarbon INFO @ 18:18:35] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.845452080800001 W
# [codecarbon INFO @ 18:18:35] Energy consumed for All CPU : 0.002849 kWh
# [codecarbon INFO @ 18:18:35] Energy consumed for all GPUs : 0.052479 kWh. Total GPU Power : 228.84820497815466 W
# [codecarbon INFO @ 18:18:35] 0.063754 kWh of electricity used since the beginning.
# Inferindo:  32%|███▏      | 1357/4203 [13:59<26:32,  1.79it/s][codecarbon INFO @ 18:18:50] Energy consumed for RAM : 0.008579 kWh. RAM Power : 38.0 W
# Inferindo:  32%|███▏      | 1358/4203 [14:00<27:51,  1.70it/s][codecarbon INFO @ 18:18:50] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.8504190368 W
# [codecarbon INFO @ 18:18:50] Energy consumed for All CPU : 0.002901 kWh
# [codecarbon INFO @ 18:18:50] Energy consumed for all GPUs : 0.053432 kWh. Total GPU Power : 228.67749069929104 W
# [codecarbon INFO @ 18:18:50] 0.064911 kWh of electricity used since the beginning.
# [codecarbon INFO @ 18:18:50] 0.007591 g.CO2eq/s mean an estimation of 239.4033946330012 kg.CO2eq/year
# Inferindo:  33%|███▎      | 1381/4203 [14:14<30:38,  1.54it/s][codecarbon INFO @ 18:19:05] Energy consumed for RAM : 0.008732 kWh. RAM Power : 38.0 W
# Inferindo:  33%|███▎      | 1382/4203 [14:15<29:09,  1.61it/s][codecarbon INFO @ 18:19:05] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.8528237936 W
# [codecarbon INFO @ 18:19:05] Energy consumed for All CPU : 0.002952 kWh
# [codecarbon INFO @ 18:19:05] Energy consumed for all GPUs : 0.054385 kWh. Total GPU Power : 228.74477804152033 W
# [codecarbon INFO @ 18:19:05] 0.066069 kWh of electricity used since the beginning.
# Inferindo:  33%|███▎      | 1404/4203 [14:29<32:55,  1.42it/s][codecarbon INFO @ 18:19:20] Energy consumed for RAM : 0.008885 kWh. RAM Power : 38.0 W
# Inferindo:  33%|███▎      | 1405/4203 [14:30<31:32,  1.48it/s][codecarbon INFO @ 18:19:20] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.8490371984 W
# [codecarbon INFO @ 18:19:20] Energy consumed for All CPU : 0.003004 kWh
# [codecarbon INFO @ 18:19:20] Energy consumed for all GPUs : 0.055338 kWh. Total GPU Power : 228.7488011739034 W
# [codecarbon INFO @ 18:19:20] 0.067227 kWh of electricity used since the beginning.
# Inferindo:  34%|███▍      | 1429/4203 [14:44<27:40,  1.67it/s][codecarbon INFO @ 18:19:35] Energy consumed for RAM : 0.009038 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 18:19:35] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.8433606392 W
# [codecarbon INFO @ 18:19:35] Energy consumed for All CPU : 0.003056 kWh
# [codecarbon INFO @ 18:19:35] Energy consumed for all GPUs : 0.056291 kWh. Total GPU Power : 228.6809082753057 W
# [codecarbon INFO @ 18:19:35] 0.068384 kWh of electricity used since the beginning.
# Inferindo:  35%|███▍      | 1453/4203 [14:59<30:27,  1.50it/s][codecarbon INFO @ 18:19:50] Energy consumed for RAM : 0.009191 kWh. RAM Power : 38.0 W
# Inferindo:  35%|███▍      | 1454/4203 [15:00<29:43,  1.54it/s][codecarbon INFO @ 18:19:50] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.851316905600001 W
# [codecarbon INFO @ 18:19:50] Energy consumed for All CPU : 0.003108 kWh
# [codecarbon INFO @ 18:19:50] Energy consumed for all GPUs : 0.057243 kWh. Total GPU Power : 228.71327373924652 W
# [codecarbon INFO @ 18:19:50] 0.069542 kWh of electricity used since the beginning.
# Inferindo:  35%|███▌      | 1477/4203 [15:14<29:10,  1.56it/s][codecarbon INFO @ 18:20:05] Energy consumed for RAM : 0.009344 kWh. RAM Power : 38.0 W
# Inferindo:  35%|███▌      | 1478/4203 [15:15<27:13,  1.67it/s][codecarbon INFO @ 18:20:05] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.850858092800001 W
# [codecarbon INFO @ 18:20:05] Energy consumed for All CPU : 0.003159 kWh
# [codecarbon INFO @ 18:20:05] Energy consumed for all GPUs : 0.058197 kWh. Total GPU Power : 229.03081664831203 W
# [codecarbon INFO @ 18:20:05] 0.070701 kWh of electricity used since the beginning.
# Inferindo:  36%|███▌      | 1502/4203 [15:29<31:19,  1.44it/s][codecarbon INFO @ 18:20:20] Energy consumed for RAM : 0.009497 kWh. RAM Power : 38.0 W
# Inferindo:  36%|███▌      | 1503/4203 [15:30<31:42,  1.42it/s][codecarbon INFO @ 18:20:20] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.848733084800001 W
# [codecarbon INFO @ 18:20:20] Energy consumed for All CPU : 0.003211 kWh
# [codecarbon INFO @ 18:20:20] Energy consumed for all GPUs : 0.059151 kWh. Total GPU Power : 228.944116458285 W
# [codecarbon INFO @ 18:20:20] 0.071859 kWh of electricity used since the beginning.
# Inferindo:  36%|███▋      | 1526/4203 [15:44<28:32,  1.56it/s][codecarbon INFO @ 18:20:35] Energy consumed for RAM : 0.009650 kWh. RAM Power : 38.0 W
# Inferindo:  36%|███▋      | 1527/4203 [15:45<31:50,  1.40it/s][codecarbon INFO @ 18:20:35] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.847440980000002 W
# [codecarbon INFO @ 18:20:35] Energy consumed for All CPU : 0.003263 kWh
# [codecarbon INFO @ 18:20:35] Energy consumed for all GPUs : 0.060111 kWh. Total GPU Power : 230.37361147320107 W
# [codecarbon INFO @ 18:20:35] 0.073024 kWh of electricity used since the beginning.
# Inferindo:  37%|███▋      | 1548/4203 [15:59<29:40,  1.49it/s][codecarbon INFO @ 18:20:50] Energy consumed for RAM : 0.009803 kWh. RAM Power : 38.0 W
# Inferindo:  37%|███▋      | 1549/4203 [16:00<27:29,  1.61it/s][codecarbon INFO @ 18:20:50] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.843505668799999 W
# [codecarbon INFO @ 18:20:50] Energy consumed for All CPU : 0.003315 kWh
# [codecarbon INFO @ 18:20:50] Energy consumed for all GPUs : 0.061066 kWh. Total GPU Power : 229.13799250199818 W
# [codecarbon INFO @ 18:20:50] 0.074183 kWh of electricity used since the beginning.
# [codecarbon INFO @ 18:20:50] 0.007599 g.CO2eq/s mean an estimation of 239.62815631581898 kg.CO2eq/year
# Inferindo:  37%|███▋      | 1572/4203 [16:14<29:09,  1.50it/s][codecarbon INFO @ 18:21:05] Energy consumed for RAM : 0.009956 kWh. RAM Power : 38.0 W
# Inferindo:  37%|███▋      | 1573/4203 [16:15<30:42,  1.43it/s][codecarbon INFO @ 18:21:05] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.855648224 W
# [codecarbon INFO @ 18:21:05] Energy consumed for All CPU : 0.003366 kWh
# [codecarbon INFO @ 18:21:05] Energy consumed for all GPUs : 0.062019 kWh. Total GPU Power : 228.92896282658938 W
# [codecarbon INFO @ 18:21:05] 0.075341 kWh of electricity used since the beginning.
# Inferindo:  38%|███▊      | 1596/4203 [16:29<25:39,  1.69it/s][codecarbon INFO @ 18:21:20] Energy consumed for RAM : 0.010109 kWh. RAM Power : 38.0 W
# Inferindo:  38%|███▊      | 1597/4203 [16:30<25:52,  1.68it/s][codecarbon INFO @ 18:21:20] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.844799156000002 W
# [codecarbon INFO @ 18:21:20] Energy consumed for All CPU : 0.003418 kWh
# [codecarbon INFO @ 18:21:20] Energy consumed for all GPUs : 0.062972 kWh. Total GPU Power : 228.73877417685517 W
# [codecarbon INFO @ 18:21:20] 0.076499 kWh of electricity used since the beginning.
# Inferindo:  39%|███▊      | 1622/4203 [16:44<24:57,  1.72it/s][codecarbon INFO @ 18:21:35] Energy consumed for RAM : 0.010262 kWh. RAM Power : 38.0 W
# Inferindo:  39%|███▊      | 1623/4203 [16:45<24:35,  1.75it/s][codecarbon INFO @ 18:21:35] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.851279292800001 W
# [codecarbon INFO @ 18:21:35] Energy consumed for All CPU : 0.003470 kWh
# [codecarbon INFO @ 18:21:35] Energy consumed for all GPUs : 0.063925 kWh. Total GPU Power : 228.64383147140404 W
# [codecarbon INFO @ 18:21:35] 0.077656 kWh of electricity used since the beginning.
# Inferindo:  39%|███▉      | 1646/4203 [16:59<25:03,  1.70it/s][codecarbon INFO @ 18:21:50] Energy consumed for RAM : 0.010415 kWh. RAM Power : 38.0 W
# Inferindo:  39%|███▉      | 1647/4203 [17:00<25:22,  1.68it/s][codecarbon INFO @ 18:21:50] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.855463644800004 W
# [codecarbon INFO @ 18:21:50] Energy consumed for All CPU : 0.003522 kWh
# [codecarbon INFO @ 18:21:50] Energy consumed for all GPUs : 0.064877 kWh. Total GPU Power : 228.5148526434999 W
# [codecarbon INFO @ 18:21:50] 0.078813 kWh of electricity used since the beginning.
# Inferindo:  40%|███▉      | 1671/4203 [17:14<27:38,  1.53it/s][codecarbon INFO @ 18:22:05] Energy consumed for RAM : 0.010568 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 18:22:05] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.850105527200004 W
# [codecarbon INFO @ 18:22:05] Energy consumed for All CPU : 0.003573 kWh
# [codecarbon INFO @ 18:22:05] Energy consumed for all GPUs : 0.065831 kWh. Total GPU Power : 229.06899957848785 W
# [codecarbon INFO @ 18:22:05] 0.079972 kWh of electricity used since the beginning.
# Inferindo:  40%|████      | 1693/4203 [17:29<27:05,  1.54it/s][codecarbon INFO @ 18:22:20] Energy consumed for RAM : 0.010721 kWh. RAM Power : 38.0 W
# Inferindo:  40%|████      | 1694/4203 [17:30<29:56,  1.40it/s][codecarbon INFO @ 18:22:20] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.8472755744 W
# [codecarbon INFO @ 18:22:20] Energy consumed for All CPU : 0.003625 kWh
# [codecarbon INFO @ 18:22:20] Energy consumed for all GPUs : 0.066784 kWh. Total GPU Power : 228.76253665552798 W
# [codecarbon INFO @ 18:22:20] 0.081130 kWh of electricity used since the beginning.
# Inferindo:  41%|████      | 1717/4203 [17:44<27:28,  1.51it/s][codecarbon INFO @ 18:22:35] Energy consumed for RAM : 0.010874 kWh. RAM Power : 38.0 W
# Inferindo:  41%|████      | 1718/4203 [17:45<29:05,  1.42it/s][codecarbon INFO @ 18:22:35] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.8561922056 W
# [codecarbon INFO @ 18:22:35] Energy consumed for All CPU : 0.003677 kWh
# [codecarbon INFO @ 18:22:35] Energy consumed for all GPUs : 0.067737 kWh. Total GPU Power : 228.8202717950878 W
# [codecarbon INFO @ 18:22:35] 0.082288 kWh of electricity used since the beginning.
# Inferindo:  41%|████▏     | 1742/4203 [17:59<23:23,  1.75it/s][codecarbon INFO @ 18:22:50] Energy consumed for RAM : 0.011027 kWh. RAM Power : 38.0 W
# Inferindo:  41%|████▏     | 1743/4203 [18:00<23:51,  1.72it/s][codecarbon INFO @ 18:22:50] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.847801016000002 W
# [codecarbon INFO @ 18:22:50] Energy consumed for All CPU : 0.003728 kWh
# [codecarbon INFO @ 18:22:50] Energy consumed for all GPUs : 0.068691 kWh. Total GPU Power : 228.92981231919188 W
# [codecarbon INFO @ 18:22:50] 0.083446 kWh of electricity used since the beginning.
# [codecarbon INFO @ 18:22:50] 0.007592 g.CO2eq/s mean an estimation of 239.41043095452682 kg.CO2eq/year
# Inferindo:  42%|████▏     | 1766/4203 [18:14<23:58,  1.69it/s][codecarbon INFO @ 18:23:05] Energy consumed for RAM : 0.011180 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 18:23:05] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.851595934400002 W
# [codecarbon INFO @ 18:23:05] Energy consumed for All CPU : 0.003780 kWh
# [codecarbon INFO @ 18:23:05] Energy consumed for all GPUs : 0.069644 kWh. Total GPU Power : 228.84233611069084 W
# [codecarbon INFO @ 18:23:05] 0.084604 kWh of electricity used since the beginning.
# Inferindo:  43%|████▎     | 1791/4203 [18:29<21:08,  1.90it/s][codecarbon INFO @ 18:23:20] Energy consumed for RAM : 0.011333 kWh. RAM Power : 38.0 W
# Inferindo:  43%|████▎     | 1792/4203 [18:30<20:50,  1.93it/s][codecarbon INFO @ 18:23:20] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.8499297176 W
# [codecarbon INFO @ 18:23:20] Energy consumed for All CPU : 0.003832 kWh
# [codecarbon INFO @ 18:23:20] Energy consumed for all GPUs : 0.070598 kWh. Total GPU Power : 228.89915047242928 W
# [codecarbon INFO @ 18:23:20] 0.085763 kWh of electricity used since the beginning.
# Inferindo:  43%|████▎     | 1817/4203 [18:45<23:32,  1.69it/s][codecarbon INFO @ 18:23:35] Energy consumed for RAM : 0.011486 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 18:23:35] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.85216508 W
# [codecarbon INFO @ 18:23:35] Energy consumed for All CPU : 0.003884 kWh
# [codecarbon INFO @ 18:23:35] Energy consumed for all GPUs : 0.071550 kWh. Total GPU Power : 228.603578985634 W
# [codecarbon INFO @ 18:23:35] 0.086920 kWh of electricity used since the beginning.
# Inferindo:  44%|████▍     | 1842/4203 [18:59<24:15,  1.62it/s][codecarbon INFO @ 18:23:50] Energy consumed for RAM : 0.011639 kWh. RAM Power : 38.0 W
# Inferindo:  44%|████▍     | 1843/4203 [19:00<22:12,  1.77it/s][codecarbon INFO @ 18:23:50] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.849823676 W
# [codecarbon INFO @ 18:23:50] Energy consumed for All CPU : 0.003935 kWh
# [codecarbon INFO @ 18:23:50] Energy consumed for all GPUs : 0.072503 kWh. Total GPU Power : 228.7675107779687 W
# [codecarbon INFO @ 18:23:50] 0.088078 kWh of electricity used since the beginning.
# Inferindo:  44%|████▍     | 1867/4203 [19:14<21:21,  1.82it/s][codecarbon INFO @ 18:24:05] Energy consumed for RAM : 0.011792 kWh. RAM Power : 38.0 W
# Inferindo:  44%|████▍     | 1868/4203 [19:15<21:23,  1.82it/s][codecarbon INFO @ 18:24:05] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.857666513600002 W
# [codecarbon INFO @ 18:24:05] Energy consumed for All CPU : 0.003987 kWh
# [codecarbon INFO @ 18:24:05] Energy consumed for all GPUs : 0.073458 kWh. Total GPU Power : 229.21358224888434 W
# [codecarbon INFO @ 18:24:05] 0.089237 kWh of electricity used since the beginning.
# ...
# [codecarbon INFO @ 18:41:20] 0.169163 kWh of electricity used since the beginning.
# Inferindo:  85%|████████▌ | 3590/4203 [36:44<05:51,  1.74it/s][codecarbon INFO @ 18:41:35] Energy consumed for RAM : 0.022502 kWh. RAM Power : 38.0 W
# Inferindo:  85%|████████▌ | 3591/4203 [36:45<05:46,  1.77it/s][codecarbon INFO @ 18:41:35] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.842921568800003 W
# [codecarbon INFO @ 18:41:35] Energy consumed for All CPU : 0.007609 kWh
# [codecarbon INFO @ 18:41:35] Energy consumed for all GPUs : 0.140211 kWh. Total GPU Power : 228.94398360243014 W
# [codecarbon INFO @ 18:41:35] 0.170322 kWh of electricity used since the beginning.
# Inferindo:  86%|████████▌ | 3616/4203 [36:59<05:38,  1.74it/s][codecarbon INFO @ 18:41:50] Energy consumed for RAM : 0.022655 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 18:41:50] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.840212280800001 W
# [codecarbon INFO @ 18:41:50] Energy consumed for All CPU : 0.007661 kWh
# [codecarbon INFO @ 18:41:50] Energy consumed for all GPUs : 0.141164 kWh. Total GPU Power : 228.8745470467541 W
# [codecarbon INFO @ 18:41:50] 0.171480 kWh of electricity used since the beginning.
# Inferindo:  87%|████████▋ | 3641/4203 [37:15<05:04,  1.85it/s][codecarbon INFO @ 18:42:05] Energy consumed for RAM : 0.022808 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 18:42:05] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.8382024296 W
# [codecarbon INFO @ 18:42:05] Energy consumed for All CPU : 0.007712 kWh
# [codecarbon INFO @ 18:42:05] Energy consumed for all GPUs : 0.142118 kWh. Total GPU Power : 228.99853822442358 W
# [codecarbon INFO @ 18:42:05] 0.172639 kWh of electricity used since the beginning.
# Inferindo:  87%|████████▋ | 3666/4203 [37:29<05:41,  1.57it/s][codecarbon INFO @ 18:42:20] Energy consumed for RAM : 0.022961 kWh. RAM Power : 38.0 W
# Inferindo:  87%|████████▋ | 3667/4203 [37:30<05:18,  1.68it/s][codecarbon INFO @ 18:42:20] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.8462059784 W
# [codecarbon INFO @ 18:42:20] Energy consumed for All CPU : 0.007764 kWh
# [codecarbon INFO @ 18:42:20] Energy consumed for all GPUs : 0.143072 kWh. Total GPU Power : 228.87277422867206 W
# [codecarbon INFO @ 18:42:20] 0.173797 kWh of electricity used since the beginning.
# Inferindo:  88%|████████▊ | 3692/4203 [37:45<04:50,  1.76it/s][codecarbon INFO @ 18:42:35] Energy consumed for RAM : 0.023114 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 18:42:35] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.840790246400005 W
# [codecarbon INFO @ 18:42:35] Energy consumed for All CPU : 0.007816 kWh
# [codecarbon INFO @ 18:42:35] Energy consumed for all GPUs : 0.144026 kWh. Total GPU Power : 229.02312451229227 W
# [codecarbon INFO @ 18:42:35] 0.174955 kWh of electricity used since the beginning.
# Inferindo:  88%|████████▊ | 3716/4203 [37:59<04:46,  1.70it/s][codecarbon INFO @ 18:42:50] Energy consumed for RAM : 0.023267 kWh. RAM Power : 38.0 W
# Inferindo:  88%|████████▊ | 3717/4203 [38:00<04:39,  1.74it/s][codecarbon INFO @ 18:42:50] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.837536537600002 W
# [codecarbon INFO @ 18:42:50] Energy consumed for All CPU : 0.007868 kWh
# [codecarbon INFO @ 18:42:50] Energy consumed for all GPUs : 0.144980 kWh. Total GPU Power : 228.98391752259627 W
# [codecarbon INFO @ 18:42:50] 0.176114 kWh of electricity used since the beginning.
# [codecarbon INFO @ 18:42:50] 0.007593 g.CO2eq/s mean an estimation of 239.46066603411384 kg.CO2eq/year
# Inferindo:  89%|████████▉ | 3741/4203 [38:14<04:23,  1.75it/s][codecarbon INFO @ 18:43:05] Energy consumed for RAM : 0.023420 kWh. RAM Power : 38.0 W
# Inferindo:  89%|████████▉ | 3742/4203 [38:15<04:20,  1.77it/s][codecarbon INFO @ 18:43:05] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.842086959200001 W
# [codecarbon INFO @ 18:43:05] Energy consumed for All CPU : 0.007919 kWh
# [codecarbon INFO @ 18:43:05] Energy consumed for all GPUs : 0.145932 kWh. Total GPU Power : 228.724436964162 W
# [codecarbon INFO @ 18:43:05] 0.177272 kWh of electricity used since the beginning.
# Inferindo:  90%|████████▉ | 3764/4203 [38:29<04:21,  1.68it/s][codecarbon INFO @ 18:43:20] Energy consumed for RAM : 0.023573 kWh. RAM Power : 38.0 W
# Inferindo:  90%|████████▉ | 3765/4203 [38:30<04:22,  1.67it/s][codecarbon INFO @ 18:43:20] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.8427959576 W
# [codecarbon INFO @ 18:43:20] Energy consumed for All CPU : 0.007971 kWh
# [codecarbon INFO @ 18:43:20] Energy consumed for all GPUs : 0.146885 kWh. Total GPU Power : 228.6656067203373 W
# [codecarbon INFO @ 18:43:20] 0.178429 kWh of electricity used since the beginning.
# Inferindo:  90%|█████████ | 3789/4203 [38:44<04:27,  1.55it/s][codecarbon INFO @ 18:43:35] Energy consumed for RAM : 0.023726 kWh. RAM Power : 38.0 W
# Inferindo:  90%|█████████ | 3790/4203 [38:45<04:27,  1.54it/s][codecarbon INFO @ 18:43:35] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.8394730712 W
# [codecarbon INFO @ 18:43:35] Energy consumed for All CPU : 0.008023 kWh
# [codecarbon INFO @ 18:43:35] Energy consumed for all GPUs : 0.147839 kWh. Total GPU Power : 228.90721628450547 W
# [codecarbon INFO @ 18:43:35] 0.179587 kWh of electricity used since the beginning.
# Inferindo:  91%|█████████ | 3814/4203 [38:59<04:01,  1.61it/s][codecarbon INFO @ 18:43:50] Energy consumed for RAM : 0.023879 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 18:43:50] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.840902235200002 W
# [codecarbon INFO @ 18:43:50] Energy consumed for All CPU : 0.008074 kWh
# [codecarbon INFO @ 18:43:50] Energy consumed for all GPUs : 0.148793 kWh. Total GPU Power : 228.9872540725422 W
# [codecarbon INFO @ 18:43:50] 0.180746 kWh of electricity used since the beginning.
# Inferindo:  91%|█████████▏| 3837/4203 [39:14<03:46,  1.62it/s][codecarbon INFO @ 18:44:05] Energy consumed for RAM : 0.024032 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 18:44:05] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.838552328000002 W
# [codecarbon INFO @ 18:44:05] Energy consumed for All CPU : 0.008126 kWh
# [codecarbon INFO @ 18:44:05] Energy consumed for all GPUs : 0.149746 kWh. Total GPU Power : 228.88995905348278 W
# [codecarbon INFO @ 18:44:05] 0.181904 kWh of electricity used since the beginning.
# Inferindo:  92%|█████████▏| 3861/4203 [39:29<03:36,  1.58it/s][codecarbon INFO @ 18:44:20] Energy consumed for RAM : 0.024185 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 18:44:20] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.839169224000004 W
# [codecarbon INFO @ 18:44:20] Energy consumed for All CPU : 0.008178 kWh
# [codecarbon INFO @ 18:44:20] Energy consumed for all GPUs : 0.150699 kWh. Total GPU Power : 228.72982298458285 W
# [codecarbon INFO @ 18:44:20] 0.183062 kWh of electricity used since the beginning.
# Inferindo:  92%|█████████▏| 3885/4203 [39:44<03:14,  1.64it/s][codecarbon INFO @ 18:44:35] Energy consumed for RAM : 0.024338 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 18:44:35] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.839921336000002 W
# [codecarbon INFO @ 18:44:35] Energy consumed for All CPU : 0.008229 kWh
# [codecarbon INFO @ 18:44:35] Energy consumed for all GPUs : 0.151653 kWh. Total GPU Power : 229.08319657166666 W
# [codecarbon INFO @ 18:44:35] 0.184221 kWh of electricity used since the beginning.
# Inferindo:  93%|█████████▎| 3910/4203 [39:59<03:03,  1.59it/s][codecarbon INFO @ 18:44:50] Energy consumed for RAM : 0.024491 kWh. RAM Power : 38.0 W
# Inferindo:  93%|█████████▎| 3911/4203 [40:00<02:47,  1.75it/s][codecarbon INFO @ 18:44:50] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.843656444 W
# [codecarbon INFO @ 18:44:50] Energy consumed for All CPU : 0.008281 kWh
# [codecarbon INFO @ 18:44:50] Energy consumed for all GPUs : 0.152607 kWh. Total GPU Power : 228.93128247155525 W
# [codecarbon INFO @ 18:44:50] 0.185379 kWh of electricity used since the beginning.
# [codecarbon INFO @ 18:44:50] 0.007593 g.CO2eq/s mean an estimation of 239.45667170598878 kg.CO2eq/year
# Inferindo:  94%|█████████▎| 3935/4203 [40:14<02:29,  1.79it/s][codecarbon INFO @ 18:45:05] Energy consumed for RAM : 0.024644 kWh. RAM Power : 38.0 W
# Inferindo:  94%|█████████▎| 3936/4203 [40:15<02:33,  1.74it/s][codecarbon INFO @ 18:45:05] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.842729811200002 W
# [codecarbon INFO @ 18:45:05] Energy consumed for All CPU : 0.008333 kWh
# [codecarbon INFO @ 18:45:05] Energy consumed for all GPUs : 0.153560 kWh. Total GPU Power : 228.7273220555254 W
# [codecarbon INFO @ 18:45:05] 0.186537 kWh of electricity used since the beginning.
# Inferindo:  94%|█████████▍| 3960/4203 [40:29<02:23,  1.70it/s][codecarbon INFO @ 18:45:20] Energy consumed for RAM : 0.024797 kWh. RAM Power : 38.0 W
# Inferindo:  94%|█████████▍| 3961/4203 [40:30<02:24,  1.67it/s][codecarbon INFO @ 18:45:20] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.845408312000004 W
# [codecarbon INFO @ 18:45:20] Energy consumed for All CPU : 0.008385 kWh
# [codecarbon INFO @ 18:45:20] Energy consumed for all GPUs : 0.154518 kWh. Total GPU Power : 229.9382894724327 W
# [codecarbon INFO @ 18:45:20] 0.187699 kWh of electricity used since the beginning.
# Inferindo:  95%|█████████▍| 3984/4203 [40:44<02:08,  1.70it/s][codecarbon INFO @ 18:45:35] Energy consumed for RAM : 0.024950 kWh. RAM Power : 38.0 W
# Inferindo:  95%|█████████▍| 3985/4203 [40:45<02:21,  1.55it/s][codecarbon INFO @ 18:45:35] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.845155109600002 W
# [codecarbon INFO @ 18:45:35] Energy consumed for All CPU : 0.008436 kWh
# [codecarbon INFO @ 18:45:35] Energy consumed for all GPUs : 0.155470 kWh. Total GPU Power : 228.7166336715329 W
# [codecarbon INFO @ 18:45:35] 0.188857 kWh of electricity used since the beginning.
# Inferindo:  95%|█████████▌| 4008/4203 [40:59<01:57,  1.65it/s][codecarbon INFO @ 18:45:50] Energy consumed for RAM : 0.025103 kWh. RAM Power : 38.0 W
# Inferindo:  95%|█████████▌| 4009/4203 [41:00<01:54,  1.70it/s][codecarbon INFO @ 18:45:50] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.842582225600003 W
# [codecarbon INFO @ 18:45:50] Energy consumed for All CPU : 0.008488 kWh
# [codecarbon INFO @ 18:45:50] Energy consumed for all GPUs : 0.156424 kWh. Total GPU Power : 228.81359257817084 W
# [codecarbon INFO @ 18:45:50] 0.190014 kWh of electricity used since the beginning.
# Inferindo:  96%|█████████▌| 4033/4203 [41:14<01:45,  1.61it/s][codecarbon INFO @ 18:46:05] Energy consumed for RAM : 0.025256 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 18:46:05] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.8567720576 W
# [codecarbon INFO @ 18:46:05] Energy consumed for All CPU : 0.008540 kWh
# [codecarbon INFO @ 18:46:05] Energy consumed for all GPUs : 0.157377 kWh. Total GPU Power : 228.77324289025327 W
# [codecarbon INFO @ 18:46:05] 0.191172 kWh of electricity used since the beginning.
# Inferindo:  97%|█████████▋| 4058/4203 [41:29<01:47,  1.35it/s][codecarbon INFO @ 18:46:20] Energy consumed for RAM : 0.025409 kWh. RAM Power : 38.0 W
# Inferindo:  97%|█████████▋| 4059/4203 [41:30<01:38,  1.46it/s][codecarbon INFO @ 18:46:20] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.843955776800003 W
# [codecarbon INFO @ 18:46:20] Energy consumed for All CPU : 0.008591 kWh
# [codecarbon INFO @ 18:46:20] Energy consumed for all GPUs : 0.158330 kWh. Total GPU Power : 228.80845562867327 W
# [codecarbon INFO @ 18:46:20] 0.192330 kWh of electricity used since the beginning.
# Inferindo:  97%|█████████▋| 4083/4203 [41:44<01:09,  1.73it/s][codecarbon INFO @ 18:46:35] Energy consumed for RAM : 0.025562 kWh. RAM Power : 38.0 W
# Inferindo:  97%|█████████▋| 4084/4203 [41:45<01:07,  1.76it/s][codecarbon INFO @ 18:46:35] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.8379814472 W
# [codecarbon INFO @ 18:46:35] Energy consumed for All CPU : 0.008643 kWh
# [codecarbon INFO @ 18:46:35] Energy consumed for all GPUs : 0.159284 kWh. Total GPU Power : 228.93953848594705 W
# [codecarbon INFO @ 18:46:35] 0.193489 kWh of electricity used since the beginning.
# Inferindo:  98%|█████████▊| 4108/4203 [41:59<00:53,  1.77it/s][codecarbon INFO @ 18:46:50] Energy consumed for RAM : 0.025715 kWh. RAM Power : 38.0 W
# Inferindo:  98%|█████████▊| 4109/4203 [42:00<00:57,  1.64it/s][codecarbon INFO @ 18:46:50] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.837197957600003 W
# [codecarbon INFO @ 18:46:50] Energy consumed for All CPU : 0.008695 kWh
# [codecarbon INFO @ 18:46:50] Energy consumed for all GPUs : 0.160237 kWh. Total GPU Power : 228.77132718202805 W
# [codecarbon INFO @ 18:46:50] 0.194646 kWh of electricity used since the beginning.
# [codecarbon INFO @ 18:46:50] 0.007595 g.CO2eq/s mean an estimation of 239.51602137050844 kg.CO2eq/year
# Inferindo:  98%|█████████▊| 4133/4203 [42:14<00:39,  1.77it/s][codecarbon INFO @ 18:47:05] Energy consumed for RAM : 0.025868 kWh. RAM Power : 38.0 W
# Inferindo:  98%|█████████▊| 4134/4203 [42:15<00:38,  1.79it/s][codecarbon INFO @ 18:47:05] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.837778824800003 W
# [codecarbon INFO @ 18:47:05] Energy consumed for All CPU : 0.008747 kWh
# [codecarbon INFO @ 18:47:05] Energy consumed for all GPUs : 0.161190 kWh. Total GPU Power : 228.7970073007563 W
# [codecarbon INFO @ 18:47:05] 0.195804 kWh of electricity used since the beginning.
# Inferindo:  99%|█████████▉| 4158/4203 [42:29<00:26,  1.68it/s][codecarbon INFO @ 18:47:20] Energy consumed for RAM : 0.026021 kWh. RAM Power : 38.0 W
# Inferindo:  99%|█████████▉| 4159/4203 [42:30<00:25,  1.75it/s][codecarbon INFO @ 18:47:20] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.842285441600003 W
# [codecarbon INFO @ 18:47:20] Energy consumed for All CPU : 0.008798 kWh
# [codecarbon INFO @ 18:47:20] Energy consumed for all GPUs : 0.162144 kWh. Total GPU Power : 228.96445678145605 W
# [codecarbon INFO @ 18:47:20] 0.196963 kWh of electricity used since the beginning.
# Inferindo: 100%|█████████▉| 4184/4203 [42:44<00:10,  1.73it/s][codecarbon INFO @ 18:47:35] Energy consumed for RAM : 0.026174 kWh. RAM Power : 38.0 W
# Inferindo: 100%|█████████▉| 4185/4203 [42:45<00:10,  1.70it/s][codecarbon INFO @ 18:47:35] Delta energy consumed for CPU with cpu_load : 0.000052 kWh, power : 12.843823188800002 W
# [codecarbon INFO @ 18:47:35] Energy consumed for All CPU : 0.008850 kWh
# [codecarbon INFO @ 18:47:35] Energy consumed for all GPUs : 0.163097 kWh. Total GPU Power : 228.8698853424826 W
# [codecarbon INFO @ 18:47:35] 0.198121 kWh of electricity used since the beginning.
# Inferindo: 100%|██████████| 4203/4203 [42:57<00:00,  1.63it/s]
# [codecarbon INFO @ 18:47:47] Energy consumed for RAM : 0.026300 kWh. RAM Power : 38.0 W
# Tempo total de execução: 2577.49 segundos
# [codecarbon INFO @ 18:47:48] Delta energy consumed for CPU with cpu_load : 0.000042 kWh, power : 12.836077423261543 W
# [codecarbon INFO @ 18:47:48] Energy consumed for All CPU : 0.008892 kWh
# [codecarbon INFO @ 18:47:48] Energy consumed for all GPUs : 0.163869 kWh. Total GPU Power : 223.67624861519107 W
# [codecarbon INFO @ 18:47:48] 0.199061 kWh of electricity used since the beginning.
# Total de emissões (detalhes em emissions.csv):  0.019577232647124677
# Acurácia: 0.5886271710682845
# F1-macro: 0.5021037127021436
# F1-weighted: 0.5361640064250016
#
# Relatório de classificação:
#               precision    recall  f1-score   support
#
#        BAIXA       0.62      0.88      0.73      2056
#        MÉDIA       0.40      0.14      0.20      1284
#         ALTA       0.57      0.58      0.57       863
#
#     accuracy                           0.59      4203
#    macro avg       0.53      0.53      0.50      4203
# weighted avg       0.54      0.59      0.54      4203
